# %%
import pandas as pd
import numpy as np
import os
import datetime
os.chdir('/home/ubuntu/Masters Thesis/')
from scripts.utilities.data_joining import GetModellingData

# %% [markdown]
# Data without Bots and De-emoji text processing

# %%
bitcoin_hourly = pd.read_csv("/mnt/bitcoin_hourly_prices_till_2023-03-30.csv", lineterminator='\n')
bitcoin_minutely = pd.read_csv("/mnt/bitcoin_price_minutely_data_till_2023_03_30.csv", lineterminator='\n')

# %%
bitcoin_minutely
# Out:
#                time exchange fsym tsym     close      high       low  \
# 0        1606780800   CCCAGG  BTC  USD  19704.72  19714.44  19686.87
# 1        1606780860   CCCAGG  BTC  USD  19682.63  19706.49  19674.34
# 2        1606780920   CCCAGG  BTC  USD  19688.59  19691.33  19654.82
# 3        1606780980   CCCAGG  BTC  USD  19664.79  19697.12  19659.91
# 4        1606781040   CCCAGG  BTC  USD  19628.40  19665.60  19623.03
# ...             ...      ...  ...  ...       ...       ...       ...
# 1223995  1680220500   CCCAGG  BTC  USD  28038.57  28044.74  28032.44
# 1223996  1680220560   CCCAGG  BTC  USD  28037.36  28043.24  28031.83
# 1223997  1680220620   CCCAGG  BTC  USD  28031.20  28039.71  28030.25
# 1223998  1680220680   CCCAGG  BTC  USD  28037.81  28038.74  28029.52
# 1223999  1680220740   CCCAGG  BTC  USD  28040.71  28052.54  28036.36
#
#              open  volumefrom    volumeto
# 0        19686.87      58.620  1151502.04
# 1        19704.72     132.800  2614001.65
# 2        19682.63      55.390  1090096.41
# 3        19688.59      51.070  1004714.46
# 4        19664.79     109.540  2149088.17
# ...           ...         ...         ...
# 1223995  28032.49      11.500   322442.59
# 1223996  28038.57      20.120   564252.17
# 1223997  28037.36      12.290   344664.77
# 1223998  28031.20       8.527   239073.67
# 1223999  28037.81      75.070  2105709.79
#
# [1224000 rows x 10 columns]

# %%
data_30min = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_True_interval_30T.csv", lineterminator='\n')
data_1hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_True_interval_1H.csv", lineterminator='\n')
data_4hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_True_interval_4H.csv", lineterminator='\n')
data_6hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_True_interval_6H.csv", lineterminator='\n')
data_1day = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_True_interval_D.csv", lineterminator='\n')

# %%
data_30min = data_30min[~data_30min['spacytextblob_processed_data_polarity_score'].isna()]
data_1hrs = data_1hrs[~data_1hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_4hrs = data_4hrs[~data_4hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_6hrs = data_6hrs[~data_6hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_1day = data_1day[~data_1day['spacytextblob_processed_data_polarity_score'].isna()]

data_30min = data_30min.drop(columns=['Unnamed: 0'])
data_1hrs = data_1hrs.drop(columns=['Unnamed: 0'])
data_4hrs = data_4hrs.drop(columns=['Unnamed: 0'])
data_6hrs = data_6hrs.drop(columns=['Unnamed: 0'])
data_1day = data_1day.drop(columns=['Unnamed: 0'])

# %%
bitcoin_minutely = bitcoin_minutely.rename(columns={'time': 'date'})
bitcoin_minutely['date'] = bitcoin_minutely['date'].apply(datetime.datetime.utcfromtimestamp)
bitcoin_hourly = bitcoin_hourly.rename(columns={'datetimes': 'date'})
bitcoin_hourly['date'] = pd.to_datetime(bitcoin_hourly['date'])

# %%
data_30min_joined = GetModellingData(data=data_30min, bitcoin_data=bitcoin_minutely, frequency='30T').get_data_for_feature_analysis()
data_1hr_joined = GetModellingData(data=data_1hrs, bitcoin_data=bitcoin_hourly, frequency='1H').get_data_for_feature_analysis()
data_4hr_joined = GetModellingData(data=data_4hrs, bitcoin_data=bitcoin_hourly, frequency='4H').get_data_for_feature_analysis()
data_6hr_joined = GetModellingData(data=data_6hrs, bitcoin_data=bitcoin_hourly, frequency='6H').get_data_for_feature_analysis()
data_1d_joined = GetModellingData(data=data_1day, bitcoin_data=bitcoin_hourly, frequency='1D').get_data_for_feature_analysis()
# Out:
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])

# %%
data_30min_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_30min_joined.dropna(inplace=True)
data_1hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1hr_joined.dropna(inplace=True)
data_4hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_4hr_joined.dropna(inplace=True)
data_6hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_6hr_joined.dropna(inplace=True)
data_1d_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1d_joined.dropna(inplace=True)

# %% [markdown]
# ### Plots and Analysis

# %% [markdown]
# 1. 30T Frequency

# %%
# correlation analysis - pearson
data_30min_joined.corr()
# Out:
#                                                      date  \
# date                                             1.000000
# flair_processed_data_score                      -0.016844
# spacytextblob_processed_data_polarity_score      0.128395
# spacytextblob_processed_data_subjectivity_score -0.031632
# textblob_processed_data_polarity_score           0.128395
# textblob_processed_data_subjectivity_score      -0.031632
# vader_processed_data_score                      -0.079405
# bert_processed_data_sentiment_score             -0.044424
# roberta_processed_data_sentiment_score           0.030953
# close                                           -0.707940
# close_t+1                                       -0.707245
# close_t+2                                       -0.708373
# close_t+3                                       -0.708360
# close_t+7                                       -0.707012
#
#                                                  flair_processed_data_score  \
# date                                                              -0.016844
# flair_processed_data_score                                         1.000000
# spacytextblob_processed_data_polarity_score                        0.247251
# spacytextblob_processed_data_subjectivity_score                   -0.043651
# textblob_processed_data_polarity_score                             0.247251
# textblob_processed_data_subjectivity_score                        -0.043651
# vader_processed_data_score                                         0.410342
# bert_processed_data_sentiment_score                                0.676578
# roberta_processed_data_sentiment_score                             0.367235
# close                                                              0.063130
# close_t+1                                                          0.062640
# close_t+2                                                          0.065258
# close_t+3                                                          0.066168
# close_t+7                                                          0.061517
#
#                                                  spacytextblob_processed_data_polarity_score  \
# date                                                                                0.128395
# flair_processed_data_score                                                          0.247251
# spacytextblob_processed_data_polarity_score                                         1.000000
# spacytextblob_processed_data_subjectivity_score                                     0.239387
# textblob_processed_data_polarity_score                                              1.000000
# textblob_processed_data_subjectivity_score                                          0.239387
# vader_processed_data_score                                                          0.285421
# bert_processed_data_sentiment_score                                                 0.308085
# roberta_processed_data_sentiment_score                                              0.280235
# close                                                                              -0.076277
# close_t+1                                                                          -0.076364
# close_t+2                                                                          -0.075751
# close_t+3                                                                          -0.075506
# close_t+7                                                                          -0.074922
#
#                                                  spacytextblob_processed_data_subjectivity_score  \
# date                                                                                   -0.031632
# flair_processed_data_score                                                             -0.043651
# spacytextblob_processed_data_polarity_score                                             0.239387
# spacytextblob_processed_data_subjectivity_score                                         1.000000
# textblob_processed_data_polarity_score                                                  0.239387
# textblob_processed_data_subjectivity_score                                              1.000000
# vader_processed_data_score                                                              0.100064
# bert_processed_data_sentiment_score                                                    -0.060416
# roberta_processed_data_sentiment_score                                                 -0.128645
# close                                                                                  -0.052141
# close_t+1                                                                              -0.054489
# close_t+2                                                                              -0.056513
# close_t+3                                                                              -0.055233
# close_t+7                                                                              -0.053299
#
#                                                  textblob_processed_data_polarity_score  \
# date                                                                           0.128395
# flair_processed_data_score                                                     0.247251
# spacytextblob_processed_data_polarity_score                                    1.000000
# spacytextblob_processed_data_subjectivity_score                                0.239387
# textblob_processed_data_polarity_score                                         1.000000
# textblob_processed_data_subjectivity_score                                     0.239387
# vader_processed_data_score                                                     0.285421
# bert_processed_data_sentiment_score                                            0.308085
# roberta_processed_data_sentiment_score                                         0.280235
# close                                                                         -0.076277
# close_t+1                                                                     -0.076364
# close_t+2                                                                     -0.075751
# close_t+3                                                                     -0.075506
# close_t+7                                                                     -0.074922
#
#                                                  textblob_processed_data_subjectivity_score  \
# date                                                                              -0.031632
# flair_processed_data_score                                                        -0.043651
# spacytextblob_processed_data_polarity_score                                        0.239387
# spacytextblob_processed_data_subjectivity_score                                    1.000000
# textblob_processed_data_polarity_score                                             0.239387
# textblob_processed_data_subjectivity_score                                         1.000000
# vader_processed_data_score                                                         0.100064
# bert_processed_data_sentiment_score                                               -0.060416
# roberta_processed_data_sentiment_score                                            -0.128645
# close                                                                             -0.052141
# close_t+1                                                                         -0.054489
# close_t+2                                                                         -0.056513
# close_t+3                                                                         -0.055233
# close_t+7                                                                         -0.053299
#
#                                                  vader_processed_data_score  \
# date                                                              -0.079405
# flair_processed_data_score                                         0.410342
# spacytextblob_processed_data_polarity_score                        0.285421
# spacytextblob_processed_data_subjectivity_score                    0.100064
# textblob_processed_data_polarity_score                             0.285421
# textblob_processed_data_subjectivity_score                         0.100064
# vader_processed_data_score                                         1.000000
# bert_processed_data_sentiment_score                                0.370230
# roberta_processed_data_sentiment_score                             0.550192
# close                                                              0.063993
# close_t+1                                                          0.062837
# close_t+2                                                          0.063825
# close_t+3                                                          0.066175
# close_t+7                                                          0.065431
#
#                                                  bert_processed_data_sentiment_score  \
# date                                                                       -0.044424
# flair_processed_data_score                                                  0.676578
# spacytextblob_processed_data_polarity_score                                 0.308085
# spacytextblob_processed_data_subjectivity_score                            -0.060416
# textblob_processed_data_polarity_score                                      0.308085
# textblob_processed_data_subjectivity_score                                 -0.060416
# vader_processed_data_score                                                  0.370230
# bert_processed_data_sentiment_score                                         1.000000
# roberta_processed_data_sentiment_score                                      0.507183
# close                                                                       0.060655
# close_t+1                                                                   0.060805
# close_t+2                                                                   0.064321
# close_t+3                                                                   0.064720
# close_t+7                                                                   0.059593
#
#                                                  roberta_processed_data_sentiment_score  \
# date                                                                           0.030953
# flair_processed_data_score                                                     0.367235
# spacytextblob_processed_data_polarity_score                                    0.280235
# spacytextblob_processed_data_subjectivity_score                               -0.128645
# textblob_processed_data_polarity_score                                         0.280235
# textblob_processed_data_subjectivity_score                                    -0.128645
# vader_processed_data_score                                                     0.550192
# bert_processed_data_sentiment_score                                            0.507183
# roberta_processed_data_sentiment_score                                         1.000000
# close                                                                          0.053956
# close_t+1                                                                      0.053048
# close_t+2                                                                      0.054038
# close_t+3                                                                      0.055362
# close_t+7                                                                      0.056026
#
#                                                     close  close_t+1  \
# date                                            -0.707940  -0.707245
# flair_processed_data_score                       0.063130   0.062640
# spacytextblob_processed_data_polarity_score     -0.076277  -0.076364
# spacytextblob_processed_data_subjectivity_score -0.052141  -0.054489
# textblob_processed_data_polarity_score          -0.076277  -0.076364
# textblob_processed_data_subjectivity_score      -0.052141  -0.054489
# vader_processed_data_score                       0.063993   0.062837
# bert_processed_data_sentiment_score              0.060655   0.060805
# roberta_processed_data_sentiment_score           0.053956   0.053048
# close                                            1.000000   0.999873
# close_t+1                                        0.999873   1.000000
# close_t+2                                        0.999701   0.999839
# close_t+3                                        0.999581   0.999687
# close_t+7                                        0.999171   0.999236
#
#                                                  close_t+2  close_t+3  \
# date                                             -0.708373  -0.708360
# flair_processed_data_score                        0.065258   0.066168
# spacytextblob_processed_data_polarity_score      -0.075751  -0.075506
# spacytextblob_processed_data_subjectivity_score  -0.056513  -0.055233
# textblob_processed_data_polarity_score           -0.075751  -0.075506
# textblob_processed_data_subjectivity_score       -0.056513  -0.055233
# vader_processed_data_score                        0.063825   0.066175
# bert_processed_data_sentiment_score               0.064321   0.064720
# roberta_processed_data_sentiment_score            0.054038   0.055362
# close                                             0.999701   0.999581
# close_t+1                                         0.999839   0.999687
# close_t+2                                         1.000000   0.999883
# close_t+3                                         0.999883   1.000000
# close_t+7                                         0.999382   0.999570
#
#                                                  close_t+7
# date                                             -0.707012
# flair_processed_data_score                        0.061517
# spacytextblob_processed_data_polarity_score      -0.074922
# spacytextblob_processed_data_subjectivity_score  -0.053299
# textblob_processed_data_polarity_score           -0.074922
# textblob_processed_data_subjectivity_score       -0.053299
# vader_processed_data_score                        0.065431
# bert_processed_data_sentiment_score               0.059593
# roberta_processed_data_sentiment_score            0.056026
# close                                             0.999171
# close_t+1                                         0.999236
# close_t+2                                         0.999382
# close_t+3                                         0.999570
# close_t+7                                         1.000000

# %% [markdown]
# Very bad correlation between all the weighted sentiment features and the closing dates

# %%
# correlation analysis - spearman
data_30min_joined.corr(method='spearman')
# Out:
#                                                      date  \
# date                                             1.000000
# flair_processed_data_score                      -0.038161
# spacytextblob_processed_data_polarity_score      0.059381
# spacytextblob_processed_data_subjectivity_score -0.008081
# textblob_processed_data_polarity_score           0.059381
# textblob_processed_data_subjectivity_score      -0.008081
# vader_processed_data_score                      -0.164793
# bert_processed_data_sentiment_score             -0.082823
# roberta_processed_data_sentiment_score          -0.040871
# close                                           -0.744912
# close_t+1                                       -0.743156
# close_t+2                                       -0.744251
# close_t+3                                       -0.742793
# close_t+7                                       -0.739925
#
#                                                  flair_processed_data_score  \
# date                                                              -0.038161
# flair_processed_data_score                                         1.000000
# spacytextblob_processed_data_polarity_score                        0.238421
# spacytextblob_processed_data_subjectivity_score                   -0.049125
# textblob_processed_data_polarity_score                             0.238421
# textblob_processed_data_subjectivity_score                        -0.049125
# vader_processed_data_score                                         0.387840
# bert_processed_data_sentiment_score                                0.695582
# roberta_processed_data_sentiment_score                             0.381202
# close                                                              0.085963
# close_t+1                                                          0.085366
# close_t+2                                                          0.085682
# close_t+3                                                          0.087670
# close_t+7                                                          0.078318
#
#                                                  spacytextblob_processed_data_polarity_score  \
# date                                                                                0.059381
# flair_processed_data_score                                                          0.238421
# spacytextblob_processed_data_polarity_score                                         1.000000
# spacytextblob_processed_data_subjectivity_score                                     0.270231
# textblob_processed_data_polarity_score                                              1.000000
# textblob_processed_data_subjectivity_score                                          0.270231
# vader_processed_data_score                                                          0.277869
# bert_processed_data_sentiment_score                                                 0.285300
# roberta_processed_data_sentiment_score                                              0.237368
# close                                                                              -0.031785
# close_t+1                                                                          -0.032018
# close_t+2                                                                          -0.032383
# close_t+3                                                                          -0.031310
# close_t+7                                                                          -0.031560
#
#                                                  spacytextblob_processed_data_subjectivity_score  \
# date                                                                                   -0.008081
# flair_processed_data_score                                                             -0.049125
# spacytextblob_processed_data_polarity_score                                             0.270231
# spacytextblob_processed_data_subjectivity_score                                         1.000000
# textblob_processed_data_polarity_score                                                  0.270231
# textblob_processed_data_subjectivity_score                                              1.000000
# vader_processed_data_score                                                              0.084913
# bert_processed_data_sentiment_score                                                    -0.029091
# roberta_processed_data_sentiment_score                                                 -0.068370
# close                                                                                  -0.043139
# close_t+1                                                                              -0.046669
# close_t+2                                                                              -0.048571
# close_t+3                                                                              -0.045208
# close_t+7                                                                              -0.042080
#
#                                                  textblob_processed_data_polarity_score  \
# date                                                                           0.059381
# flair_processed_data_score                                                     0.238421
# spacytextblob_processed_data_polarity_score                                    1.000000
# spacytextblob_processed_data_subjectivity_score                                0.270231
# textblob_processed_data_polarity_score                                         1.000000
# textblob_processed_data_subjectivity_score                                     0.270231
# vader_processed_data_score                                                     0.277869
# bert_processed_data_sentiment_score                                            0.285300
# roberta_processed_data_sentiment_score                                         0.237368
# close                                                                         -0.031785
# close_t+1                                                                     -0.032018
# close_t+2                                                                     -0.032383
# close_t+3                                                                     -0.031310
# close_t+7                                                                     -0.031560
#
#                                                  textblob_processed_data_subjectivity_score  \
# date                                                                              -0.008081
# flair_processed_data_score                                                        -0.049125
# spacytextblob_processed_data_polarity_score                                        0.270231
# spacytextblob_processed_data_subjectivity_score                                    1.000000
# textblob_processed_data_polarity_score                                             0.270231
# textblob_processed_data_subjectivity_score                                         1.000000
# vader_processed_data_score                                                         0.084913
# bert_processed_data_sentiment_score                                               -0.029091
# roberta_processed_data_sentiment_score                                            -0.068370
# close                                                                             -0.043139
# close_t+1                                                                         -0.046669
# close_t+2                                                                         -0.048571
# close_t+3                                                                         -0.045208
# close_t+7                                                                         -0.042080
#
#                                                  vader_processed_data_score  \
# date                                                              -0.164793
# flair_processed_data_score                                         0.387840
# spacytextblob_processed_data_polarity_score                        0.277869
# spacytextblob_processed_data_subjectivity_score                    0.084913
# textblob_processed_data_polarity_score                             0.277869
# textblob_processed_data_subjectivity_score                         0.084913
# vader_processed_data_score                                         1.000000
# bert_processed_data_sentiment_score                                0.383800
# roberta_processed_data_sentiment_score                             0.502562
# close                                                              0.087476
# close_t+1                                                          0.086496
# close_t+2                                                          0.086232
# close_t+3                                                          0.088150
# close_t+7                                                          0.082704
#
#                                                  bert_processed_data_sentiment_score  \
# date                                                                       -0.082823
# flair_processed_data_score                                                  0.695582
# spacytextblob_processed_data_polarity_score                                 0.285300
# spacytextblob_processed_data_subjectivity_score                            -0.029091
# textblob_processed_data_polarity_score                                      0.285300
# textblob_processed_data_subjectivity_score                                 -0.029091
# vader_processed_data_score                                                  0.383800
# bert_processed_data_sentiment_score                                         1.000000
# roberta_processed_data_sentiment_score                                      0.504446
# close                                                                       0.075763
# close_t+1                                                                   0.077628
# close_t+2                                                                   0.079430
# close_t+3                                                                   0.081025
# close_t+7                                                                   0.070066
#
#                                                  roberta_processed_data_sentiment_score  \
# date                                                                          -0.040871
# flair_processed_data_score                                                     0.381202
# spacytextblob_processed_data_polarity_score                                    0.237368
# spacytextblob_processed_data_subjectivity_score                               -0.068370
# textblob_processed_data_polarity_score                                         0.237368
# textblob_processed_data_subjectivity_score                                    -0.068370
# vader_processed_data_score                                                     0.502562
# bert_processed_data_sentiment_score                                            0.504446
# roberta_processed_data_sentiment_score                                         1.000000
# close                                                                          0.090698
# close_t+1                                                                      0.091107
# close_t+2                                                                      0.092230
# close_t+3                                                                      0.090555
# close_t+7                                                                      0.088732
#
#                                                     close  close_t+1  \
# date                                            -0.744912  -0.743156
# flair_processed_data_score                       0.085963   0.085366
# spacytextblob_processed_data_polarity_score     -0.031785  -0.032018
# spacytextblob_processed_data_subjectivity_score -0.043139  -0.046669
# textblob_processed_data_polarity_score          -0.031785  -0.032018
# textblob_processed_data_subjectivity_score      -0.043139  -0.046669
# vader_processed_data_score                       0.087476   0.086496
# bert_processed_data_sentiment_score              0.075763   0.077628
# roberta_processed_data_sentiment_score           0.090698   0.091107
# close                                            1.000000   0.999655
# close_t+1                                        0.999655   1.000000
# close_t+2                                        0.999371   0.999730
# close_t+3                                        0.999334   0.999566
# close_t+7                                        0.998375   0.998281
#
#                                                  close_t+2  close_t+3  \
# date                                             -0.744251  -0.742793
# flair_processed_data_score                        0.085682   0.087670
# spacytextblob_processed_data_polarity_score      -0.032383  -0.031310
# spacytextblob_processed_data_subjectivity_score  -0.048571  -0.045208
# textblob_processed_data_polarity_score           -0.032383  -0.031310
# textblob_processed_data_subjectivity_score       -0.048571  -0.045208
# vader_processed_data_score                        0.086232   0.088150
# bert_processed_data_sentiment_score               0.079430   0.081025
# roberta_processed_data_sentiment_score            0.092230   0.090555
# close                                             0.999371   0.999334
# close_t+1                                         0.999730   0.999566
# close_t+2                                         1.000000   0.999620
# close_t+3                                         0.999620   1.000000
# close_t+7                                         0.998258   0.998656
#
#                                                  close_t+7
# date                                             -0.739925
# flair_processed_data_score                        0.078318
# spacytextblob_processed_data_polarity_score      -0.031560
# spacytextblob_processed_data_subjectivity_score  -0.042080
# textblob_processed_data_polarity_score           -0.031560
# textblob_processed_data_subjectivity_score       -0.042080
# vader_processed_data_score                        0.082704
# bert_processed_data_sentiment_score               0.070066
# roberta_processed_data_sentiment_score            0.088732
# close                                             0.998375
# close_t+1                                         0.998281
# close_t+2                                         0.998258
# close_t+3                                         0.998656
# close_t+7                                         1.000000

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data
Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.061
# Skew:                           0.415   Prob(JB):                       0.0108
# Kurtosis:                       2.342   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.6224
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.712
# Time:                        18:17:32   Log-Likelihood:                -2115.4
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.688e+04   2453.885     15.031      0.000     3.2e+04    4.17e+04
# flair_processed_data_score                        723.2474   2432.591      0.297      0.767   -4075.601    5522.096
# spacytextblob_processed_data_polarity_score     -6127.9847   4410.073     -1.390      0.166   -1.48e+04    2571.904
# spacytextblob_processed_data_subjectivity_score -1083.5954   3182.952     -0.340      0.734   -7362.704    5195.514
# textblob_processed_data_polarity_score          -6127.9847   4410.073     -1.390      0.166   -1.48e+04    2571.904
# textblob_processed_data_subjectivity_score      -1083.5954   3182.952     -0.340      0.734   -7362.704    5195.514
# vader_processed_data_score                       3441.3064   5062.681      0.680      0.498   -6546.001    1.34e+04
# bert_processed_data_sentiment_score              1952.1514   4617.605      0.423      0.673   -7157.142    1.11e+04
# roberta_processed_data_sentiment_score            681.4302   4727.851      0.144      0.886   -8645.347       1e+04
# ==============================================================================
# Omnibus:                       12.370   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.002
# Skew:                           0.411   Prob(JB):                       0.0111
# Kurtosis:                       2.339   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.6281
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.708
# Time:                        18:17:32   Log-Likelihood:                -2115.1
# No. Observations:                 194   AIC:                             4244.
# Df Residuals:                     187   BIC:                             4267.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.679e+04   2450.231     15.015      0.000     3.2e+04    4.16e+04
# flair_processed_data_score                        681.8459   2428.969      0.281      0.779   -4109.857    5473.549
# spacytextblob_processed_data_polarity_score     -6144.1375   4403.507     -1.395      0.165   -1.48e+04    2542.797
# spacytextblob_processed_data_subjectivity_score -1078.6988   3178.213     -0.339      0.735   -7348.458    5191.061
# textblob_processed_data_polarity_score          -6144.1375   4403.507     -1.395      0.165   -1.48e+04    2542.797
# textblob_processed_data_subjectivity_score      -1078.6988   3178.213     -0.339      0.735   -7348.458    5191.061
# vader_processed_data_score                       3610.6593   5055.142      0.714      0.476   -6361.777    1.36e+04
# bert_processed_data_sentiment_score              1791.8315   4610.730      0.389      0.698   -7303.898    1.09e+04
# roberta_processed_data_sentiment_score            839.1825   4720.811      0.178      0.859   -8473.708    1.02e+04
# ==============================================================================
# Omnibus:                       12.314   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.939
# Skew:                           0.409   Prob(JB):                       0.0115
# Kurtosis:                       2.339   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.6015
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.729
# Time:                        18:17:32   Log-Likelihood:                -2115.3
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4267.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.679e+04   2452.068     15.002      0.000    3.19e+04    4.16e+04
# flair_processed_data_score                        649.6337   2430.790      0.267      0.790   -4145.661    5444.929
# spacytextblob_processed_data_polarity_score     -6011.7475   4406.808     -1.364      0.174   -1.47e+04    2681.699
# spacytextblob_processed_data_subjectivity_score -1104.4404   3180.596     -0.347      0.729   -7378.900    5170.019
# textblob_processed_data_polarity_score          -6011.7475   4406.808     -1.364      0.174   -1.47e+04    2681.699
# textblob_processed_data_subjectivity_score      -1104.4404   3180.596     -0.347      0.729   -7378.900    5170.019
# vader_processed_data_score                       3374.6031   5058.932      0.667      0.506   -6605.309    1.34e+04
# bert_processed_data_sentiment_score              1783.3012   4614.186      0.386      0.700   -7319.247    1.09e+04
# roberta_processed_data_sentiment_score            947.4567   4724.350      0.201      0.841   -8372.415    1.03e+04
# ==============================================================================
# Omnibus:                       12.111   Durbin-Watson:                   0.077
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.993
# Skew:                           0.415   Prob(JB):                       0.0111
# Kurtosis:                       2.350   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.6228
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.712
# Time:                        18:17:32   Log-Likelihood:                -2114.7
# No. Observations:                 194   AIC:                             4243.
# Df Residuals:                     187   BIC:                             4266.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.686e+04   2445.213     15.075      0.000     3.2e+04    4.17e+04
# flair_processed_data_score                        660.4793   2423.995      0.272      0.786   -4121.411    5442.369
# spacytextblob_processed_data_polarity_score     -6157.1465   4394.488     -1.401      0.163   -1.48e+04    2511.997
# spacytextblob_processed_data_subjectivity_score -1159.5949   3171.704     -0.366      0.715   -7416.514    5097.324
# textblob_processed_data_polarity_score          -6157.1465   4394.488     -1.401      0.163   -1.48e+04    2511.997
# textblob_processed_data_subjectivity_score      -1159.5949   3171.704     -0.366      0.715   -7416.514    5097.324
# vader_processed_data_score                       3517.8249   5044.790      0.697      0.486   -6434.188    1.35e+04
# bert_processed_data_sentiment_score              1863.5831   4601.287      0.405      0.686   -7213.518    1.09e+04
# roberta_processed_data_sentiment_score            680.1260   4711.143      0.144      0.885   -8613.692    9973.944
# ==============================================================================
# Omnibus:                       12.494   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.970
# Skew:                           0.408   Prob(JB):                       0.0113
# Kurtosis:                       2.333   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 3. 4H frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_4hr_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8902
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.503
# Time:                        18:17:32   Log-Likelihood:                -2147.5
# No. Observations:                 197   AIC:                             4309.
# Df Residuals:                     190   BIC:                             4332.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.728e+04   2372.513     15.713      0.000    3.26e+04     4.2e+04
# flair_processed_data_score                        782.9707   2422.239      0.323      0.747   -3994.964    5560.905
# spacytextblob_processed_data_polarity_score     -6729.2247   4281.904     -1.572      0.118   -1.52e+04    1716.952
# spacytextblob_processed_data_subjectivity_score -1458.3609   3103.255     -0.470      0.639   -7579.618    4662.896
# textblob_processed_data_polarity_score          -6729.2247   4281.904     -1.572      0.118   -1.52e+04    1716.952
# textblob_processed_data_subjectivity_score      -1458.3609   3103.255     -0.470      0.639   -7579.618    4662.896
# vader_processed_data_score                       3969.0328   5010.199      0.792      0.429   -5913.726    1.39e+04
# bert_processed_data_sentiment_score              2252.9407   4584.603      0.491      0.624   -6790.317    1.13e+04
# roberta_processed_data_sentiment_score            627.4837   4684.595      0.134      0.894   -8613.011    9867.979
# ==============================================================================
# Omnibus:                       12.016   Durbin-Watson:                   0.085
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.929
# Skew:                           0.409   Prob(JB):                       0.0115
# Kurtosis:                       2.354   Cond. No.                     3.89e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.86e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.8802
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.510
# Time:                        18:17:32   Log-Likelihood:                -2147.1
# No. Observations:                 197   AIC:                             4308.
# Df Residuals:                     190   BIC:                             4331.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.707e+04   2367.173     15.659      0.000    3.24e+04    4.17e+04
# flair_processed_data_score                        773.4426   2416.787      0.320      0.749   -3993.738    5540.624
# spacytextblob_processed_data_polarity_score     -6653.9968   4272.267     -1.557      0.121   -1.51e+04    1773.171
# spacytextblob_processed_data_subjectivity_score -1365.8301   3096.270     -0.441      0.660   -7473.310    4741.650
# textblob_processed_data_polarity_score          -6653.9968   4272.267     -1.557      0.121   -1.51e+04    1773.171
# textblob_processed_data_subjectivity_score      -1365.8301   3096.270     -0.441      0.660   -7473.310    4741.650
# vader_processed_data_score                       4020.7704   4998.923      0.804      0.422   -5839.746    1.39e+04
# bert_processed_data_sentiment_score              1949.2226   4574.284      0.426      0.670   -7073.682     1.1e+04
# roberta_processed_data_sentiment_score           1050.3444   4674.051      0.225      0.822   -8169.354    1.03e+04
# ==============================================================================
# Omnibus:                       11.911   Durbin-Watson:                   0.087
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                8.909
# Skew:                           0.410   Prob(JB):                       0.0116
# Kurtosis:                       2.358   Cond. No.                     3.89e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.86e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8873
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.505
# Time:                        18:17:32   Log-Likelihood:                -2146.9
# No. Observations:                 197   AIC:                             4308.
# Df Residuals:                     190   BIC:                             4331.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                             3.71e+04   2364.995     15.686      0.000    3.24e+04    4.18e+04
# flair_processed_data_score                        795.8657   2414.563      0.330      0.742   -3966.928    5558.659
# spacytextblob_processed_data_polarity_score     -6685.8022   4268.335     -1.566      0.119   -1.51e+04    1733.610
# spacytextblob_processed_data_subjectivity_score -1411.1870   3093.421     -0.456      0.649   -7513.046    4690.672
# textblob_processed_data_polarity_score          -6685.8022   4268.335     -1.566      0.119   -1.51e+04    1733.610
# textblob_processed_data_subjectivity_score      -1411.1870   3093.421     -0.456      0.649   -7513.046    4690.672
# vader_processed_data_score                       4210.0648   4994.322      0.843      0.400   -5641.376    1.41e+04
# bert_processed_data_sentiment_score              1970.7606   4570.074      0.431      0.667   -7043.840     1.1e+04
# roberta_processed_data_sentiment_score            728.9773   4669.749      0.156      0.876   -8482.235    9940.190
# ==============================================================================
# Omnibus:                       11.759   Durbin-Watson:                   0.084
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                8.910
# Skew:                           0.413   Prob(JB):                       0.0116
# Kurtosis:                       2.365   Cond. No.                     3.89e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.86e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.8725
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.516
# Time:                        18:17:32   Log-Likelihood:                -2146.5
# No. Observations:                 197   AIC:                             4307.
# Df Residuals:                     190   BIC:                             4330.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.709e+04   2359.946     15.716      0.000    3.24e+04    4.17e+04
# flair_processed_data_score                        763.8984   2409.408      0.317      0.752   -3988.727    5516.524
# spacytextblob_processed_data_polarity_score     -6190.6545   4259.223     -1.453      0.148   -1.46e+04    2210.783
# spacytextblob_processed_data_subjectivity_score -1685.6887   3086.816     -0.546      0.586   -7774.521    4403.144
# textblob_processed_data_polarity_score          -6190.6545   4259.223     -1.453      0.148   -1.46e+04    2210.783
# textblob_processed_data_subjectivity_score      -1685.6887   3086.816     -0.546      0.586   -7774.521    4403.144
# vader_processed_data_score                       4439.4205   4983.660      0.891      0.374   -5390.989    1.43e+04
# bert_processed_data_sentiment_score              1866.2222   4560.318      0.409      0.683   -7129.133    1.09e+04
# roberta_processed_data_sentiment_score            701.0717   4659.780      0.150      0.881   -8490.476    9892.619
# ==============================================================================
# Omnibus:                       12.688   Durbin-Watson:                   0.081
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.874
# Skew:                           0.395   Prob(JB):                       0.0118
# Kurtosis:                       2.325   Cond. No.                     3.89e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.86e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.8746
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.515
# Time:                        18:17:32   Log-Likelihood:                -2146.6
# No. Observations:                 197   AIC:                             4307.
# Df Residuals:                     190   BIC:                             4330.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3
Durbin-Watson:                   0.077
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.080
# Skew:                           0.409   Prob(JB):                       0.0107
# Kurtosis:                       2.326   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.6110
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.721
# Time:                        18:17:32   Log-Likelihood:                -2114.7
# No. Observations:                 194   AIC:                             4243.
# Df Residuals:                     187   BIC:                             4266.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.684e+04   2444.440     15.071      0.000     3.2e+04    4.17e+04
# flair_processed_data_score                        670.2162   2423.228      0.277      0.782   -4110.161    5450.594
# spacytextblob_processed_data_polarity_score     -5570.7132   4393.099     -1.268      0.206   -1.42e+04    3095.689
# spacytextblob_processed_data_subjectivity_score -1481.1546   3170.701     -0.467      0.641   -7736.095    4773.786
# textblob_processed_data_polarity_score          -5570.7132   4393.099     -1.268      0.206   -1.42e+04    3095.689
# textblob_processed_data_subjectivity_score      -1481.1546   3170.701     -0.467      0.641   -7736.095    4773.786
# vader_processed_data_score                       3890.9741   5043.194      0.772      0.441   -6057.892    1.38e+04
# bert_processed_data_sentiment_score              1673.7169   4599.832      0.364      0.716   -7400.514    1.07e+04
# roberta_processed_data_sentiment_score            616.7369   4709.653      0.131      0.896   -8674.142    9907.615
# ==============================================================================
# Omnibus:                       13.006   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.995
# Skew:                           0.401   Prob(JB):                       0.0111
# Kurtosis:                       2.314   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.6392
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.699
# Time:                        18:17:32   Log-Likelihood:                -2115.0
# No. Observations:                 194   AIC:                             4244.
# Df Residuals:                     187   BIC:                             4267.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.702e+04   2448.140     15.123      0.000    3.22e+04    4.19e+04
# flair_processed_data_score                        792.8883   2426.896      0.327      0.744   -3994.725    5580.502
# spacytextblob_processed_data_polarity_score     -5666.5690   4399.748     -1.288      0.199   -1.43e+04    3012.951
# spacytextblob_processed_data_subjectivity_score -1587.2558   3175.501     -0.500      0.618   -7851.664    4677.153
# textblob_processed_data_polarity_score          -5666.5690   4399.748     -1.288      0.199   -1.43e+04    3012.951
# textblob_processed_data_subjectivity_score      -1587.2558   3175.501     -0.500      0.618   -7851.664    4677.153
# vader_processed_data_score                       3590.7751   5050.828      0.711      0.478   -6373.150    1.36e+04
# bert_processed_data_sentiment_score              1688.5997   4606.794      0.367      0.714   -7399.367    1.08e+04
# roberta_processed_data_sentiment_score            792.4339   4716.782      0.168      0.867   -8512.508    1.01e+04
# ==============================================================================
# Omnibus:                       14.305   Durbin-Watson:                   0.073
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                9.084
# Skew:                           0.386   Prob(JB):                       0.0107
# Kurtosis:                       2.274   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.6003
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.730
# Time:                        18:17:32   Log-Likelihood:                -2116.3
# No. Observations:                 194   AIC:                             4247.
# Df Residuals:                     187   BIC:                             4269.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                             3.68e+04   2464.783     14.932      0.000    3.19e+04    4.17e+04
# flair_processed_data_score                        489.1012   2443.394      0.200      0.842   -4331.058    5309.261
# spacytextblob_processed_data_polarity_score     -5587.1964   4429.658     -1.261      0.209   -1.43e+04    3151.327
# spacytextblob_processed_data_subjectivity_score -1519.7001   3197.087     -0.475      0.635   -7826.694    4787.293
# textblob_processed_data_polarity_score          -5587.1964   4429.658     -1.261      0.209   -1.43e+04    3151.327
# textblob_processed_data_subjectivity_score      -1519.7001   3197.087     -0.475      0.635   -7826.694    4787.293
# vader_processed_data_score                       3571.6707   5085.163      0.702      0.483   -6459.989    1.36e+04
# bert_processed_data_sentiment_score              1353.7743   4638.111      0.292      0.771   -7795.971    1.05e+04
# roberta_processed_data_sentiment_score           1562.5208   4748.846      0.329      0.742   -7805.675    1.09e+04
# ==============================================================================
# Omnibus:                       14.604   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.728
# Skew:                           0.362   Prob(JB):                       0.0127
# Kurtosis:                       2.256   Cond. No.                     2.11e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.21e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 5. 1D Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1d_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5713
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.753
# Time:                        18:17:32   Log-Likelihood:                -2139.8
# No. Observations:                 196   AIC:                             4294.
# Df Residuals:                     189   BIC:                             4317.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                             3.72e+04   2481.059     14.994      0.000    3.23e+04    4.21e+04
# flair_processed_data_score                       1237.4207   2454.114      0.504      0.615   -3603.553    6078.394
# spacytextblob_processed_data_polarity_score     -5833.3362   4465.444     -1.306      0.193   -1.46e+04    2975.176
# spacytextblob_processed_data_subjectivity_score -1099.4301   3217.873     -0.342      0.733   -7446.990    5248.130
# textblob_processed_data_polarity_score          -5833.3362   4465.444     -1.306      0.193   -1.46e+04    2975.176
# textblob_processed_data_subjectivity_score      -1099.4301   3217.873     -0.342      0.733   -7446.990    5248.130
# vader_processed_data_score                       2030.9576   5076.195      0.400      0.690   -7982.320     1.2e+04
# bert_processed_data_sentiment_score              1369.0108   4669.538      0.293      0.770   -7842.097    1.06e+04
# roberta_processed_data_sentiment_score           1280.5168   4774.308      0.268      0.789   -8137.260    1.07e+04
# ==============================================================================
# Omnibus:                       12.944   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.593
# Skew:                           0.430   Prob(JB):                      0.00826
# Kurtosis:                       2.340   Cond. No.                     1.66e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.01e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5606
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.761
# Time:                        18:17:32   Log-Likelihood:                -2139.4
# No. Observations:                 196   AIC:                             4293.
# Df Residuals:                     189   BIC:                             4316.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.712e+04   2475.990     14.994      0.000    3.22e+04     4.2e+04
# flair_processed_data_score                       1252.9083   2449.100      0.512      0.610   -3578.175    6083.992
# spacytextblob_processed_data_polarity_score     -4970.0829   4456.321     -1.115      0.266   -1.38e+04    3820.434
# spacytextblob_processed_data_subjectivity_score -1526.4806   3211.299     -0.475      0.635   -7861.073    4808.112
# textblob_processed_data_polarity_score          -4970.0829   4456.321     -1.115      0.266   -1.38e+04    3820.434
# textblob_processed_data_subjectivity_score      -1526.4806   3211.299     -0.475      0.635   -7861.073    4808.112
# vader_processed_data_score                       2340.2963   5065.824      0.462      0.645   -7652.524    1.23e+04
# bert_processed_data_sentiment_score               809.8353   4659.998      0.174      0.862   -8382.454       1e+04
# roberta_processed_data_sentiment_score           1795.7239   4764.555      0.377      0.707   -7602.813    1.12e+04
# ==============================================================================
# Omnibus:                       14.805   Durbin-Watson:                   0.069
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                9.469
# Skew:                           0.397   Prob(JB):                      0.00879
# Kurtosis:                       2.272   Cond. No.                     1.66e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.01e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5428
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.775
# Time:                        18:17:32   Log-Likelihood:                -2141.5
# No. Observations:                 196   AIC:                             4297.
# Df Residuals:                     189   BIC:                             4320.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.715e+04   2502.439     14.846      0.000    3.22e+04    4.21e+04
# flair_processed_data_score                       1254.1932   2475.262      0.507      0.613   -3628.495    6136.882
# spacytextblob_processed_data_polarity_score     -5135.3937   4503.923     -1.140      0.256    -1.4e+04    3749.023
# spacytextblob_processed_data_subjectivity_score -1451.8535   3245.602     -0.447      0.655   -7854.112    4950.405
# textblob_processed_data_polarity_score          -5135.3937   4503.923     -1.140      0.256    -1.4e+04    3749.023
# textblob_processed_data_subjectivity_score      -1451.8535   3245.602     -0.447      0.655   -7854.112    4950.405
# vader_processed_data_score                       2091.8588   5119.937      0.409      0.683   -8007.704    1.22e+04
# bert_processed_data_sentiment_score               303.6756   4709.776      0.064      0.949   -8986.805    9594.156
# roberta_processed_data_sentiment_score           2350.8496   4815.449      0.488      0.626   -7148.082    1.18e+04
# ==============================================================================
# Omnibus:                       14.501   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                9.381
# Skew:                           0.396   Prob(JB):                      0.00918
# Kurtosis:                       2.279   Cond. No.                     1.66e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.01e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.6160
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.717
# Time:                        18:17:32   Log-Likelihood:                -2143.4
# No. Observations:                 196   AIC:                             4301.
# Df Residuals:                     189   BIC:                             4324.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.778e+04   2526.845     14.952      0.000    3.28e+04    4.28e+04
# flair_processed_data_score                       1794.8792   2499.402      0.718      0.474   -3135.430    6725.188
# spacytextblob_processed_data_polarity_score     -5698.9280   4547.849     -1.253      0.212   -1.47e+04    3272.137
# spacytextblob_processed_data_subjectivity_score -1629.4412   3277.256     -0.497      0.620   -8094.140    4835.257
# textblob_processed_data_polarity_score          -5698.9280   4547.849     -1.253      0.212   -1.47e+04    3272.137
# textblob_processed_data_subjectivity_score      -1629.4412   3277.256     -0.497      0.620   -8094.140    4835.257
# vader_processed_data_score                       1857.1461   5169.871      0.359      0.720   -8340.917    1.21e+04
# bert_processed_data_sentiment_score               234.0809   4755.710      0.049      0.961   -9147.009    9615.171
# roberta_processed_data_sentiment_score           1622.0347   4862.414      0.334      0.739   -7969.539    1.12e+04
# ==============================================================================
# Omnibus:                       13.331   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                9.455
# Skew:                           0.417   Prob(JB):                      0.00885
# Kurtosis:                       2.320   Cond. No.                     1.66e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.01e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5742
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):              0.751
# Time:                        18:17:32   Log-Likelihood:                -2142.8
# No. Observations:                 196   AIC:                             4300.
# Df Residuals:                     189   BIC:                             4322.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.756e+04   2518.695     14.914      0.000    3.26e+04    4.25e+04
# flair_processed_data_score                       1044.7442   2491.342      0.419      0.675   -3869.664    5959.152
# spacytextblob_processed_data_polarity_score     -6009.4182   4533.182     -1.326      0.187    -1.5e+04    2932.714
# spacytextblob_processed_data_subjectivity_score -1157.4735   3266.686     -0.354      0.723   -7601.323    5286.376
# textblob_processed_data_polarity_score          -6009.4182   4533.182     -1.326      0.187    -1.5e+04    2932.714
# textblob_processed_data_subjectivity_score      -1157.4735   3266.686     -0.354      0.723   -7601.323    5286.376
# vader_processed_data_score                       2585.0442   5153.198      0.502      0.617   -7580.129    1.28e+04
# bert_processed_data_sentiment_score              1090.1009   4740.372      0.230      0.818   -8260.734    1.04e+04
# roberta_processed_data_sentiment_score           1611.9640   4846.732      0.333      0.740   -7948.675    1.12e+04
# ==============================================================================
# Omnibus:                       20.937   Durbin-Watson:                   0.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.734
# Skew:                           0.341   Prob(JB):                      0.00770
# Kurtosis:                       2.148   Cond. No.                     1.66e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.01e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
