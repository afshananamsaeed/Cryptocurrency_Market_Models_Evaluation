# %%
import pandas as pd
import numpy as np
import os
import datetime
os.chdir('/home/ubuntu/Masters Thesis/')
from scripts.utilities.data_joining import GetModellingData

# %% [markdown]
# Data without Bots and De-emoji text processing

# %%
bitcoin_hourly = pd.read_csv("/mnt/bitcoin_hourly_prices_till_2023-03-30.csv", lineterminator='\n')
bitcoin_minutely = pd.read_csv("/mnt/bitcoin_price_minutely_data_till_2023_03_30.csv", lineterminator='\n')

# %%
bitcoin_minutely
# Out:
#                time exchange fsym tsym     close      high       low  \
# 0        1606780800   CCCAGG  BTC  USD  19704.72  19714.44  19686.87
# 1        1606780860   CCCAGG  BTC  USD  19682.63  19706.49  19674.34
# 2        1606780920   CCCAGG  BTC  USD  19688.59  19691.33  19654.82
# 3        1606780980   CCCAGG  BTC  USD  19664.79  19697.12  19659.91
# 4        1606781040   CCCAGG  BTC  USD  19628.40  19665.60  19623.03
# ...             ...      ...  ...  ...       ...       ...       ...
# 1223995  1680220500   CCCAGG  BTC  USD  28038.57  28044.74  28032.44
# 1223996  1680220560   CCCAGG  BTC  USD  28037.36  28043.24  28031.83
# 1223997  1680220620   CCCAGG  BTC  USD  28031.20  28039.71  28030.25
# 1223998  1680220680   CCCAGG  BTC  USD  28037.81  28038.74  28029.52
# 1223999  1680220740   CCCAGG  BTC  USD  28040.71  28052.54  28036.36
#
#              open  volumefrom    volumeto
# 0        19686.87      58.620  1151502.04
# 1        19704.72     132.800  2614001.65
# 2        19682.63      55.390  1090096.41
# 3        19688.59      51.070  1004714.46
# 4        19664.79     109.540  2149088.17
# ...           ...         ...         ...
# 1223995  28032.49      11.500   322442.59
# 1223996  28038.57      20.120   564252.17
# 1223997  28037.36      12.290   344664.77
# 1223998  28031.20       8.527   239073.67
# 1223999  28037.81      75.070  2105709.79
#
# [1224000 rows x 10 columns]

# %%
data_30min = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_False_interval_30T.csv", lineterminator='\n')
data_1hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_False_interval_1H.csv", lineterminator='\n')
data_4hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_False_interval_4H.csv", lineterminator='\n')
data_6hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_False_interval_6H.csv", lineterminator='\n')
data_1day = pd.read_csv("/home/ubuntu/Masters Thesis/data/influencer_data/weighted_scores_influencer_processed_False_interval_D.csv", lineterminator='\n')

# %%
data_30min = data_30min[~data_30min['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_1hrs = data_1hrs[~data_1hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_4hrs = data_4hrs[~data_4hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_6hrs = data_6hrs[~data_6hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_1day = data_1day[~data_1day['spacytextblob_nonprocessed_data_polarity_score'].isna()]

data_30min = data_30min.drop(columns=['Unnamed: 0'])
data_1hrs = data_1hrs.drop(columns=['Unnamed: 0'])
data_4hrs = data_4hrs.drop(columns=['Unnamed: 0'])
data_6hrs = data_6hrs.drop(columns=['Unnamed: 0'])
data_1day = data_1day.drop(columns=['Unnamed: 0'])

# %%
bitcoin_minutely = bitcoin_minutely.rename(columns={'time': 'date'})
bitcoin_minutely['date'] = bitcoin_minutely['date'].apply(datetime.datetime.utcfromtimestamp)
bitcoin_hourly = bitcoin_hourly.rename(columns={'datetimes': 'date'})
bitcoin_hourly['date'] = pd.to_datetime(bitcoin_hourly['date'])

# %%
data_30min_joined = GetModellingData(data=data_30min, bitcoin_data=bitcoin_minutely, frequency='30T').get_data_for_feature_analysis()
data_1hr_joined = GetModellingData(data=data_1hrs, bitcoin_data=bitcoin_hourly, frequency='1H').get_data_for_feature_analysis()
data_4hr_joined = GetModellingData(data=data_4hrs, bitcoin_data=bitcoin_hourly, frequency='4H').get_data_for_feature_analysis()
data_6hr_joined = GetModellingData(data=data_6hrs, bitcoin_data=bitcoin_hourly, frequency='6H').get_data_for_feature_analysis()
data_1d_joined = GetModellingData(data=data_1day, bitcoin_data=bitcoin_hourly, frequency='1D').get_data_for_feature_analysis()
# Out:
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])

# %%
data_30min_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_30min_joined.dropna(inplace=True)
data_1hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1hr_joined.dropna(inplace=True)
data_4hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_4hr_joined.dropna(inplace=True)
data_6hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_6hr_joined.dropna(inplace=True)
data_1d_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1d_joined.dropna(inplace=True)

# %% [markdown]
# ### Plots and Analysis

# %% [markdown]
# 1. 30T Frequency

# %%
# correlation analysis - pearson
data_30min_joined.corr()
# Out:
#                                                         date  \
# date                                                1.000000
# flair_nonprocessed_data_score                       0.034831
# spacytextblob_nonprocessed_data_polarity_score      0.130229
# spacytextblob_nonprocessed_data_subjectivity_score -0.042654
# textblob_nonprocessed_data_polarity_score           0.130229
# textblob_nonprocessed_data_subjectivity_score      -0.042654
# vader_nonprocessed_data_score                      -0.058654
# bert_nonprocessed_data_sentiment_score             -0.025151
# roberta_nonprocessed_data_sentiment_score           0.028074
# close                                              -0.707940
# close_t+1                                          -0.707245
# close_t+2                                          -0.708373
# close_t+3                                          -0.708360
# close_t+7                                          -0.707012
#
#                                                     flair_nonprocessed_data_score  \
# date                                                                     0.034831
# flair_nonprocessed_data_score                                            1.000000
# spacytextblob_nonprocessed_data_polarity_score                           0.252031
# spacytextblob_nonprocessed_data_subjectivity_score                      -0.060426
# textblob_nonprocessed_data_polarity_score                                0.252031
# textblob_nonprocessed_data_subjectivity_score                           -0.060426
# vader_nonprocessed_data_score                                            0.362489
# bert_nonprocessed_data_sentiment_score                                   0.655395
# roberta_nonprocessed_data_sentiment_score                                0.470309
# close                                                                    0.028032
# close_t+1                                                                0.028318
# close_t+2                                                                0.031622
# close_t+3                                                                0.031985
# close_t+7                                                                0.027574
#
#                                                     spacytextblob_nonprocessed_data_polarity_score  \
# date                                                                                      0.130229
# flair_nonprocessed_data_score                                                             0.252031
# spacytextblob_nonprocessed_data_polarity_score                                            1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                        0.222824
# textblob_nonprocessed_data_polarity_score                                                 1.000000
# textblob_nonprocessed_data_subjectivity_score                                             0.222824
# vader_nonprocessed_data_score                                                             0.311875
# bert_nonprocessed_data_sentiment_score                                                    0.303675
# roberta_nonprocessed_data_sentiment_score                                                 0.306646
# close                                                                                    -0.074956
# close_t+1                                                                                -0.075003
# close_t+2                                                                                -0.074477
# close_t+3                                                                                -0.074658
# close_t+7                                                                                -0.073988
#
#                                                     spacytextblob_nonprocessed_data_subjectivity_score  \
# date                                                                                        -0.042654
# flair_nonprocessed_data_score                                                               -0.060426
# spacytextblob_nonprocessed_data_polarity_score                                               0.222824
# spacytextblob_nonprocessed_data_subjectivity_score                                           1.000000
# textblob_nonprocessed_data_polarity_score                                                    0.222824
# textblob_nonprocessed_data_subjectivity_score                                                1.000000
# vader_nonprocessed_data_score                                                                0.117705
# bert_nonprocessed_data_sentiment_score                                                      -0.009303
# roberta_nonprocessed_data_sentiment_score                                                   -0.065890
# close                                                                                       -0.034647
# close_t+1                                                                                   -0.037003
# close_t+2                                                                                   -0.039235
# close_t+3                                                                                   -0.038089
# close_t+7                                                                                   -0.036543
#
#                                                     textblob_nonprocessed_data_polarity_score  \
# date                                                                                 0.130229
# flair_nonprocessed_data_score                                                        0.252031
# spacytextblob_nonprocessed_data_polarity_score                                       1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.222824
# textblob_nonprocessed_data_polarity_score                                            1.000000
# textblob_nonprocessed_data_subjectivity_score                                        0.222824
# vader_nonprocessed_data_score                                                        0.311875
# bert_nonprocessed_data_sentiment_score                                               0.303675
# roberta_nonprocessed_data_sentiment_score                                            0.306646
# close                                                                               -0.074956
# close_t+1                                                                           -0.075003
# close_t+2                                                                           -0.074477
# close_t+3                                                                           -0.074658
# close_t+7                                                                           -0.073988
#
#                                                     textblob_nonprocessed_data_subjectivity_score  \
# date                                                                                    -0.042654
# flair_nonprocessed_data_score                                                           -0.060426
# spacytextblob_nonprocessed_data_polarity_score                                           0.222824
# spacytextblob_nonprocessed_data_subjectivity_score                                       1.000000
# textblob_nonprocessed_data_polarity_score                                                0.222824
# textblob_nonprocessed_data_subjectivity_score                                            1.000000
# vader_nonprocessed_data_score                                                            0.117705
# bert_nonprocessed_data_sentiment_score                                                  -0.009303
# roberta_nonprocessed_data_sentiment_score                                               -0.065890
# close                                                                                   -0.034647
# close_t+1                                                                               -0.037003
# close_t+2                                                                               -0.039235
# close_t+3                                                                               -0.038089
# close_t+7                                                                               -0.036543
#
#                                                     vader_nonprocessed_data_score  \
# date                                                                    -0.058654
# flair_nonprocessed_data_score                                            0.362489
# spacytextblob_nonprocessed_data_polarity_score                           0.311875
# spacytextblob_nonprocessed_data_subjectivity_score                       0.117705
# textblob_nonprocessed_data_polarity_score                                0.311875
# textblob_nonprocessed_data_subjectivity_score                            0.117705
# vader_nonprocessed_data_score                                            1.000000
# bert_nonprocessed_data_sentiment_score                                   0.380811
# roberta_nonprocessed_data_sentiment_score                                0.598776
# close                                                                    0.068682
# close_t+1                                                                0.067710
# close_t+2                                                                0.068739
# close_t+3                                                                0.070925
# close_t+7                                                                0.070201
#
#                                                     bert_nonprocessed_data_sentiment_score  \
# date                                                                             -0.025151
# flair_nonprocessed_data_score                                                     0.655395
# spacytextblob_nonprocessed_data_polarity_score                                    0.303675
# spacytextblob_nonprocessed_data_subjectivity_score                               -0.009303
# textblob_nonprocessed_data_polarity_score                                         0.303675
# textblob_nonprocessed_data_subjectivity_score                                    -0.009303
# vader_nonprocessed_data_score                                                     0.380811
# bert_nonprocessed_data_sentiment_score                                            1.000000
# roberta_nonprocessed_data_sentiment_score                                         0.519359
# close                                                                             0.048950
# close_t+1                                                                         0.048369
# close_t+2                                                                         0.051243
# close_t+3                                                                         0.051591
# close_t+7                                                                         0.048125
#
#                                                     roberta_nonprocessed_data_sentiment_score  \
# date                                                                                 0.028074
# flair_nonprocessed_data_score                                                        0.470309
# spacytextblob_nonprocessed_data_polarity_score                                       0.306646
# spacytextblob_nonprocessed_data_subjectivity_score                                  -0.065890
# textblob_nonprocessed_data_polarity_score                                            0.306646
# textblob_nonprocessed_data_subjectivity_score                                       -0.065890
# vader_nonprocessed_data_score                                                        0.598776
# bert_nonprocessed_data_sentiment_score                                               0.519359
# roberta_nonprocessed_data_sentiment_score                                            1.000000
# close                                                                                0.054942
# close_t+1                                                                            0.054342
# close_t+2                                                                            0.055200
# close_t+3                                                                            0.057162
# close_t+7                                                                            0.057432
#
#                                                        close  close_t+1  \
# date                                               -0.707940  -0.707245
# flair_nonprocessed_data_score                       0.028032   0.028318
# spacytextblob_nonprocessed_data_polarity_score     -0.074956  -0.075003
# spacytextblob_nonprocessed_data_subjectivity_score -0.034647  -0.037003
# textblob_nonprocessed_data_polarity_score          -0.074956  -0.075003
# textblob_nonprocessed_data_subjectivity_score      -0.034647  -0.037003
# vader_nonprocessed_data_score                       0.068682   0.067710
# bert_nonprocessed_data_sentiment_score              0.048950   0.048369
# roberta_nonprocessed_data_sentiment_score           0.054942   0.054342
# close                                               1.000000   0.999873
# close_t+1                                           0.999873   1.000000
# close_t+2                                           0.999701   0.999839
# close_t+3                                           0.999581   0.999687
# close_t+7                                           0.999171   0.999236
#
#                                                     close_t+2  close_t+3  \
# date                                                -0.708373  -0.708360
# flair_nonprocessed_data_score                        0.031622   0.031985
# spacytextblob_nonprocessed_data_polarity_score      -0.074477  -0.074658
# spacytextblob_nonprocessed_data_subjectivity_score  -0.039235  -0.038089
# textblob_nonprocessed_data_polarity_score           -0.074477  -0.074658
# textblob_nonprocessed_data_subjectivity_score       -0.039235  -0.038089
# vader_nonprocessed_data_score                        0.068739   0.070925
# bert_nonprocessed_data_sentiment_score               0.051243   0.051591
# roberta_nonprocessed_data_sentiment_score            0.055200   0.057162
# close                                                0.999701   0.999581
# close_t+1                                            0.999839   0.999687
# close_t+2                                            1.000000   0.999883
# close_t+3                                            0.999883   1.000000
# close_t+7                                            0.999382   0.999570
#
#                                                     close_t+7
# date                                                -0.707012
# flair_nonprocessed_data_score                        0.027574
# spacytextblob_nonprocessed_data_polarity_score      -0.073988
# spacytextblob_nonprocessed_data_subjectivity_score  -0.036543
# textblob_nonprocessed_data_polarity_score           -0.073988
# textblob_nonprocessed_data_subjectivity_score       -0.036543
# vader_nonprocessed_data_score                        0.070201
# bert_nonprocessed_data_sentiment_score               0.048125
# roberta_nonprocessed_data_sentiment_score            0.057432
# close                                                0.999171
# close_t+1                                            0.999236
# close_t+2                                            0.999382
# close_t+3                                            0.999570
# close_t+7                                            1.000000

# %% [markdown]
# Very bad correlation between all the weighted sentiment features and the closing dates

# %%
# correlation analysis - spearman
data_30min_joined.corr(method='spearman')
# Out:
#                                                         date  \
# date                                                1.000000
# flair_nonprocessed_data_score                       0.034516
# spacytextblob_nonprocessed_data_polarity_score      0.061433
# spacytextblob_nonprocessed_data_subjectivity_score -0.021516
# textblob_nonprocessed_data_polarity_score           0.061433
# textblob_nonprocessed_data_subjectivity_score      -0.021516
# vader_nonprocessed_data_score                      -0.152522
# bert_nonprocessed_data_sentiment_score             -0.059963
# roberta_nonprocessed_data_sentiment_score          -0.045689
# close                                              -0.744912
# close_t+1                                          -0.743156
# close_t+2                                          -0.744251
# close_t+3                                          -0.742793
# close_t+7                                          -0.739925
#
#                                                     flair_nonprocessed_data_score  \
# date                                                                     0.034516
# flair_nonprocessed_data_score                                            1.000000
# spacytextblob_nonprocessed_data_polarity_score                           0.249920
# spacytextblob_nonprocessed_data_subjectivity_score                      -0.026622
# textblob_nonprocessed_data_polarity_score                                0.249920
# textblob_nonprocessed_data_subjectivity_score                           -0.026622
# vader_nonprocessed_data_score                                            0.339689
# bert_nonprocessed_data_sentiment_score                                   0.659497
# roberta_nonprocessed_data_sentiment_score                                0.472298
# close                                                                    0.011435
# close_t+1                                                                0.013705
# close_t+2                                                                0.015194
# close_t+3                                                                0.017107
# close_t+7                                                                0.008289
#
#                                                     spacytextblob_nonprocessed_data_polarity_score  \
# date                                                                                      0.061433
# flair_nonprocessed_data_score                                                             0.249920
# spacytextblob_nonprocessed_data_polarity_score                                            1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                        0.243083
# textblob_nonprocessed_data_polarity_score                                                 1.000000
# textblob_nonprocessed_data_subjectivity_score                                             0.243083
# vader_nonprocessed_data_score                                                             0.289524
# bert_nonprocessed_data_sentiment_score                                                    0.279334
# roberta_nonprocessed_data_sentiment_score                                                 0.258083
# close                                                                                    -0.034189
# close_t+1                                                                                -0.034447
# close_t+2                                                                                -0.035113
# close_t+3                                                                                -0.034304
# close_t+7                                                                                -0.033792
#
#                                                     spacytextblob_nonprocessed_data_subjectivity_score  \
# date                                                                                        -0.021516
# flair_nonprocessed_data_score                                                               -0.026622
# spacytextblob_nonprocessed_data_polarity_score                                               0.243083
# spacytextblob_nonprocessed_data_subjectivity_score                                           1.000000
# textblob_nonprocessed_data_polarity_score                                                    0.243083
# textblob_nonprocessed_data_subjectivity_score                                                1.000000
# vader_nonprocessed_data_score                                                                0.106006
# bert_nonprocessed_data_sentiment_score                                                       0.023236
# roberta_nonprocessed_data_sentiment_score                                                   -0.010180
# close                                                                                       -0.021955
# close_t+1                                                                                   -0.025901
# close_t+2                                                                                   -0.027891
# close_t+3                                                                                   -0.024532
# close_t+7                                                                                   -0.021804
#
#                                                     textblob_nonprocessed_data_polarity_score  \
# date                                                                                 0.061433
# flair_nonprocessed_data_score                                                        0.249920
# spacytextblob_nonprocessed_data_polarity_score                                       1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.243083
# textblob_nonprocessed_data_polarity_score                                            1.000000
# textblob_nonprocessed_data_subjectivity_score                                        0.243083
# vader_nonprocessed_data_score                                                        0.289524
# bert_nonprocessed_data_sentiment_score                                               0.279334
# roberta_nonprocessed_data_sentiment_score                                            0.258083
# close                                                                               -0.034189
# close_t+1                                                                           -0.034447
# close_t+2                                                                           -0.035113
# close_t+3                                                                           -0.034304
# close_t+7                                                                           -0.033792
#
#                                                     textblob_nonprocessed_data_subjectivity_score  \
# date                                                                                    -0.021516
# flair_nonprocessed_data_score                                                           -0.026622
# spacytextblob_nonprocessed_data_polarity_score                                           0.243083
# spacytextblob_nonprocessed_data_subjectivity_score                                       1.000000
# textblob_nonprocessed_data_polarity_score                                                0.243083
# textblob_nonprocessed_data_subjectivity_score                                            1.000000
# vader_nonprocessed_data_score                                                            0.106006
# bert_nonprocessed_data_sentiment_score                                                   0.023236
# roberta_nonprocessed_data_sentiment_score                                               -0.010180
# close                                                                                   -0.021955
# close_t+1                                                                               -0.025901
# close_t+2                                                                               -0.027891
# close_t+3                                                                               -0.024532
# close_t+7                                                                               -0.021804
#
#                                                     vader_nonprocessed_data_score  \
# date                                                                    -0.152522
# flair_nonprocessed_data_score                                            0.339689
# spacytextblob_nonprocessed_data_polarity_score                           0.289524
# spacytextblob_nonprocessed_data_subjectivity_score                       0.106006
# textblob_nonprocessed_data_polarity_score                                0.289524
# textblob_nonprocessed_data_subjectivity_score                            0.106006
# vader_nonprocessed_data_score                                            1.000000
# bert_nonprocessed_data_sentiment_score                                   0.400137
# roberta_nonprocessed_data_sentiment_score                                0.555521
# close                                                                    0.111768
# close_t+1                                                                0.111289
# close_t+2                                                                0.111231
# close_t+3                                                                0.113378
# close_t+7                                                                0.107361
#
#                                                     bert_nonprocessed_data_sentiment_score  \
# date                                                                             -0.059963
# flair_nonprocessed_data_score                                                     0.659497
# spacytextblob_nonprocessed_data_polarity_score                                    0.279334
# spacytextblob_nonprocessed_data_subjectivity_score                                0.023236
# textblob_nonprocessed_data_polarity_score                                         0.279334
# textblob_nonprocessed_data_subjectivity_score                                     0.023236
# vader_nonprocessed_data_score                                                     0.400137
# bert_nonprocessed_data_sentiment_score                                            1.000000
# roberta_nonprocessed_data_sentiment_score                                         0.489526
# close                                                                             0.066698
# close_t+1                                                                         0.068572
# close_t+2                                                                         0.070157
# close_t+3                                                                         0.070733
# close_t+7                                                                         0.063898
#
#                                                     roberta_nonprocessed_data_sentiment_score  \
# date                                                                                -0.045689
# flair_nonprocessed_data_score                                                        0.472298
# spacytextblob_nonprocessed_data_polarity_score                                       0.258083
# spacytextblob_nonprocessed_data_subjectivity_score                                  -0.010180
# textblob_nonprocessed_data_polarity_score                                            0.258083
# textblob_nonprocessed_data_subjectivity_score                                       -0.010180
# vader_nonprocessed_data_score                                                        0.555521
# bert_nonprocessed_data_sentiment_score                                               0.489526
# roberta_nonprocessed_data_sentiment_score                                            1.000000
# close                                                                                0.091722
# close_t+1                                                                            0.090768
# close_t+2                                                                            0.091242
# close_t+3                                                                            0.091937
# close_t+7                                                                            0.090333
#
#                                                        close  close_t+1  \
# date                                               -0.744912  -0.743156
# flair_nonprocessed_data_score                       0.011435   0.013705
# spacytextblob_nonprocessed_data_polarity_score     -0.034189  -0.034447
# spacytextblob_nonprocessed_data_subjectivity_score -0.021955  -0.025901
# textblob_nonprocessed_data_polarity_score          -0.034189  -0.034447
# textblob_nonprocessed_data_subjectivity_score      -0.021955  -0.025901
# vader_nonprocessed_data_score                       0.111768   0.111289
# bert_nonprocessed_data_sentiment_score              0.066698   0.068572
# roberta_nonprocessed_data_sentiment_score           0.091722   0.090768
# close                                               1.000000   0.999655
# close_t+1                                           0.999655   1.000000
# close_t+2                                           0.999371   0.999730
# close_t+3                                           0.999334   0.999566
# close_t+7                                           0.998375   0.998281
#
#                                                     close_t+2  close_t+3  \
# date                                                -0.744251  -0.742793
# flair_nonprocessed_data_score                        0.015194   0.017107
# spacytextblob_nonprocessed_data_polarity_score      -0.035113  -0.034304
# spacytextblob_nonprocessed_data_subjectivity_score  -0.027891  -0.024532
# textblob_nonprocessed_data_polarity_score           -0.035113  -0.034304
# textblob_nonprocessed_data_subjectivity_score       -0.027891  -0.024532
# vader_nonprocessed_data_score                        0.111231   0.113378
# bert_nonprocessed_data_sentiment_score               0.070157   0.070733
# roberta_nonprocessed_data_sentiment_score            0.091242   0.091937
# close                                                0.999371   0.999334
# close_t+1                                            0.999730   0.999566
# close_t+2                                            1.000000   0.999620
# close_t+3                                            0.999620   1.000000
# close_t+7                                            0.998258   0.998656
#
#                                                     close_t+7
# date                                                -0.739925
# flair_nonprocessed_data_score                        0.008289
# spacytextblob_nonprocessed_data_polarity_score      -0.033792
# spacytextblob_nonprocessed_data_subjectivity_score  -0.021804
# textblob_nonprocessed_data_polarity_score           -0.033792
# textblob_nonprocessed_data_subjectivity_score       -0.021804
# vader_nonprocessed_data_score                        0.107361
# bert_nonprocessed_data_sentiment_score               0.063898
# roberta_nonprocessed_data_sentiment_score            0.090333
# close                                                0.998375
# close_t+1                                            0.998281
# close_t+2                                            0.998258
# close_t+3                                            0.998656
# close_t+7                                            1.000000

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_30min_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5701
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.754
# Time:                        13:46:02   Log-Likelihood:                -2115.6
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.623e+04   2603.526     13.916      0.000    3.11e+04    4.14e+04
# flair_nonprocessed_data_score                       -492.9267   2570.218     -0.192      0.848   -5563.276    4577.423
# spacytextblob_nonprocessed_data_polarity_score     -6152.3327   4340.491     -1.417      0.158   -1.47e+04    2410.288
# spacytextblob_nonprocessed_data_subjectivity_score  -724.6125   3121.325     -0.232      0.817   -6882.148    5432.923
# textblob_nonprocessed_data_polarity_score          -6152.3327   4340.491     -1.417      0.158   -1.47e+04    2410.288
# textblob_nonprocessed_data_subjectivity_score       -724.6125   3121.325     -0.232      0.817   -6882.148    5432.923
# vader_nonprocessed_data_score                       4370.6810   5147.772      0.849      0.397   -5784.489    1.45e+04
# bert_nonprocessed_data_sentiment_score              2532.1222   4769.240      0.531      0.596   -6876.306    1.19e+04
# roberta_nonprocessed_data_sentiment_score           1035.1431   4769.740      0.217      0.828   -8374.271    1.04e+04
# ==============================================================================
# Omnibus:                       12.192   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.797
# Skew:                           0.403   Prob(JB):                       0.0123
# Kurtosis:                       2.338   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5651
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.758
# Time:                        13:46:02   Log-Likelihood:                -2115.7
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.631e+04   2604.851     13.941      0.000    3.12e+04    4.15e+04
# flair_nonprocessed_data_score                       -464.0629   2571.526     -0.180      0.857   -5536.992    4608.866
# spacytextblob_nonprocessed_data_polarity_score     -6104.8141   4342.699     -1.406      0.161   -1.47e+04    2462.162
# spacytextblob_nonprocessed_data_subjectivity_score  -826.5128   3122.913     -0.265      0.792   -6987.180    5334.155
# textblob_nonprocessed_data_polarity_score          -6104.8141   4342.699     -1.406      0.161   -1.47e+04    2462.162
# textblob_nonprocessed_data_subjectivity_score       -826.5128   3122.913     -0.265      0.792   -6987.180    5334.155
# vader_nonprocessed_data_score                       4341.8176   5150.391      0.843      0.400   -5818.518    1.45e+04
# bert_nonprocessed_data_sentiment_score              2484.5234   4771.666      0.521      0.603   -6928.691    1.19e+04
# roberta_nonprocessed_data_sentiment_score           1002.6677   4772.166      0.210      0.834   -8411.533    1.04e+04
# ==============================================================================
# Omnibus:                       12.117   Durbin-Watson:                   0.069
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.789
# Skew:                           0.404   Prob(JB):                       0.0123
# Kurtosis:                       2.341   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5773
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.748
# Time:                        13:46:02   Log-Likelihood:                -2115.9
# No. Observations:                 194   AIC:                             4246.
# Df Residuals:                     187   BIC:                             4269.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.644e+04   2607.812     13.974      0.000    3.13e+04    4.16e+04
# flair_nonprocessed_data_score                       -398.1982   2574.449     -0.155      0.877   -5476.893    4680.497
# spacytextblob_nonprocessed_data_polarity_score     -6101.9674   4347.635     -1.404      0.162   -1.47e+04    2474.747
# spacytextblob_nonprocessed_data_subjectivity_score  -923.0975   3126.463     -0.295      0.768   -7090.768    5244.573
# textblob_nonprocessed_data_polarity_score          -6101.9674   4347.635     -1.404      0.162   -1.47e+04    2474.747
# textblob_nonprocessed_data_subjectivity_score       -923.0975   3126.463     -0.295      0.768   -7090.768    5244.573
# vader_nonprocessed_data_score                       4392.2955   5156.245      0.852      0.395   -5779.590    1.46e+04
# bert_nonprocessed_data_sentiment_score              2574.6041   4777.090      0.539      0.591   -6849.310     1.2e+04
# roberta_nonprocessed_data_sentiment_score            909.4173   4777.591      0.190      0.849   -8515.484    1.03e+04
# ==============================================================================
# Omnibus:                       12.074   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.732
# Skew:                           0.402   Prob(JB):                       0.0127
# Kurtosis:                       2.341   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5918
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.737
# Time:                        13:46:02   Log-Likelihood:                -2115.7
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.636e+04   2604.660     13.959      0.000    3.12e+04    4.15e+04
# flair_nonprocessed_data_score                       -405.2578   2571.337     -0.158      0.875   -5477.814    4667.299
# spacytextblob_nonprocessed_data_polarity_score     -6166.6284   4342.380     -1.420      0.157   -1.47e+04    2399.719
# spacytextblob_nonprocessed_data_subjectivity_score  -866.8209   3122.684     -0.278      0.782   -7027.036    5293.395
# textblob_nonprocessed_data_polarity_score          -6166.6284   4342.380     -1.420      0.157   -1.47e+04    2399.719
# textblob_nonprocessed_data_subjectivity_score       -866.8209   3122.684     -0.278      0.782   -7027.036    5293.395
# vader_nonprocessed_data_score                       4477.0412   5150.013      0.869      0.386   -5682.549    1.46e+04
# bert_nonprocessed_data_sentiment_score              2539.3774   4771.316      0.532      0.595   -6873.146     1.2e+04
# roberta_nonprocessed_data_sentiment_score           1002.0174   4771.816      0.210      0.834   -8411.492    1.04e+04
# ==============================================================================
# Omnibus:                       12.046   Durbin-Watson:                   0.069
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.754
# Skew:                           0.403   Prob(JB):                       0.0126
# Kurtosis:                       2.343   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5746
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.750
# Time:                        13:46:02   Log-Likelihood:                -2115.4
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.621e+04   2601.585     13.917      0.000    3.11e+04    4.13e+04
# flair_nonprocessed_data_score                       -520.7463   2568.301     -0.203      0.840   -5587.314    4545.822
# spacytextblob_nonprocessed_data_polarity_score     -6082.2765   4337.253     -1.402      0.162   -1.46e+04    2473.958
# spacytextblob_nonprocessed_data_subjectivity_score  -810.7578   3118.997     -0.260      0.795   -6963.701    5342.185
# textblob_nonprocessed_data_polarity_score          -6082.2765   4337.253     -1.402      0.162   -1.46e+04    2473.958
# textblob_nonprocessed_data_subjectivity_score       -810.7578   3118.997     -0.260      0.795   -6963.701    5342.185
# vader_nonprocessed_data_score                       4407.9041   5143.933      0.857      0.393   -5739.692    1.46e+04
# bert_nonprocessed_data_sentiment_score              2412.2240   4765.683      0.506      0.613   -6989.187    1.18e+04
# roberta_nonprocessed_data_sentiment_score           1192.6809   4766.183      0.250      0.803   -8209.715    1.06e+04
# ==============================================================================
# Omnibus:                       11.995   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.687
# Skew:                           0.401   Prob(JB):                       0.0130
# Kurtosis:                       2.342   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 2. 1H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5762
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.749
# Time:                        13:46:02   Log-Likelihood:                -2115.9
# No. Observations:                 194   AIC:                             4246.
# Df Residuals:                     187   BIC:                             4269.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.643e+04   2608.271     13.968      0.000    3.13e+04    4.16e+04
# flair_nonprocessed_data_score                       -410.8034   2574.902     -0.160      0.873   -5490.393    4668.787
# spacytextblob_nonprocessed_data_polarity_score     -6110.4643   4348.401     -1.405      0.162   -1.47e+04    2467.761
# spacytextblob_nonprocessed_data_subjectivity_score  -916.0927   3127.014     -0.293      0.770   -7084.850    5252.665
# textblob_nonprocessed_data_polarity_score          -6110.4643   4348.401     -1.405      0.162   -1.47e+04    2467.761
# textblob_nonprocessed_data_subjectivity_score       -916.0927   3127.014     -0.293      0.770   -7084.850    5252.665
# vader_nonprocessed_data_score                       4408.0803   5157.154      0.855      0.394   -5765.597    1.46e+04
# bert_nonprocessed_data_sentiment_score              2572.0224   4777.932      0.538      0.591   -6853.552     1.2e+04
# roberta_nonprocessed_data_sentiment_score            892.0413   4778.433      0.187      0.852   -8534.521    1.03e+04
# ==============================================================================
# Omnibus:                       12.102   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.747
# Skew:                           0.402   Prob(JB):                       0.0126
# Kurtosis:                       2.340   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5816
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.745
# Time:                        13:46:02   Log-Likelihood:                -2115.6
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                3.63e+04   2603.335     13.943      0.000    3.12e+04    4.14e+04
# flair_nonprocessed_data_score                       -400.6682   2570.029     -0.156      0.876   -5470.644    4669.308
# spacytextblob_nonprocessed_data_polarity_score     -6180.2551   4340.171     -1.424      0.156   -1.47e+04    2381.735
# spacytextblob_nonprocessed_data_subjectivity_score  -767.3065   3121.095     -0.246      0.806   -6924.388    5389.775
# textblob_nonprocessed_data_polarity_score          -6180.2551   4340.171     -1.424      0.156   -1.47e+04    2381.735
# textblob_nonprocessed_data_subjectivity_score       -767.3065   3121.095     -0.246      0.806   -6924.388    5389.775
# vader_nonprocessed_data_score                       4392.4367   5147.393      0.853      0.395   -5761.985    1.45e+04
# bert_nonprocessed_data_sentiment_score              2504.5837   4768.889      0.525      0.600   -6903.151    1.19e+04
# roberta_nonprocessed_data_sentiment_score           1037.2580   4769.389      0.217      0.828   -8371.463    1.04e+04
# ==============================================================================
# Omnibus:                       12.120   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.694
# Skew:                           0.399   Prob(JB):                       0.0129
# Kurtosis:                       2.337   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5964
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.733
# Time:                        13:46:02   Log-Likelihood:                -2115.2
# No. Observations:                 194   AIC:                             4244.
# Df Residuals:                     187   BIC:                             4267.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.621e+04   2599.088     13.932      0.000    3.11e+04    4.13e+04
# flair_nonprocessed_data_score                       -470.4521   2565.836     -0.183      0.855   -5532.157    4591.253
# spacytextblob_nonprocessed_data_polarity_score     -6196.7660   4333.091     -1.430      0.154   -1.47e+04    2351.256
# spacytextblob_nonprocessed_data_subjectivity_score  -775.2831   3116.004     -0.249      0.804   -6922.321    5371.754
# textblob_nonprocessed_data_polarity_score          -6196.7660   4333.091     -1.430      0.154   -1.47e+04    2351.256
# textblob_nonprocessed_data_subjectivity_score       -775.2831   3116.004     -0.249      0.804   -6922.321    5371.754
# vader_nonprocessed_data_score                       4526.7054   5138.996      0.881      0.380   -5611.151    1.47e+04
# bert_nonprocessed_data_sentiment_score              2429.9172   4761.109      0.510      0.610   -6962.471    1.18e+04
# roberta_nonprocessed_data_sentiment_score           1168.1589   4761.608      0.245      0.806   -8225.213    1.06e+04
# ==============================================================================
# Omnibus:                       12.098   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.620
# Skew:                           0.395   Prob(JB):                       0.0134
# Kurtosis:                       2.335   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5682
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.755
# Time:                        13:46:02   Log-Likelihood:                -2115.4
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.618e+04   2601.100     13.910      0.000    3.11e+04    4.13e+04
# flair_nonprocessed_data_score                       -529.7042   2567.823     -0.206      0.837   -5595.329    4535.921
# spacytextblob_nonprocessed_data_polarity_score     -6030.1566   4336.446     -1.391      0.166   -1.46e+04    2524.485
# spacytextblob_nonprocessed_data_subjectivity_score  -813.1321   3118.417     -0.261      0.795   -6964.929    5338.665
# textblob_nonprocessed_data_polarity_score          -6030.1566   4336.446     -1.391      0.166   -1.46e+04    2524.485
# textblob_nonprocessed_data_subjectivity_score       -813.1321   3118.417     -0.261      0.795   -6964.929    5338.665
# vader_nonprocessed_data_score                       4315.3323   5142.975      0.839      0.402   -5830.375    1.45e+04
# bert_nonprocessed_data_sentiment_score              2414.7599   4764.796      0.507      0.613   -6984.901    1.18e+04
# roberta_nonprocessed_data_sentiment_score           1265.3010   4765.295      0.266      0.791   -8135.345    1.07e+04
# ==============================================================================
# Omnibus:                       11.924   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                8.690
# Skew:                           0.402   Prob(JB):                       0.0130
# Kurtosis:                       2.345   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5868
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.741
# Time:                        13:46:02   Log-Likelihood:                -2114.8
# No. Observations:                 194   AIC:                             4244.
# Df Residuals:                     187   BIC:                             4267.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.626e+04   2593.937     13.980      0.000    3.11e+04    4.14e+04
# flair_nonprocessed_data_score                       -579.5439   2560.751     -0.226      0.821   -5631.218    4472.130
# spacytextblob_nonprocessed_data_polarity_score     -6150.5142   4324.503     -1.422      0.157   -1.47e+04    2380.567
# spacytextblob_nonprocessed_data_subjectivity_score  -862.6057   3109.828     -0.277      0.782   -6997.461    5272.249
# textblob_nonprocessed_data_polarity_score          -6150.5142   4324.503     -1.422      0.157   -1.47e+04    2380.567
# textblob_nonprocessed_data_subjectivity_score       -862.6057   3109.828     -0.277      0.782   -6997.461    5272.249
# vader_nonprocessed_data_score                       4446.0904   5128.811      0.867      0.387   -5671.675    1.46e+04
# bert_nonprocessed_data_sentiment_score              2607.5992   4751.673      0.549      0.584   -6766.174     1.2e+04
# roberta_nonprocessed_data_sentiment_score           1029.8788   4752.171      0.217      0.829   -8344.877    1.04e+04
# ==============================================================================
# Omnibus:                       12.275   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.623
# Skew:                           0.392   Prob(JB):                       0.0134
# Kurtosis:                       2.328   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 3. 4H frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_4hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8335
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.545
# Time:                        13:46:02   Log-Likelihood:                -2147.7
# No. Observations:                 197   AIC:                             4309.
# Df Residuals:                     190   BIC:                             4332.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.681e+04   2506.351     14.688      0.000    3.19e+04    4.18e+04
# flair_nonprocessed_data_score                       -368.8914   2551.195     -0.145      0.885   -5401.196    4663.413
# spacytextblob_nonprocessed_data_polarity_score     -6766.6176   4209.758     -1.607      0.110   -1.51e+04    1537.248
# spacytextblob_nonprocessed_data_subjectivity_score -1234.9269   3039.505     -0.406      0.685   -7230.436    4760.582
# textblob_nonprocessed_data_polarity_score          -6766.6176   4209.758     -1.607      0.110   -1.51e+04    1537.248
# textblob_nonprocessed_data_subjectivity_score      -1234.9269   3039.505     -0.406      0.685   -7230.436    4760.582
# vader_nonprocessed_data_score                       5150.6570   5076.870      1.015      0.312   -4863.613    1.52e+04
# bert_nonprocessed_data_sentiment_score              3011.2282   4713.536      0.639      0.524   -6286.354    1.23e+04
# roberta_nonprocessed_data_sentiment_score            664.0618   4722.266      0.141      0.888   -8650.741    9978.864
# ==============================================================================
# Omnibus:                       11.722   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                8.574
# Skew:                           0.395   Prob(JB):                       0.0137
# Kurtosis:                       2.352   Cond. No.                     4.66e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8380
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.542
# Time:                        13:46:02   Log-Likelihood:                -2147.2
# No. Observations:                 197   AIC:                             4308.
# Df Residuals:                     190   BIC:                             4331.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.656e+04   2500.154     14.622      0.000    3.16e+04    4.15e+04
# flair_nonprocessed_data_score                       -526.2606   2544.887     -0.207      0.836   -5546.123    4493.602
# spacytextblob_nonprocessed_data_polarity_score     -6686.7073   4199.349     -1.592      0.113    -1.5e+04    1596.627
# spacytextblob_nonprocessed_data_subjectivity_score -1160.7727   3031.990     -0.383      0.702   -7141.458    4819.912
# textblob_nonprocessed_data_polarity_score          -6686.7073   4199.349     -1.592      0.113    -1.5e+04    1596.627
# textblob_nonprocessed_data_subjectivity_score      -1160.7727   3031.990     -0.383      0.702   -7141.458    4819.912
# vader_nonprocessed_data_score                       5134.4067   5064.318      1.014      0.312   -4855.102    1.51e+04
# bert_nonprocessed_data_sentiment_score              2907.2707   4701.882      0.618      0.537   -6367.324    1.22e+04
# roberta_nonprocessed_data_sentiment_score           1146.1523   4710.590      0.243      0.808   -8145.619    1.04e+04
# ==============================================================================
# Omnibus:                       11.690   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                8.537
# Skew:                           0.394   Prob(JB):                       0.0140
# Kurtosis:                       2.352   Cond. No.                     4.66e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8459
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.536
# Time:                        13:46:02   Log-Likelihood:                -2147.0
# No. Observations:                 197   AIC:                             4308.
# Df Residuals:                     190   BIC:                             4331.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.659e+04   2497.820     14.649      0.000    3.17e+04    4.15e+04
# flair_nonprocessed_data_score                       -503.9782   2542.511     -0.198      0.843   -5519.153    4511.196
# spacytextblob_nonprocessed_data_polarity_score     -6731.0229   4195.428     -1.604      0.110    -1.5e+04    1544.576
# spacytextblob_nonprocessed_data_subjectivity_score -1183.1315   3029.158     -0.391      0.697   -7158.231    4791.968
# textblob_nonprocessed_data_polarity_score          -6731.0229   4195.428     -1.604      0.110    -1.5e+04    1544.576
# textblob_nonprocessed_data_subjectivity_score      -1183.1315   3029.158     -0.391      0.697   -7158.231    4791.968
# vader_nonprocessed_data_score                       5331.0522   5059.588      1.054      0.293   -4649.128    1.53e+04
# bert_nonprocessed_data_sentiment_score              2950.9964   4697.491      0.628      0.531   -6314.937    1.22e+04
# roberta_nonprocessed_data_sentiment_score            856.8674   4706.191      0.182      0.856   -8426.227    1.01e+04
# ==============================================================================
# Omnibus:                       11.471   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):                8.493
# Skew:                           0.395   Prob(JB):                       0.0143
# Kurtosis:                       2.360   Cond. No.                     4.66e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.8217
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.554
# Time:                        13:46:02   Log-Likelihood:                -2146.6
# No. Observations:                 197   AIC:                             4307.
# Df Residuals:                     190   BIC:                             4330.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.657e+04   2492.850     14.669      0.000    3.16e+04    4.15e+04
# flair_nonprocessed_data_score                       -417.4558   2537.453     -0.165      0.869   -5422.653    4587.741
# spacytextblob_nonprocessed_data_polarity_score     -6256.3102   4187.081     -1.494      0.137   -1.45e+04    2002.825
# spacytextblob_nonprocessed_data_subjectivity_score -1428.3352   3023.132     -0.472      0.637   -7391.548    4534.878
# textblob_nonprocessed_data_polarity_score          -6256.3102   4187.081     -1.494      0.137   -1.45e+04    2002.825
# textblob_nonprocessed_data_subjectivity_score      -1428.3352   3023.132     -0.472      0.637   -7391.548    4534.878
# vader_nonprocessed_data_score                       5431.2865   5049.523      1.076      0.283   -4529.039    1.54e+04
# bert_nonprocessed_data_sentiment_score              2613.6685   4688.146      0.558      0.578   -6633.831    1.19e+04
# roberta_nonprocessed_data_sentiment_score            974.3676   4696.828      0.207      0.836   -8290.259    1.02e+04
# ==============================================================================
# Omnibus:                       12.436   Durbin-Watson:                   0.075
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.488
# Skew:                           0.378   Prob(JB):                       0.0144
# Kurtosis:                       2.320   Cond. No.                     4.66e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.8127
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.561
# Time:                        13:46:02   Log-Likelihood:                -2146.8
# No. Observations:                 197   AIC:                             4308.
# Df Residuals:                     190   BIC:                             4331.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.672e+04   2495.349     14.716      0.000    3.18e+04    4.16e+04
# flair_nonprocessed_data_score                       -446.3040   2539.996     -0.176      0.861   -5456.517    4563.909
# spacytextblob_nonprocessed_data_polarity_score     -6121.6870   4191.277     -1.461      0.146   -1.44e+04    2145.725
# spacytextblob_nonprocessed_data_subjectivity_score -1624.7080   3026.161     -0.537      0.592   -7593.897    4344.481
# textblob_nonprocessed_data_polarity_score          -6121.6870   4191.277     -1.461      0.146   -1.44e+04    2145.725
# textblob_nonprocessed_data_subjectivity_score      -1624.7080   3026.161     -0.537      0.592   -7593.897    4344.481
# vader_nonprocessed_data_score                       5088.4496   5054.583      1.007      0.315   -4881.858    1.51e+04
# bert_nonprocessed_data_sentiment_score              2638.2347   4692.844      0.562      0.575   -6618.532    1.19e+04
# roberta_nonprocessed_data_sentiment_score           1211.5284   4701.535      0.258      0.797   -8062.383    1.05e+04
# ==============================================================================
# Omnibus:                       13.526   Durbin-Watson:                   0.076
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.599
# Skew:                           0.367   Prob(JB):                       0.0136
# Kurtosis:                       2.287   Cond. No.                     4.66e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-35. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 4. 6H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_6hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5762
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.749
# Time:                        13:46:02   Log-Likelihood:                -2115.9
# No. Observations:                 194   AIC:                             4246.
# Df Residuals:                     187   BIC:                             4269.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.643e+04   2608.271     13.968      0.000    3.13e+04    4.16e+04
# flair_nonprocessed_data_score                       -410.8034   2574.902     -0.160      0.873   -5490.393    4668.787
# spacytextblob_nonprocessed_data_polarity_score     -6110.4643   4348.401     -1.405      0.162   -1.47e+04    2467.761
# spacytextblob_nonprocessed_data_subjectivity_score  -916.0927   3127.014     -0.293      0.770   -7084.850    5252.665
# textblob_nonprocessed_data_polarity_score          -6110.4643   4348.401     -1.405      0.162   -1.47e+04    2467.761
# textblob_nonprocessed_data_subjectivity_score       -916.0927   3127.014     -0.293      0.770   -7084.850    5252.665
# vader_nonprocessed_data_score                       4408.0803   5157.154      0.855      0.394   -5765.597    1.46e+04
# bert_nonprocessed_data_sentiment_score              2572.0224   4777.932      0.538      0.591   -6853.552     1.2e+04
# roberta_nonprocessed_data_sentiment_score            892.0413   4778.433      0.187      0.852   -8534.521    1.03e+04
# ==============================================================================
# Omnibus:                       12.102   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.747
# Skew:                           0.402   Prob(JB):                       0.0126
# Kurtosis:                       2.340   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5830
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.744
# Time:                        13:46:02   Log-Likelihood:                -2115.3
# No. Observations:                 194   AIC:                             4245.
# Df Residuals:                     187   BIC:                             4268.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.625e+04   2600.478     13.939      0.000    3.11e+04    4.14e+04
# flair_nonprocessed_data_score                       -520.0309   2567.209     -0.203      0.840   -5584.443    4544.381
# spacytextblob_nonprocessed_data_polarity_score     -6166.4424   4335.408     -1.422      0.157   -1.47e+04    2386.151
# spacytextblob_nonprocessed_data_subjectivity_score  -814.8259   3117.670     -0.261      0.794   -6965.150    5335.499
# textblob_nonprocessed_data_polarity_score          -6166.4424   4335.408     -1.422      0.157   -1.47e+04    2386.151
# textblob_nonprocessed_data_subjectivity_score       -814.8259   3117.670     -0.261      0.794   -6965.150    5335.499
# vader_nonprocessed_data_score                       4396.2946   5141.744      0.855      0.394   -5746.983    1.45e+04
# bert_nonprocessed_data_sentiment_score              2527.3095   4763.655      0.531      0.596   -6870.101    1.19e+04
# roberta_nonprocessed_data_sentiment_score           1107.2758   4764.154      0.232      0.816   -8291.119    1.05e+04
# ==============================================================================
# Omnibus:                       12.559   Durbin-Watson:                   0.072
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.736
# Skew:                           0.394   Prob(JB):                       0.0127
# Kurtosis:                       2.321   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5671
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.756
# Time:                        13:46:02   Log-Likelihood:                -2114.8
# No. Observations:                 194   AIC:                             4244.
# Df Residuals:                     187   BIC:                             4267.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.619e+04   2593.442     13.955      0.000    3.11e+04    4.13e+04
# flair_nonprocessed_data_score                       -457.0689   2560.263     -0.179      0.859   -5507.780    4593.642
# spacytextblob_nonprocessed_data_polarity_score     -5600.8069   4323.679     -1.295      0.197   -1.41e+04    2928.649
# spacytextblob_nonprocessed_data_subjectivity_score -1122.0189   3109.236     -0.361      0.719   -7255.705    5011.667
# textblob_nonprocessed_data_polarity_score          -5600.8069   4323.679     -1.295      0.197   -1.41e+04    2928.649
# textblob_nonprocessed_data_subjectivity_score      -1122.0189   3109.236     -0.361      0.719   -7255.705    5011.667
# vader_nonprocessed_data_score                       4663.1126   5127.834      0.909      0.364   -5452.724    1.48e+04
# bert_nonprocessed_data_sentiment_score              2164.8019   4750.768      0.456      0.649   -7207.185    1.15e+04
# roberta_nonprocessed_data_sentiment_score           1193.9059   4751.266      0.251      0.802   -8179.063    1.06e+04
# ==============================================================================
# Omnibus:                       12.769   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                8.641
# Skew:                           0.385   Prob(JB):                       0.0133
# Kurtosis:                       2.310   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.5749
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.750
# Time:                        13:46:02   Log-Likelihood:                -2115.2
# No. Observations:                 194   AIC:                             4244.
# Df Residuals:                     187   BIC:                             4267.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                3.63e+04   2598.203     13.973      0.000    3.12e+04    4.14e+04
# flair_nonprocessed_data_score                       -488.5813   2564.963     -0.190      0.849   -5548.563    4571.400
# spacytextblob_nonprocessed_data_polarity_score     -5591.1448   4331.615     -1.291      0.198   -1.41e+04    2953.967
# spacytextblob_nonprocessed_data_subjectivity_score -1245.3391   3114.943     -0.400      0.690   -7390.283    4899.605
# textblob_nonprocessed_data_polarity_score          -5591.1448   4331.615     -1.291      0.198   -1.41e+04    2953.967
# textblob_nonprocessed_data_subjectivity_score      -1245.3391   3114.943     -0.400      0.690   -7390.283    4899.605
# vader_nonprocessed_data_score                       4446.2613   5137.246      0.865      0.388   -5688.143    1.46e+04
# bert_nonprocessed_data_sentiment_score              2268.1186   4759.488      0.477      0.634   -7121.071    1.17e+04
# roberta_nonprocessed_data_sentiment_score           1385.9208   4759.987      0.291      0.771   -8004.252    1.08e+04
# ==============================================================================
# Omnibus:                       13.892   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.707
# Skew:                           0.372   Prob(JB):                       0.0129
# Kurtosis:                       2.275   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.5492
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.770
# Time:                        13:46:02   Log-Likelihood:                -2116.4
# No. Observations:                 194   AIC:                             4247.
# Df Residuals:                     187   BIC:                             4270.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.597e+04   2615.326     13.754      0.000    3.08e+04    4.11e+04
# flair_nonprocessed_data_score                       -557.5464   2581.867     -0.216      0.829   -5650.875    4535.782
# spacytextblob_nonprocessed_data_polarity_score     -5394.9969   4360.162     -1.237      0.218    -1.4e+04    3206.430
# spacytextblob_nonprocessed_data_subjectivity_score -1143.9564   3135.471     -0.365      0.716   -7329.398    5041.485
# textblob_nonprocessed_data_polarity_score          -5394.9969   4360.162     -1.237      0.218    -1.4e+04    3206.430
# textblob_nonprocessed_data_subjectivity_score      -1143.9564   3135.471     -0.365      0.716   -7329.398    5041.485
# vader_nonprocessed_data_score                       4296.4777   5171.102      0.831      0.407   -5904.716    1.45e+04
# bert_nonprocessed_data_sentiment_score              1396.2338   4790.855      0.291      0.771   -8054.834    1.08e+04
# roberta_nonprocessed_data_sentiment_score           2214.7922   4791.357      0.462      0.644   -7237.266    1.17e+04
# ==============================================================================
# Omnibus:                       14.218   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.419
# Skew:                           0.350   Prob(JB):                       0.0149
# Kurtosis:                       2.258   Cond. No.                     6.37e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.14e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 5. 1D Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1d_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.4877
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.817
# Time:                        13:46:02   Log-Likelihood:                -2140.1
# No. Observations:                 196   AIC:                             4294.
# Df Residuals:                     189   BIC:                             4317.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.653e+04   2636.341     13.857      0.000    3.13e+04    4.17e+04
# flair_nonprocessed_data_score                        -49.0552   2590.165     -0.019      0.985   -5158.402    5060.291
# spacytextblob_nonprocessed_data_polarity_score     -5815.3972   4397.600     -1.322      0.188   -1.45e+04    2859.287
# spacytextblob_nonprocessed_data_subjectivity_score  -816.6443   3157.939     -0.259      0.796   -7045.979    5412.691
# textblob_nonprocessed_data_polarity_score          -5815.3972   4397.600     -1.322      0.188   -1.45e+04    2859.287
# textblob_nonprocessed_data_subjectivity_score       -816.6443   3157.939     -0.259      0.796   -7045.979    5412.691
# vader_nonprocessed_data_score                       3363.6221   5184.844      0.649      0.517   -6863.976    1.36e+04
# bert_nonprocessed_data_sentiment_score              2063.7105   4824.654      0.428      0.669   -7453.379    1.16e+04
# roberta_nonprocessed_data_sentiment_score           1349.0225   4828.546      0.279      0.780   -8175.743    1.09e+04
# ==============================================================================
# Omnibus:                       12.638   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.279
# Skew:                           0.419   Prob(JB):                      0.00966
# Kurtosis:                       2.341   Cond. No.                     7.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.53e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.4757
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.826
# Time:                        13:46:02   Log-Likelihood:                -2139.7
# No. Observations:                 196   AIC:                             4293.
# Df Residuals:                     189   BIC:                             4316.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.621e+04   2631.008     13.764      0.000     3.1e+04    4.14e+04
# flair_nonprocessed_data_score                       -243.7494   2584.926     -0.094      0.925   -5342.761    4855.263
# spacytextblob_nonprocessed_data_polarity_score     -4871.7292   4388.705     -1.110      0.268   -1.35e+04    3785.409
# spacytextblob_nonprocessed_data_subjectivity_score -1168.9578   3151.552     -0.371      0.711   -7385.693    5047.778
# textblob_nonprocessed_data_polarity_score          -4871.7292   4388.705     -1.110      0.268   -1.35e+04    3785.409
# textblob_nonprocessed_data_subjectivity_score      -1168.9578   3151.552     -0.371      0.711   -7385.693    5047.778
# vader_nonprocessed_data_score                       3392.5411   5174.357      0.656      0.513   -6814.370    1.36e+04
# bert_nonprocessed_data_sentiment_score              1428.6817   4814.896      0.297      0.767   -8069.158    1.09e+04
# roberta_nonprocessed_data_sentiment_score           2381.2367   4818.779      0.494      0.622   -7124.264    1.19e+04
# ==============================================================================
# Omnibus:                       14.280   Durbin-Watson:                   0.060
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                9.082
# Skew:                           0.384   Prob(JB):                       0.0107
# Kurtosis:                       2.277   Cond. No.                     7.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.53e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                    0.4415
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.850
# Time:                        13:46:02   Log-Likelihood:                -2141.8
# No. Observations:                 196   AIC:                             4298.
# Df Residuals:                     189   BIC:                             4321.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.626e+04   2659.801     13.631      0.000     3.1e+04    4.15e+04
# flair_nonprocessed_data_score                       -164.0498   2613.215     -0.063      0.950   -5318.864    4990.764
# spacytextblob_nonprocessed_data_polarity_score     -4866.6474   4436.734     -1.097      0.274   -1.36e+04    3885.232
# spacytextblob_nonprocessed_data_subjectivity_score -1134.6581   3186.041     -0.356      0.722   -7419.428    5150.111
# textblob_nonprocessed_data_polarity_score          -4866.6474   4436.734     -1.097      0.274   -1.36e+04    3885.232
# textblob_nonprocessed_data_subjectivity_score      -1134.6581   3186.041     -0.356      0.722   -7419.428    5150.111
# vader_nonprocessed_data_score                       3241.2677   5230.984      0.620      0.536   -7077.345    1.36e+04
# bert_nonprocessed_data_sentiment_score               922.1191   4867.589      0.189      0.850   -8679.662    1.05e+04
# roberta_nonprocessed_data_sentiment_score           2509.0771   4871.515      0.515      0.607   -7100.449    1.21e+04
# ==============================================================================
# Omnibus:                       13.969   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                9.003
# Skew:                           0.384   Prob(JB):                       0.0111
# Kurtosis:                       2.284   Cond. No.                     7.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.53e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                    0.4649
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.834
# Time:                        13:46:02   Log-Likelihood:                -2143.9
# No. Observations:                 196   AIC:                             4302.
# Df Residuals:                     189   BIC:                             4325.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.694e+04   2687.820     13.745      0.000    3.16e+04    4.22e+04
# flair_nonprocessed_data_score                         68.2738   2640.743      0.026      0.979   -5140.842    5277.390
# spacytextblob_nonprocessed_data_polarity_score     -5514.2458   4483.472     -1.230      0.220   -1.44e+04    3329.828
# spacytextblob_nonprocessed_data_subjectivity_score -1305.5562   3219.604     -0.406      0.686   -7656.531    5045.418
# textblob_nonprocessed_data_polarity_score          -5514.2458   4483.472     -1.230      0.220   -1.44e+04    3329.828
# textblob_nonprocessed_data_subjectivity_score      -1305.5562   3219.604     -0.406      0.686   -7656.531    5045.418
# vader_nonprocessed_data_score                       3448.9762   5286.088      0.652      0.515   -6978.335    1.39e+04
# bert_nonprocessed_data_sentiment_score              1492.7810   4918.865      0.303      0.762   -8210.148    1.12e+04
# roberta_nonprocessed_data_sentiment_score           1427.6076   4922.832      0.290      0.772   -8283.147    1.11e+04
# ==============================================================================
# Omnibus:                       12.907   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.158
# Skew:                           0.408   Prob(JB):                       0.0103
# Kurtosis:                       2.325   Cond. No.                     7.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.53e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.4996
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):              0.808
# Time:                        13:46:02   Log-Likelihood:                -2143.0
# No. Observations:                 196   AIC:                             4300.
# Df Residuals:                     189   BIC:                             4323.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.661e+04   2675.958     13.681      0.000    3.13e+04    4.19e+04
# flair_nonprocessed_data_score                       -375.2196   2629.088     -0.143      0.887   -5561.346    4810.906
# spacytextblob_nonprocessed_data_polarity_score     -5726.1360   4463.684     -1.283      0.201   -1.45e+04    3078.905
# spacytextblob_nonprocessed_data_subjectivity_score  -713.9709   3205.394     -0.223      0.824   -7036.916    5608.974
# textblob_nonprocessed_data_polarity_score          -5726.1360   4463.684     -1.283      0.201   -1.45e+04    3078.905
# textblob_nonprocessed_data_subjectivity_score       -713.9709   3205.394     -0.223      0.824   -7036.916    5608.974
# vader_nonprocessed_data_score                       3014.8945   5262.758      0.573      0.567   -7366.397    1.34e+04
# bert_nonprocessed_data_sentiment_score              1664.5080   4897.156      0.340      0.734   -7995.597    1.13e+04
# roberta_nonprocessed_data_sentiment_score           2728.0803   4901.106      0.557      0.578   -6939.817    1.24e+04
# ==============================================================================
# Omnibus:                       21.264   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.517
# Skew:                           0.326   Prob(JB):                      0.00858
# Kurtosis:                       2.139   Cond. No.                     7.28e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.53e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
