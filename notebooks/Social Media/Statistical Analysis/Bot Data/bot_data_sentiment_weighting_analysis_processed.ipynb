# %%
import pandas as pd
import numpy as np
import os
import datetime
os.chdir('/home/ubuntu/Masters Thesis/')
from scripts.utilities.data_joining import GetModellingData

# %% [markdown]
# Data without Bots and De-emoji text processing

# %%
bitcoin_hourly = pd.read_csv("/mnt/bitcoin_hourly_prices_till_2023-03-30.csv", lineterminator='\n')
bitcoin_minutely = pd.read_csv("/mnt/bitcoin_price_minutely_data_till_2023_03_30.csv", lineterminator='\n')

# %%
bitcoin_minutely
# Out:
#                time exchange fsym tsym     close      high       low  \
# 0        1606780800   CCCAGG  BTC  USD  19704.72  19714.44  19686.87
# 1        1606780860   CCCAGG  BTC  USD  19682.63  19706.49  19674.34
# 2        1606780920   CCCAGG  BTC  USD  19688.59  19691.33  19654.82
# 3        1606780980   CCCAGG  BTC  USD  19664.79  19697.12  19659.91
# 4        1606781040   CCCAGG  BTC  USD  19628.40  19665.60  19623.03
# ...             ...      ...  ...  ...       ...       ...       ...
# 1223995  1680220500   CCCAGG  BTC  USD  28038.57  28044.74  28032.44
# 1223996  1680220560   CCCAGG  BTC  USD  28037.36  28043.24  28031.83
# 1223997  1680220620   CCCAGG  BTC  USD  28031.20  28039.71  28030.25
# 1223998  1680220680   CCCAGG  BTC  USD  28037.81  28038.74  28029.52
# 1223999  1680220740   CCCAGG  BTC  USD  28040.71  28052.54  28036.36
#
#              open  volumefrom    volumeto
# 0        19686.87      58.620  1151502.04
# 1        19704.72     132.800  2614001.65
# 2        19682.63      55.390  1090096.41
# 3        19688.59      51.070  1004714.46
# 4        19664.79     109.540  2149088.17
# ...           ...         ...         ...
# 1223995  28032.49      11.500   322442.59
# 1223996  28038.57      20.120   564252.17
# 1223997  28037.36      12.290   344664.77
# 1223998  28031.20       8.527   239073.67
# 1223999  28037.81      75.070  2105709.79
#
# [1224000 rows x 10 columns]

# %%
data_30min = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_True_interval_30T.csv", lineterminator='\n')
data_1hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_True_interval_1H.csv", lineterminator='\n')
data_4hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_True_interval_4H.csv", lineterminator='\n')
data_6hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_True_interval_6H.csv", lineterminator='\n')
data_1day = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_True_interval_D.csv", lineterminator='\n')

# %%
data_30min = data_30min[~data_30min['spacytextblob_processed_data_polarity_score'].isna()]
data_1hrs = data_1hrs[~data_1hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_4hrs = data_4hrs[~data_4hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_6hrs = data_6hrs[~data_6hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_1day = data_1day[~data_1day['spacytextblob_processed_data_polarity_score'].isna()]

data_30min = data_30min.drop(columns=['Unnamed: 0'])
data_1hrs = data_1hrs.drop(columns=['Unnamed: 0'])
data_4hrs = data_4hrs.drop(columns=['Unnamed: 0'])
data_6hrs = data_6hrs.drop(columns=['Unnamed: 0'])
data_1day = data_1day.drop(columns=['Unnamed: 0'])

# %%
bitcoin_minutely = bitcoin_minutely.rename(columns={'time': 'date'})
bitcoin_minutely['date'] = bitcoin_minutely['date'].apply(datetime.datetime.utcfromtimestamp)
bitcoin_hourly = bitcoin_hourly.rename(columns={'datetimes': 'date'})
bitcoin_hourly['date'] = pd.to_datetime(bitcoin_hourly['date'])

# %%
data_30min_joined = GetModellingData(data=data_30min, bitcoin_data=bitcoin_minutely, frequency='30T').get_data_for_feature_analysis()
data_1hr_joined = GetModellingData(data=data_1hrs, bitcoin_data=bitcoin_hourly, frequency='1H').get_data_for_feature_analysis()
data_4hr_joined = GetModellingData(data=data_4hrs, bitcoin_data=bitcoin_hourly, frequency='4H').get_data_for_feature_analysis()
data_6hr_joined = GetModellingData(data=data_6hrs, bitcoin_data=bitcoin_hourly, frequency='6H').get_data_for_feature_analysis()
data_1d_joined = GetModellingData(data=data_1day, bitcoin_data=bitcoin_hourly, frequency='1D').get_data_for_feature_analysis()
# Out:
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])

# %%
data_30min_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_30min_joined.dropna(inplace=True)
data_1hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1hr_joined.dropna(inplace=True)
data_4hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_4hr_joined.dropna(inplace=True)
data_6hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_6hr_joined.dropna(inplace=True)
data_1d_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1d_joined.dropna(inplace=True)

# %% [markdown]
# ### Plots and Analysis

# %% [markdown]
# 1. 30T Frequency

# %%
# correlation analysis - pearson
data_30min_joined.corr()
# Out:
#                                                      date  \
# date                                             1.000000
# flair_processed_data_score                       0.093815
# spacytextblob_processed_data_polarity_score      0.148168
# spacytextblob_processed_data_subjectivity_score  0.170697
# textblob_processed_data_polarity_score           0.148168
# textblob_processed_data_subjectivity_score       0.170697
# vader_processed_data_score                       0.016431
# bert_processed_data_sentiment_score             -0.049604
# roberta_processed_data_sentiment_score           0.004345
# close                                           -0.715881
# close_t+1                                       -0.716094
# close_t+2                                       -0.716302
# close_t+3                                       -0.716504
# close_t+7                                       -0.717309
#
#                                                  flair_processed_data_score  \
# date                                                               0.093815
# flair_processed_data_score                                         1.000000
# spacytextblob_processed_data_polarity_score                        0.261420
# spacytextblob_processed_data_subjectivity_score                    0.123181
# textblob_processed_data_polarity_score                             0.261420
# textblob_processed_data_subjectivity_score                         0.123181
# vader_processed_data_score                                         0.333802
# bert_processed_data_sentiment_score                                0.588367
# roberta_processed_data_sentiment_score                             0.431989
# close                                                             -0.072464
# close_t+1                                                         -0.072690
# close_t+2                                                         -0.072963
# close_t+3                                                         -0.073158
# close_t+7                                                         -0.073793
#
#                                                  spacytextblob_processed_data_polarity_score  \
# date                                                                                0.148168
# flair_processed_data_score                                                          0.261420
# spacytextblob_processed_data_polarity_score                                         1.000000
# spacytextblob_processed_data_subjectivity_score                                     0.570403
# textblob_processed_data_polarity_score                                              1.000000
# textblob_processed_data_subjectivity_score                                          0.570403
# vader_processed_data_score                                                          0.446452
# bert_processed_data_sentiment_score                                                 0.297316
# roberta_processed_data_sentiment_score                                              0.443209
# close                                                                              -0.077016
# close_t+1                                                                          -0.077263
# close_t+2                                                                          -0.077274
# close_t+3                                                                          -0.077363
# close_t+7                                                                          -0.077213
#
#                                                  spacytextblob_processed_data_subjectivity_score  \
# date                                                                                    0.170697
# flair_processed_data_score                                                              0.123181
# spacytextblob_processed_data_polarity_score                                             0.570403
# spacytextblob_processed_data_subjectivity_score                                         1.000000
# textblob_processed_data_polarity_score                                                  0.570403
# textblob_processed_data_subjectivity_score                                              1.000000
# vader_processed_data_score                                                              0.272236
# bert_processed_data_sentiment_score                                                     0.133189
# roberta_processed_data_sentiment_score                                                  0.244358
# close                                                                                  -0.116140
# close_t+1                                                                              -0.116464
# close_t+2                                                                              -0.116523
# close_t+3                                                                              -0.116524
# close_t+7                                                                              -0.116282
#
#                                                  textblob_processed_data_polarity_score  \
# date                                                                           0.148168
# flair_processed_data_score                                                     0.261420
# spacytextblob_processed_data_polarity_score                                    1.000000
# spacytextblob_processed_data_subjectivity_score                                0.570403
# textblob_processed_data_polarity_score                                         1.000000
# textblob_processed_data_subjectivity_score                                     0.570403
# vader_processed_data_score                                                     0.446452
# bert_processed_data_sentiment_score                                            0.297316
# roberta_processed_data_sentiment_score                                         0.443209
# close                                                                         -0.077016
# close_t+1                                                                     -0.077263
# close_t+2                                                                     -0.077274
# close_t+3                                                                     -0.077363
# close_t+7                                                                     -0.077213
#
#                                                  textblob_processed_data_subjectivity_score  \
# date                                                                               0.170697
# flair_processed_data_score                                                         0.123181
# spacytextblob_processed_data_polarity_score                                        0.570403
# spacytextblob_processed_data_subjectivity_score                                    1.000000
# textblob_processed_data_polarity_score                                             0.570403
# textblob_processed_data_subjectivity_score                                         1.000000
# vader_processed_data_score                                                         0.272236
# bert_processed_data_sentiment_score                                                0.133189
# roberta_processed_data_sentiment_score                                             0.244358
# close                                                                             -0.116140
# close_t+1                                                                         -0.116464
# close_t+2                                                                         -0.116523
# close_t+3                                                                         -0.116524
# close_t+7                                                                         -0.116282
#
#                                                  vader_processed_data_score  \
# date                                                               0.016431
# flair_processed_data_score                                         0.333802
# spacytextblob_processed_data_polarity_score                        0.446452
# spacytextblob_processed_data_subjectivity_score                    0.272236
# textblob_processed_data_polarity_score                             0.446452
# textblob_processed_data_subjectivity_score                         0.272236
# vader_processed_data_score                                         1.000000
# bert_processed_data_sentiment_score                                0.429783
# roberta_processed_data_sentiment_score                             0.619424
# close                                                              0.003786
# close_t+1                                                          0.003926
# close_t+2                                                          0.003934
# close_t+3                                                          0.003909
# close_t+7                                                          0.004216
#
#                                                  bert_processed_data_sentiment_score  \
# date                                                                       -0.049604
# flair_processed_data_score                                                  0.588367
# spacytextblob_processed_data_polarity_score                                 0.297316
# spacytextblob_processed_data_subjectivity_score                             0.133189
# textblob_processed_data_polarity_score                                      0.297316
# textblob_processed_data_subjectivity_score                                  0.133189
# vader_processed_data_score                                                  0.429783
# bert_processed_data_sentiment_score                                         1.000000
# roberta_processed_data_sentiment_score                                      0.575118
# close                                                                       0.032694
# close_t+1                                                                   0.032591
# close_t+2                                                                   0.032517
# close_t+3                                                                   0.032183
# close_t+7                                                                   0.031868
#
#                                                  roberta_processed_data_sentiment_score  \
# date                                                                           0.004345
# flair_processed_data_score                                                     0.431989
# spacytextblob_processed_data_polarity_score                                    0.443209
# spacytextblob_processed_data_subjectivity_score                                0.244358
# textblob_processed_data_polarity_score                                         0.443209
# textblob_processed_data_subjectivity_score                                     0.244358
# vader_processed_data_score                                                     0.619424
# bert_processed_data_sentiment_score                                            0.575118
# roberta_processed_data_sentiment_score                                         1.000000
# close                                                                          0.036981
# close_t+1                                                                      0.037086
# close_t+2                                                                      0.036868
# close_t+3                                                                      0.036775
# close_t+7                                                                      0.036749
#
#                                                     close  close_t+1  \
# date                                            -0.715881  -0.716094
# flair_processed_data_score                      -0.072464  -0.072690
# spacytextblob_processed_data_polarity_score     -0.077016  -0.077263
# spacytextblob_processed_data_subjectivity_score -0.116140  -0.116464
# textblob_processed_data_polarity_score          -0.077016  -0.077263
# textblob_processed_data_subjectivity_score      -0.116140  -0.116464
# vader_processed_data_score                       0.003786   0.003926
# bert_processed_data_sentiment_score              0.032694   0.032591
# roberta_processed_data_sentiment_score           0.036981   0.037086
# close                                            1.000000   0.999861
# close_t+1                                        0.999861   1.000000
# close_t+2                                        0.999727   0.999861
# close_t+3                                        0.999591   0.999726
# close_t+7                                        0.999026   0.999169
#
#                                                  close_t+2  close_t+3  \
# date                                             -0.716302  -0.716504
# flair_processed_data_score                       -0.072963  -0.073158
# spacytextblob_processed_data_polarity_score      -0.077274  -0.077363
# spacytextblob_processed_data_subjectivity_score  -0.116523  -0.116524
# textblob_processed_data_polarity_score           -0.077274  -0.077363
# textblob_processed_data_subjectivity_score       -0.116523  -0.116524
# vader_processed_data_score                        0.003934   0.003909
# bert_processed_data_sentiment_score               0.032517   0.032183
# roberta_processed_data_sentiment_score            0.036868   0.036775
# close                                             0.999727   0.999591
# close_t+1                                         0.999861   0.999726
# close_t+2                                         1.000000   0.999860
# close_t+3                                         0.999860   1.000000
# close_t+7                                         0.999312   0.999452
#
#                                                  close_t+7
# date                                             -0.717309
# flair_processed_data_score                       -0.073793
# spacytextblob_processed_data_polarity_score      -0.077213
# spacytextblob_processed_data_subjectivity_score  -0.116282
# textblob_processed_data_polarity_score           -0.077213
# textblob_processed_data_subjectivity_score       -0.116282
# vader_processed_data_score                        0.004216
# bert_processed_data_sentiment_score               0.031868
# roberta_processed_data_sentiment_score            0.036749
# close                                             0.999026
# close_t+1                                         0.999169
# close_t+2                                         0.999312
# close_t+3                                         0.999452
# close_t+7                                         1.000000

# %% [markdown]
# Very bad correlation between all the weighted sentiment features and the closing dates

# %%
# correlation analysis - spearman
data_30min_joined.corr(method='spearman')
# Out:
#                                                      date  \
# date                                             1.000000
# flair_processed_data_score                       0.091912
# spacytextblob_processed_data_polarity_score      0.178838
# spacytextblob_processed_data_subjectivity_score  0.176932
# textblob_processed_data_polarity_score           0.178838
# textblob_processed_data_subjectivity_score       0.176932
# vader_processed_data_score                       0.031789
# bert_processed_data_sentiment_score             -0.044891
# roberta_processed_data_sentiment_score           0.013999
# close                                           -0.692278
# close_t+1                                       -0.692633
# close_t+2                                       -0.692979
# close_t+3                                       -0.693322
# close_t+7                                       -0.694725
#
#                                                  flair_processed_data_score  \
# date                                                               0.091912
# flair_processed_data_score                                         1.000000
# spacytextblob_processed_data_polarity_score                        0.236256
# spacytextblob_processed_data_subjectivity_score                    0.109925
# textblob_processed_data_polarity_score                             0.236256
# textblob_processed_data_subjectivity_score                         0.109925
# vader_processed_data_score                                         0.326891
# bert_processed_data_sentiment_score                                0.580809
# roberta_processed_data_sentiment_score                             0.427771
# close                                                             -0.073363
# close_t+1                                                         -0.073650
# close_t+2                                                         -0.073721
# close_t+3                                                         -0.073958
# close_t+7                                                         -0.074502
#
#                                                  spacytextblob_processed_data_polarity_score  \
# date                                                                                0.178838
# flair_processed_data_score                                                          0.236256
# spacytextblob_processed_data_polarity_score                                         1.000000
# spacytextblob_processed_data_subjectivity_score                                     0.615946
# textblob_processed_data_polarity_score                                              1.000000
# textblob_processed_data_subjectivity_score                                          0.615946
# vader_processed_data_score                                                          0.439090
# bert_processed_data_sentiment_score                                                 0.246170
# roberta_processed_data_sentiment_score                                              0.403540
# close                                                                              -0.076329
# close_t+1                                                                          -0.076917
# close_t+2                                                                          -0.077104
# close_t+3                                                                          -0.077162
# close_t+7                                                                          -0.077500
#
#                                                  spacytextblob_processed_data_subjectivity_score  \
# date                                                                                    0.176932
# flair_processed_data_score                                                              0.109925
# spacytextblob_processed_data_polarity_score                                             0.615946
# spacytextblob_processed_data_subjectivity_score                                         1.000000
# textblob_processed_data_polarity_score                                                  0.615946
# textblob_processed_data_subjectivity_score                                              1.000000
# vader_processed_data_score                                                              0.303257
# bert_processed_data_sentiment_score                                                     0.122030
# roberta_processed_data_sentiment_score                                                  0.255145
# close                                                                                  -0.104368
# close_t+1                                                                              -0.104901
# close_t+2                                                                              -0.104830
# close_t+3                                                                              -0.104884
# close_t+7                                                                              -0.105163
#
#                                                  textblob_processed_data_polarity_score  \
# date                                                                           0.178838
# flair_processed_data_score                                                     0.236256
# spacytextblob_processed_data_polarity_score                                    1.000000
# spacytextblob_processed_data_subjectivity_score                                0.615946
# textblob_processed_data_polarity_score                                         1.000000
# textblob_processed_data_subjectivity_score                                     0.615946
# vader_processed_data_score                                                     0.439090
# bert_processed_data_sentiment_score                                            0.246170
# roberta_processed_data_sentiment_score                                         0.403540
# close                                                                         -0.076329
# close_t+1                                                                     -0.076917
# close_t+2                                                                     -0.077104
# close_t+3                                                                     -0.077162
# close_t+7                                                                     -0.077500
#
#                                                  textblob_processed_data_subjectivity_score  \
# date                                                                               0.176932
# flair_processed_data_score                                                         0.109925
# spacytextblob_processed_data_polarity_score                                        0.615946
# spacytextblob_processed_data_subjectivity_score                                    1.000000
# textblob_processed_data_polarity_score                                             0.615946
# textblob_processed_data_subjectivity_score                                         1.000000
# vader_processed_data_score                                                         0.303257
# bert_processed_data_sentiment_score                                                0.122030
# roberta_processed_data_sentiment_score                                             0.255145
# close                                                                             -0.104368
# close_t+1                                                                         -0.104901
# close_t+2                                                                         -0.104830
# close_t+3                                                                         -0.104884
# close_t+7                                                                         -0.105163
#
#                                                  vader_processed_data_score  \
# date                                                               0.031789
# flair_processed_data_score                                         0.326891
# spacytextblob_processed_data_polarity_score                        0.439090
# spacytextblob_processed_data_subjectivity_score                    0.303257
# textblob_processed_data_polarity_score                             0.439090
# textblob_processed_data_subjectivity_score                         0.303257
# vader_processed_data_score                                         1.000000
# bert_processed_data_sentiment_score                                0.413888
# roberta_processed_data_sentiment_score                             0.599413
# close                                                             -0.000521
# close_t+1                                                         -0.000533
# close_t+2                                                         -0.000527
# close_t+3                                                         -0.000635
# close_t+7                                                         -0.000484
#
#                                                  bert_processed_data_sentiment_score  \
# date                                                                       -0.044891
# flair_processed_data_score                                                  0.580809
# spacytextblob_processed_data_polarity_score                                 0.246170
# spacytextblob_processed_data_subjectivity_score                             0.122030
# textblob_processed_data_polarity_score                                      0.246170
# textblob_processed_data_subjectivity_score                                  0.122030
# vader_processed_data_score                                                  0.413888
# bert_processed_data_sentiment_score                                         1.000000
# roberta_processed_data_sentiment_score                                      0.549224
# close                                                                       0.032503
# close_t+1                                                                   0.032511
# close_t+2                                                                   0.032539
# close_t+3                                                                   0.032181
# close_t+7                                                                   0.032295
#
#                                                  roberta_processed_data_sentiment_score  \
# date                                                                           0.013999
# flair_processed_data_score                                                     0.427771
# spacytextblob_processed_data_polarity_score                                    0.403540
# spacytextblob_processed_data_subjectivity_score                                0.255145
# textblob_processed_data_polarity_score                                         0.403540
# textblob_processed_data_subjectivity_score                                     0.255145
# vader_processed_data_score                                                     0.599413
# bert_processed_data_sentiment_score                                            0.549224
# roberta_processed_data_sentiment_score                                         1.000000
# close                                                                          0.030387
# close_t+1                                                                      0.030213
# close_t+2                                                                      0.029796
# close_t+3                                                                      0.029506
# close_t+7                                                                      0.029257
#
#                                                     close  close_t+1  \
# date                                            -0.692278  -0.692633
# flair_processed_data_score                      -0.073363  -0.073650
# spacytextblob_processed_data_polarity_score     -0.076329  -0.076917
# spacytextblob_processed_data_subjectivity_score -0.104368  -0.104901
# textblob_processed_data_polarity_score          -0.076329  -0.076917
# textblob_processed_data_subjectivity_score      -0.104368  -0.104901
# vader_processed_data_score                      -0.000521  -0.000533
# bert_processed_data_sentiment_score              0.032503   0.032511
# roberta_processed_data_sentiment_score           0.030387   0.030213
# close                                            1.000000   0.999711
# close_t+1                                        0.999711   1.000000
# close_t+2                                        0.999433   0.999712
# close_t+3                                        0.999171   0.999433
# close_t+7                                        0.998078   0.998363
#
#                                                  close_t+2  close_t+3  \
# date                                             -0.692979  -0.693322
# flair_processed_data_score                       -0.073721  -0.073958
# spacytextblob_processed_data_polarity_score      -0.077104  -0.077162
# spacytextblob_processed_data_subjectivity_score  -0.104830  -0.104884
# textblob_processed_data_polarity_score           -0.077104  -0.077162
# textblob_processed_data_subjectivity_score       -0.104830  -0.104884
# vader_processed_data_score                       -0.000527  -0.000635
# bert_processed_data_sentiment_score               0.032539   0.032181
# roberta_processed_data_sentiment_score            0.029796   0.029506
# close                                             0.999433   0.999171
# close_t+1                                         0.999712   0.999433
# close_t+2                                         1.000000   0.999713
# close_t+3                                         0.999713   1.000000
# close_t+7                                         0.998646   0.998921
#
#                                                  close_t+7
# date                                             -0.694725
# flair_processed_data_score                       -0.074502
# spacytextblob_processed_data_polarity_score      -0.077500
# spacytextblob_processed_data_subjectivity_score  -0.105163
# textblob_processed_data_polarity_score           -0.077500
# textblob_processed_data_subjectivity_score       -0.105163
# vader_processed_data_score                       -0.000484
# bert_processed_data_sentiment_score               0.032295
# roberta_processed_data_sentiment_score            0.029257
# close                                             0.998078
# close_t+1                                         0.998363
# close_t+2                                         0.998646
# close_t+3                                         0.998921
# close_t+7                                         1.000000

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_30min_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     46.70
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           1.33e-56
# Time:                        18:21:11   Log-Likelihood:                -90986.
# No. Observations:                8329   AIC:                         1.820e+05
# Df Residuals:                    8322   BIC:                         1.820e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.027e+04    350.466    114.891      0.000    3.96e+04     4.1e+04
# flair_processed_data_score                      -3207.6586    309.091    -10.378      0.000   -3813.555   -2601.762
# spacytextblob_processed_data_polarity_score     -2008.9609    593.631     -3.384      0.001   -3172.625    -845.297
# spacytextblob_processed_data_subjectivity_score -3919.6583    483.233     -8.111      0.000   -4866.916   -2972.400
# textblob_processed_data_polarity_score          -2008.9609    593.631     -3.384      0.001   -3172.625    -845.297
# textblob_processed_data_subjectivity_score      -3919.6583    483.233     -8.111      0.000   -4866.916   -2972.400
# vader_processed_data_score                        410.0100    730.650      0.561      0.575   -1022.247    1842.267
# bert_processed_data_sentiment_score              3783.4300    631.474      5.991      0.000    2545.584    5021.276
# roberta_processed_data_sentiment_score           4649.8624    816.712      5.693      0.000    3048.903    6250.822
# ==============================================================================
# Omnibus:                      982.137   Durbin-Watson:                   0.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.987
# Skew:                           0.124   Prob(JB):                     9.65e-62
# Kurtosis:                       2.135   Cond. No.                     9.39e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.43e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     46.94
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           6.73e-57
# Time:                        18:21:11   Log-Likelihood:                -90985.
# No. Observations:                8329   AIC:                         1.820e+05
# Df Residuals:                    8322   BIC:                         1.820e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.027e+04    350.432    114.908      0.000    3.96e+04     4.1e+04
# flair_processed_data_score                      -3214.0085    309.061    -10.399      0.000   -3819.845   -2608.172
# spacytextblob_processed_data_polarity_score     -2018.2557    593.572     -3.400      0.001   -3181.805    -854.706
# spacytextblob_processed_data_subjectivity_score -3930.3806    483.186     -8.134      0.000   -4877.545   -2983.216
# textblob_processed_data_polarity_score          -2018.2557    593.572     -3.400      0.001   -3181.805    -854.706
# textblob_processed_data_subjectivity_score      -3930.3806    483.186     -8.134      0.000   -4877.545   -2983.216
# vader_processed_data_score                        424.7106    730.579      0.581      0.561   -1007.406    1856.827
# bert_processed_data_sentiment_score              3778.1864    631.412      5.984      0.000    2540.462    5015.911
# roberta_processed_data_sentiment_score           4665.0169    816.632      5.713      0.000    3064.215    6265.819
# ==============================================================================
# Omnibus:                      983.093   Durbin-Watson:                   0.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.889
# Skew:                           0.123   Prob(JB):                     1.01e-61
# Kurtosis:                       2.135   Cond. No.                     9.39e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.43e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     47.00
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           5.71e-57
# Time:                        18:21:11   Log-Likelihood:                -90985.
# No. Observations:                8329   AIC:                         1.820e+05
# Df Residuals:                    8322   BIC:                         1.820e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.027e+04    350.412    114.917      0.000    3.96e+04     4.1e+04
# flair_processed_data_score                      -3221.6123    309.044    -10.424      0.000   -3827.415   -2615.809
# spacytextblob_processed_data_polarity_score     -2012.9156    593.539     -3.391      0.001   -3176.400    -849.431
# spacytextblob_processed_data_subjectivity_score -3933.5490    483.159     -8.141      0.000   -4880.661   -2986.437
# textblob_processed_data_polarity_score          -2012.9156    593.539     -3.391      0.001   -3176.400    -849.431
# textblob_processed_data_subjectivity_score      -3933.5490    483.159     -8.141      0.000   -4880.661   -2986.437
# vader_processed_data_score                        436.1515    730.538      0.597      0.551    -995.884    1868.187
# bert_processed_data_sentiment_score              3787.1541    631.377      5.998      0.000    2549.499    5024.809
# roberta_processed_data_sentiment_score           4645.5522    816.586      5.689      0.000    3044.840    6246.265
# ==============================================================================
# Omnibus:                      986.660   Durbin-Watson:                   0.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.120
# Skew:                           0.122   Prob(JB):                     9.03e-62
# Kurtosis:                       2.134   Cond. No.                     9.39e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.43e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     46.98
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           6.04e-57
# Time:                        18:21:11   Log-Likelihood:                -90985.
# No. Observations:                8329   AIC:                         1.820e+05
# Df Residuals:                    8322   BIC:                         1.820e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.026e+04    350.419    114.903      0.000    3.96e+04     4.1e+04
# flair_processed_data_score                      -3222.0893    309.049    -10.426      0.000   -3827.903   -2616.276
# spacytextblob_processed_data_polarity_score     -2016.6347    593.550     -3.398      0.001   -3180.140    -853.130
# spacytextblob_processed_data_subjectivity_score -3931.7500    483.168     -8.137      0.000   -4878.879   -2984.621
# textblob_processed_data_polarity_score          -2016.6347    593.550     -3.398      0.001   -3180.140    -853.130
# textblob_processed_data_subjectivity_score      -3931.7500    483.168     -8.137      0.000   -4878.879   -2984.621
# vader_processed_data_score                        442.2752    730.551      0.605      0.545    -989.786    1874.337
# bert_processed_data_sentiment_score              3769.5182    631.388      5.970      0.000    2531.841    5007.196
# roberta_processed_data_sentiment_score           4651.3290    816.601      5.696      0.000    3050.588    6252.070
# ==============================================================================
# Omnibus:                      986.676   Durbin-Watson:                   0.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.989
# Skew:                           0.122   Prob(JB):                     9.64e-62
# Kurtosis:                       2.134   Cond. No.                     9.39e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.43e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     47.06
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           4.72e-57
# Time:                        18:21:11   Log-Likelihood:                -90985.
# No. Observations:                8329   AIC:                         1.820e+05
# Df Residuals:                    8322   BIC:                         1.820e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.025e+04    350.415    114.864      0.000    3.96e+04    4.09e+04
# flair_processed_data_score                      -3239.8130    309.046    -10.483      0.000   -3845.621   -2634.005
# spacytextblob_processed_data_polarity_score     -2014.6336    593.544     -3.394      0.001   -3178.127    -851.140
# spacytextblob_processed_data_subjectivity_score -3925.2626    483.163     -8.124      0.000   -4872.382   -2978.143
# textblob_processed_data_polarity_score          -2014.6336    593.544     -3.394      0.001   -3178.127    -851.140
# textblob_processed_data_subjectivity_score      -3925.2626    483.163     -8.124      0.000   -4872.382   -2978.143
# vader_processed_data_score                        471.6606    730.544      0.646      0.519    -960.387    1903.708
# bert_processed_data_sentiment_score              3764.5320    631.382      5.962      0.000    2526.867    5002.197
# roberta_processed_data_sentiment_score           4649.0916    816.593      5.693      0.000    3048.366    6249.817
# ==============================================================================
# Omnibus:                      988.973   Durbin-Watson:                   0.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.698
# Skew:                           0.120   Prob(JB):                     1.11e-61
# Kurtosis:                       2.133   Cond. No.                     9.39e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.43e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 2. 1H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1hr_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     29.99
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           2.08e-35
# Time:                        18:21:11   Log-Likelihood:                -45902.
# No. Observations:                4204   AIC:                         9.182e+04
# Df Residuals:                    4197   BIC:                         9.186e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.062e+04    518.767     78.303      0.000    3.96e+04    4.16e+04
# flair_processed_data_score                      -3039.4979    455.122     -6.678      0.000   -3931.777   -2147.219
# spacytextblob_processed_data_polarity_score     -3906.9527    897.799     -4.352      0.000   -5667.114   -2146.792
# spacytextblob_processed_data_subjectivity_score -3990.3363    724.611     -5.507      0.000   -5410.957   -2569.716
# textblob_processed_data_polarity_score          -3906.9527    897.799     -4.352      0.000   -5667.114   -2146.792
# textblob_processed_data_subjectivity_score      -3990.3363    724.611     -5.507      0.000   -5410.957   -2569.716
# vader_processed_data_score                       1390.9536   1110.521      1.253      0.210    -786.256    3568.163
# bert_processed_data_sentiment_score              5420.4218    940.446      5.764      0.000    3576.650    7264.194
# roberta_processed_data_sentiment_score           4525.8673   1197.053      3.781      0.000    2179.009    6872.726
# ==============================================================================
# Omnibus:                      464.702   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.208
# Skew:                           0.103   Prob(JB):                     4.37e-30
# Kurtosis:                       2.146   Cond. No.                     8.24e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.37e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     30.01
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           1.96e-35
# Time:                        18:21:11   Log-Likelihood:                -45902.
# No. Observations:                4204   AIC:                         9.182e+04
# Df Residuals:                    4197   BIC:                         9.186e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.062e+04    518.756     78.303      0.000    3.96e+04    4.16e+04
# flair_processed_data_score                      -3047.5868    455.112     -6.696      0.000   -3939.847   -2155.326
# spacytextblob_processed_data_polarity_score     -3903.1186    897.780     -4.348      0.000   -5663.243   -2142.994
# spacytextblob_processed_data_subjectivity_score -3990.2693    724.595     -5.507      0.000   -5410.860   -2569.679
# textblob_processed_data_polarity_score          -3903.1186    897.780     -4.348      0.000   -5663.243   -2142.994
# textblob_processed_data_subjectivity_score      -3990.2693    724.595     -5.507      0.000   -5410.860   -2569.679
# vader_processed_data_score                       1391.4060   1110.498      1.253      0.210    -785.758    3568.570
# bert_processed_data_sentiment_score              5429.6360    940.426      5.774      0.000    3585.903    7273.369
# roberta_processed_data_sentiment_score           4517.1625   1197.028      3.774      0.000    2170.353    6863.972
# ==============================================================================
# Omnibus:                      466.827   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.363
# Skew:                           0.102   Prob(JB):                     4.04e-30
# Kurtosis:                       2.145   Cond. No.                     8.24e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.37e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     29.96
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           2.29e-35
# Time:                        18:21:11   Log-Likelihood:                -45902.
# No. Observations:                4204   AIC:                         9.182e+04
# Df Residuals:                    4197   BIC:                         9.186e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.061e+04    518.792     78.275      0.000    3.96e+04    4.16e+04
# flair_processed_data_score                      -3060.1957    455.143     -6.724      0.000   -3952.518   -2167.874
# spacytextblob_processed_data_polarity_score     -3877.2154    897.842     -4.318      0.000   -5637.461   -2116.970
# spacytextblob_processed_data_subjectivity_score -3987.5152    724.645     -5.503      0.000   -5408.204   -2566.827
# textblob_processed_data_polarity_score          -3877.2154    897.842     -4.318      0.000   -5637.461   -2116.970
# textblob_processed_data_subjectivity_score      -3987.5152    724.645     -5.503      0.000   -5408.204   -2566.827
# vader_processed_data_score                       1406.6705   1110.574      1.267      0.205    -770.643    3583.984
# bert_processed_data_sentiment_score              5439.3564    940.491      5.784      0.000    3595.496    7283.216
# roberta_processed_data_sentiment_score           4501.4013   1197.111      3.760      0.000    2154.431    6848.372
# ==============================================================================
# Omnibus:                      466.560   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.266
# Skew:                           0.101   Prob(JB):                     4.24e-30
# Kurtosis:                       2.145   Cond. No.                     8.24e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.37e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     29.79
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           3.64e-35
# Time:                        18:21:11   Log-Likelihood:                -45903.
# No. Observations:                4204   AIC:                         9.182e+04
# Df Residuals:                    4197   BIC:                         9.186e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.059e+04    518.838     78.234      0.000    3.96e+04    4.16e+04
# flair_processed_data_score                      -3065.3411    455.184     -6.734      0.000   -3957.742   -2172.940
# spacytextblob_processed_data_polarity_score     -3864.8019    897.922     -4.304      0.000   -5625.204   -2104.400
# spacytextblob_processed_data_subjectivity_score -3976.7878    724.710     -5.487      0.000   -5397.603   -2555.973
# textblob_processed_data_polarity_score          -3864.8019    897.922     -4.304      0.000   -5625.204   -2104.400
# textblob_processed_data_subjectivity_score      -3976.7878    724.710     -5.487      0.000   -5397.603   -2555.973
# vader_processed_data_score                       1434.7332   1110.673      1.292      0.197    -742.774    3612.241
# bert_processed_data_sentiment_score              5405.3812    940.575      5.747      0.000    3561.357    7249.405
# roberta_processed_data_sentiment_score           4485.7029   1197.217      3.747      0.000    2138.523    6832.883
# ==============================================================================
# Omnibus:                      467.591   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.316
# Skew:                           0.101   Prob(JB):                     4.13e-30
# Kurtosis:                       2.144   Cond. No.                     8.24e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.37e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     30.10
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           1.55e-35
# Time:                        18:21:11   Log-Likelihood:                -45901.
# No. Observations:                4204   AIC:                         9.182e+04
# Df Residuals:                    4197   BIC:                         9.186e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.062e+04    518.621     78.316      0.000    3.96e+04    4.16e+04
# flair_processed_data_score                      -3108.4595    454.994     -6.832      0.000   -4000.488   -2216.430
# spacytextblob_processed_data_polarity_score     -3895.4236    897.547     -4.340      0.000   -5655.091   -2135.756
# spacytextblob_processed_data_subjectivity_score -3967.9779    724.407     -5.478      0.000   -5388.200   -2547.756
# textblob_processed_data_polarity_score          -3895.4236    897.547     -4.340      0.000   -5655.091   -2135.756
# textblob_processed_data_subjectivity_score      -3967.9779    724.407     -5.478      0.000   -5388.200   -2547.756
# vader_processed_data_score                       1391.4595   1110.210      1.253      0.210    -785.139    3568.058
# bert_processed_data_sentiment_score              5480.1593    940.182      5.829      0.000    3636.905    7323.414
# roberta_processed_data_sentiment_score           4448.5826   1196.718      3.717      0.000    2102.382    6794.783
# ==============================================================================
# Omnibus:                      470.776   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.263
# Skew:                           0.096   Prob(JB):                     4.25e-30
# Kurtosis:                       2.143   Cond. No.                     8.24e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.37e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 3. 4H frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_4hr_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     9.136
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           8.93e-10
# Time:                        18:21:11   Log-Likelihood:                -12040.
# No. Observations:                1103   AIC:                         2.409e+04
# Df Residuals:                    1096   BIC:                         2.413e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.139e+04   1142.741     36.223      0.000    3.92e+04    4.36e+04
# flair_processed_data_score                      -3002.9689   1022.099     -2.938      0.003   -5008.461    -997.477
# spacytextblob_processed_data_polarity_score     -4992.8934   2130.524     -2.344      0.019   -9173.260    -812.527
# spacytextblob_processed_data_subjectivity_score -6246.1619   1713.969     -3.644      0.000   -9609.193   -2883.130
# textblob_processed_data_polarity_score          -4992.8934   2130.524     -2.344      0.019   -9173.260    -812.527
# textblob_processed_data_subjectivity_score      -6246.1619   1713.969     -3.644      0.000   -9609.193   -2883.130
# vader_processed_data_score                       4732.5219   2537.461      1.865      0.062    -246.308    9711.352
# bert_processed_data_sentiment_score              5426.7708   2115.036      2.566      0.010    1276.793    9576.749
# roberta_processed_data_sentiment_score           4688.5958   2652.637      1.768      0.077    -516.224    9893.416
# ==============================================================================
# Omnibus:                      121.523   Durbin-Watson:                   0.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.911
# Skew:                           0.100   Prob(JB):                     1.59e-08
# Kurtosis:                       2.139   Cond. No.                     2.43e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.81e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     9.163
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           8.33e-10
# Time:                        18:21:11   Log-Likelihood:                -12040.
# No. Observations:                1103   AIC:                         2.409e+04
# Df Residuals:                    1096   BIC:                         2.413e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.136e+04   1142.475     36.205      0.000    3.91e+04    4.36e+04
# flair_processed_data_score                      -3054.2903   1021.861     -2.989      0.003   -5059.316   -1049.265
# spacytextblob_processed_data_polarity_score     -4962.6704   2130.028     -2.330      0.020   -9142.064    -783.276
# spacytextblob_processed_data_subjectivity_score -6243.6065   1713.570     -3.644      0.000   -9605.856   -2881.357
# textblob_processed_data_polarity_score          -4962.6704   2130.028     -2.330      0.020   -9142.064    -783.276
# textblob_processed_data_subjectivity_score      -6243.6065   1713.570     -3.644      0.000   -9605.856   -2881.357
# vader_processed_data_score                       4817.2388   2536.871      1.899      0.058    -160.433    9794.911
# bert_processed_data_sentiment_score              5478.5158   2114.544      2.591      0.010    1329.503    9627.528
# roberta_processed_data_sentiment_score           4622.6229   2652.020      1.743      0.082    -580.986    9826.232
# ==============================================================================
# Omnibus:                      123.074   Durbin-Watson:                   0.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.007
# Skew:                           0.097   Prob(JB):                     1.52e-08
# Kurtosis:                       2.136   Cond. No.                     2.43e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.81e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     9.272
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           6.23e-10
# Time:                        18:21:11   Log-Likelihood:                -12040.
# No. Observations:                1103   AIC:                         2.409e+04
# Df Residuals:                    1096   BIC:                         2.413e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.137e+04   1142.422     36.212      0.000    3.91e+04    4.36e+04
# flair_processed_data_score                      -3151.7824   1021.813     -3.084      0.002   -5156.714   -1146.851
# spacytextblob_processed_data_polarity_score     -4993.8368   2129.928     -2.345      0.019   -9173.034    -814.640
# spacytextblob_processed_data_subjectivity_score -6247.5891   1713.490     -3.646      0.000   -9609.680   -2885.498
# textblob_processed_data_polarity_score          -4993.8368   2129.928     -2.345      0.019   -9173.034    -814.640
# textblob_processed_data_subjectivity_score      -6247.5891   1713.490     -3.646      0.000   -9609.680   -2885.498
# vader_processed_data_score                       4912.3012   2536.751      1.936      0.053     -65.136    9889.739
# bert_processed_data_sentiment_score              5552.4391   2114.445      2.626      0.009    1403.622    9701.256
# roberta_processed_data_sentiment_score           4540.8481   2651.895      1.712      0.087    -662.516    9744.213
# ==============================================================================
# Omnibus:                      122.883   Durbin-Watson:                   0.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.884
# Skew:                           0.093   Prob(JB):                     1.61e-08
# Kurtosis:                       2.136   Cond. No.                     2.43e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.81e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     9.366
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           4.85e-10
# Time:                        18:21:11   Log-Likelihood:                -12040.
# No. Observations:                1103   AIC:                         2.409e+04
# Df Residuals:                    1096   BIC:                         2.413e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.138e+04   1142.175     36.225      0.000    3.91e+04    4.36e+04
# flair_processed_data_score                      -3166.9785   1021.593     -3.100      0.002   -5171.477   -1162.480
# spacytextblob_processed_data_polarity_score     -4983.2368   2129.468     -2.340      0.019   -9161.532    -804.942
# spacytextblob_processed_data_subjectivity_score -6258.3775   1713.120     -3.653      0.000   -9619.742   -2897.013
# textblob_processed_data_polarity_score          -4983.2368   2129.468     -2.340      0.019   -9161.532    -804.942
# textblob_processed_data_subjectivity_score      -6258.3775   1713.120     -3.653      0.000   -9619.742   -2897.013
# vader_processed_data_score                       4988.1420   2536.203      1.967      0.049      11.779    9964.505
# bert_processed_data_sentiment_score              5716.7460   2113.988      2.704      0.007    1568.825    9864.667
# roberta_processed_data_sentiment_score           4440.8229   2651.322      1.675      0.094    -761.418    9643.064
# ==============================================================================
# Omnibus:                      122.609   Durbin-Watson:                   0.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.775
# Skew:                           0.091   Prob(JB):                     1.70e-08
# Kurtosis:                       2.137   Cond. No.                     2.43e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.81e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     9.290
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           5.94e-10
# Time:                        18:21:11   Log-Likelihood:                -12042.
# No. Observations:                1103   AIC:                         2.410e+04
# Df Residuals:                    1096   BIC:                         2.413e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.139e+04   1144.154     36.176      0.000    3.91e+04    4.36e+04
# flair_processed_data_score                      -3156.6914   1023.363     -3.085      0.002   -5164.663   -1148.719
# spacytextblob_processed_data_polarity_score     -4968.8488   2133.158     -2.329      0.020   -9154.384    -783.313
# spacytextblob_processed_data_subjectivity_score -6247.1081   1716.088     -3.640      0.000   -9614.298   -2879.918
# textblob_processed_data_polarity_score          -4968.8488   2133.158     -2.329      0.020   -9154.384    -783.313
# textblob_processed_data_subjectivity_score      -6247.1081   1716.088     -3.640      0.000   -9614.298   -2879.918
# vader_processed_data_score                       5018.0038   2540.598      1.975      0.049      33.017       1e+04
# bert_processed_data_sentiment_score              5703.6366   2117.652      2.693      0.007    1548.527    9858.746
# roberta_processed_data_sentiment_score           4396.5029   2655.917      1.655      0.098    -814.753    9607.759
# ==============================================================================
# Omnibus:                      125.901   Durbin-Watson:                   0.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.126
# Skew:                           0.088   Prob(JB):                     1.43e-08
# Kurtosis:                       2.131   Cond. No.                     2.43e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.81e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 4. 6H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_6hr_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     6.528
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           9.95e-07
# Time:                        18:21:11   Log-Likelihood:                -8144.9
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.634e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.148e+04   1449.634     28.612      0.000    3.86e+04    4.43e+04
# flair_processed_data_score                      -2127.5552   1309.481     -1.625      0.105   -4698.302     443.192
# spacytextblob_processed_data_polarity_score     -6962.5111   2787.830     -2.497      0.013   -1.24e+04   -1489.501
# spacytextblob_processed_data_subjectivity_score -6523.0855   2230.265     -2.925      0.004   -1.09e+04   -2144.675
# textblob_processed_data_polarity_score          -6962.5111   2787.830     -2.497      0.013   -1.24e+04   -1489.501
# textblob_processed_data_subjectivity_score      -6523.0855   2230.265     -2.925      0.004   -1.09e+04   -2144.675
# vader_processed_data_score                       6281.4531   3318.369      1.893      0.059    -233.100    1.28e+04
# bert_processed_data_sentiment_score              4858.9433   2656.171      1.829      0.068    -355.596    1.01e+04
# roberta_processed_data_sentiment_score           5327.8919   3415.942      1.560      0.119   -1378.215     1.2e+04
# ==============================================================================
# Omnibus:                       87.013   Durbin-Watson:                   0.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.947
# Skew:                           0.088   Prob(JB):                     3.83e-06
# Kurtosis:                       2.122   Cond. No.                     9.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.37e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     6.659
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           7.11e-07
# Time:                        18:21:11   Log-Likelihood:                -8144.4
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.634e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                             4.15e+04   1448.512     28.649      0.000    3.87e+04    4.43e+04
# flair_processed_data_score                      -2211.3409   1308.468     -1.690      0.091   -4780.098     357.416
# spacytextblob_processed_data_polarity_score     -7004.2792   2785.672     -2.514      0.012   -1.25e+04   -1535.505
# spacytextblob_processed_data_subjectivity_score -6635.9922   2228.539     -2.978      0.003    -1.1e+04   -2260.970
# textblob_processed_data_polarity_score          -7004.2792   2785.672     -2.514      0.012   -1.25e+04   -1535.505
# textblob_processed_data_subjectivity_score      -6635.9922   2228.539     -2.978      0.003    -1.1e+04   -2260.970
# vader_processed_data_score                       6502.8545   3315.801      1.961      0.050      -6.657     1.3e+04
# bert_processed_data_sentiment_score              4762.2885   2654.115      1.794      0.073    -448.216    9972.792
# roberta_processed_data_sentiment_score           5347.9916   3413.298      1.567      0.118   -1352.925     1.2e+04
# ==============================================================================
# Omnibus:                       86.664   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.819
# Skew:                           0.084   Prob(JB):                     4.08e-06
# Kurtosis:                       2.122   Cond. No.                     9.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.37e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     6.816
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           4.74e-07
# Time:                        18:21:11   Log-Likelihood:                -8143.9
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.633e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.159e+04   1447.637     28.727      0.000    3.87e+04    4.44e+04
# flair_processed_data_score                      -2320.1054   1307.678     -1.774      0.076   -4887.311     247.100
# spacytextblob_processed_data_polarity_score     -7013.6075   2783.990     -2.519      0.012   -1.25e+04   -1548.136
# spacytextblob_processed_data_subjectivity_score -6715.5551   2227.193     -3.015      0.003   -1.11e+04   -2343.176
# textblob_processed_data_polarity_score          -7013.6075   2783.990     -2.519      0.012   -1.25e+04   -1548.136
# textblob_processed_data_subjectivity_score      -6715.5551   2227.193     -3.015      0.003   -1.11e+04   -2343.176
# vader_processed_data_score                       6714.3283   3313.798      2.026      0.043     208.749    1.32e+04
# bert_processed_data_sentiment_score              5050.9187   2652.512      1.904      0.057    -156.438    1.03e+04
# roberta_processed_data_sentiment_score           4980.1556   3411.237      1.460      0.145   -1716.713    1.17e+04
# ==============================================================================
# Omnibus:                       87.241   Durbin-Watson:                   0.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.819
# Skew:                           0.079   Prob(JB):                     4.08e-06
# Kurtosis:                       2.121   Cond. No.                     9.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.37e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     6.850
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           4.34e-07
# Time:                        18:21:11   Log-Likelihood:                -8145.5
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.634e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.164e+04   1450.737     28.703      0.000    3.88e+04    4.45e+04
# flair_processed_data_score                      -2393.0964   1310.478     -1.826      0.068   -4965.799     179.606
# spacytextblob_processed_data_polarity_score     -7041.7669   2789.951     -2.524      0.012   -1.25e+04   -1564.593
# spacytextblob_processed_data_subjectivity_score -6669.9077   2231.962     -2.988      0.003   -1.11e+04   -2288.167
# textblob_processed_data_polarity_score          -7041.7669   2789.951     -2.524      0.012   -1.25e+04   -1564.593
# textblob_processed_data_subjectivity_score      -6669.9077   2231.962     -2.988      0.003   -1.11e+04   -2288.167
# vader_processed_data_score                       6499.1178   3320.893      1.957      0.051     -20.391     1.3e+04
# bert_processed_data_sentiment_score              5304.5924   2658.192      1.996      0.046      86.086    1.05e+04
# roberta_processed_data_sentiment_score           5056.3508   3418.541      1.479      0.140   -1654.857    1.18e+04
# ==============================================================================
# Omnibus:                       90.857   Durbin-Watson:                   0.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.174
# Skew:                           0.072   Prob(JB):                     3.42e-06
# Kurtosis:                       2.112   Cond. No.                     9.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.37e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     6.798
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):           4.96e-07
# Time:                        18:21:11   Log-Likelihood:                -8153.5
# No. Observations:                 746   AIC:                         1.632e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.169e+04   1466.452     28.430      0.000    3.88e+04    4.46e+04
# flair_processed_data_score                      -2517.8106   1324.673     -1.901      0.058   -5118.382      82.760
# spacytextblob_processed_data_polarity_score     -6952.4689   2820.173     -2.465      0.014   -1.25e+04   -1415.964
# spacytextblob_processed_data_subjectivity_score -6721.1372   2256.139     -2.979      0.003   -1.12e+04   -2291.931
# textblob_processed_data_polarity_score          -6952.4689   2820.173     -2.465      0.014   -1.25e+04   -1415.964
# textblob_processed_data_subjectivity_score      -6721.1372   2256.139     -2.979      0.003   -1.12e+04   -2291.931
# vader_processed_data_score                       6792.8726   3356.867      2.024      0.043     202.742    1.34e+04
# bert_processed_data_sentiment_score              5369.1521   2686.986      1.998      0.046      94.116    1.06e+04
# roberta_processed_data_sentiment_score           5110.4348   3455.572      1.479      0.140   -1673.472    1.19e+04
# ==============================================================================
# Omnibus:                       85.906   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.590
# Skew:                           0.076   Prob(JB):                     4.58e-06
# Kurtosis:                       2.124   Cond. No.                     9.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.37e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 5. 1D Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1d_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     3.071
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):            0.00657
# Time:                        18:21:11   Log-Likelihood:                -2544.0
# No. Observations:                 233   AIC:                             5102.
# Df Residuals:                     226   BIC:                             5126.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.166e+04   3142.163     13.259      0.000    3.55e+04    4.79e+04
# flair_processed_data_score                      -3882.0101   3060.558     -1.268      0.206   -9912.889    2148.868
# spacytextblob_processed_data_polarity_score     -1.191e+04   6283.346     -1.896      0.059   -2.43e+04     469.457
# spacytextblob_processed_data_subjectivity_score -7288.7379   4985.847     -1.462      0.145   -1.71e+04    2535.955
# textblob_processed_data_polarity_score          -1.191e+04   6283.346     -1.896      0.059   -2.43e+04     469.457
# textblob_processed_data_subjectivity_score      -7288.7379   4985.847     -1.462      0.145   -1.71e+04    2535.955
# vader_processed_data_score                       7471.5014   7224.132      1.034      0.302   -6763.768    2.17e+04
# bert_processed_data_sentiment_score              9411.7130   5656.018      1.664      0.097   -1733.562    2.06e+04
# roberta_processed_data_sentiment_score           9833.0741   7694.897      1.278      0.203   -5329.845     2.5e+04
# ==============================================================================
# Omnibus:                       22.536   Durbin-Watson:                   0.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.331
# Skew:                           0.008   Prob(JB):                       0.0256
# Kurtosis:                       2.131   Cond. No.                     4.47e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.79e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     3.155
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):            0.00544
# Time:                        18:21:11   Log-Likelihood:                -2543.1
# No. Observations:                 233   AIC:                             5100.
# Df Residuals:                     226   BIC:                             5124.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.165e+04   3130.532     13.304      0.000    3.55e+04    4.78e+04
# flair_processed_data_score                      -4150.1663   3049.229     -1.361      0.175   -1.02e+04    1858.388
# spacytextblob_processed_data_polarity_score     -1.187e+04   6260.087     -1.896      0.059   -2.42e+04     468.483
# spacytextblob_processed_data_subjectivity_score -7460.2085   4967.392     -1.502      0.135   -1.72e+04    2328.118
# textblob_processed_data_polarity_score          -1.187e+04   6260.087     -1.896      0.059   -2.42e+04     468.483
# textblob_processed_data_subjectivity_score      -7460.2085   4967.392     -1.502      0.135   -1.72e+04    2328.118
# vader_processed_data_score                       8508.0376   7197.391      1.182      0.238   -5674.539    2.27e+04
# bert_processed_data_sentiment_score              9491.8943   5635.082      1.684      0.093   -1612.126    2.06e+04
# roberta_processed_data_sentiment_score           8972.9996   7666.413      1.170      0.243   -6133.792    2.41e+04
# ==============================================================================
# Omnibus:                       23.965   Durbin-Watson:                   0.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.565
# Skew:                          -0.012   Prob(JB):                       0.0228
# Kurtosis:                       2.118   Cond. No.                     4.47e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.79e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     3.174
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):            0.00522
# Time:                        18:21:11   Log-Likelihood:                -2545.4
# No. Observations:                 233   AIC:                             5105.
# Df Residuals:                     226   BIC:                             5129.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.144e+04   3160.944     13.109      0.000    3.52e+04    4.77e+04
# flair_processed_data_score                      -5164.5237   3078.850     -1.677      0.095   -1.12e+04     902.401
# spacytextblob_processed_data_polarity_score     -1.184e+04   6320.901     -1.873      0.062   -2.43e+04     615.341
# spacytextblob_processed_data_subjectivity_score -7049.8494   5015.647     -1.406      0.161   -1.69e+04    2833.565
# textblob_processed_data_polarity_score          -1.184e+04   6320.901     -1.873      0.062   -2.43e+04     615.341
# textblob_processed_data_subjectivity_score      -7049.8494   5015.647     -1.406      0.161   -1.69e+04    2833.565
# vader_processed_data_score                       8567.8195   7267.310      1.179      0.240   -5752.533    2.29e+04
# bert_processed_data_sentiment_score              1.019e+04   5689.824      1.791      0.075   -1021.949    2.14e+04
# roberta_processed_data_sentiment_score           9242.2494   7740.888      1.194      0.234   -6011.297    2.45e+04
# ==============================================================================
# Omnibus:                       22.646   Durbin-Watson:                   0.148
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.350
# Skew:                          -0.009   Prob(JB):                       0.0254
# Kurtosis:                       2.130   Cond. No.                     4.47e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.79e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     3.095
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):            0.00622
# Time:                        18:21:11   Log-Likelihood:                -2547.8
# No. Observations:                 233   AIC:                             5110.
# Df Residuals:                     226   BIC:                             5134.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.165e+04   3194.676     13.038      0.000    3.54e+04    4.79e+04
# flair_processed_data_score                      -4769.8572   3111.707     -1.533      0.127   -1.09e+04    1361.812
# spacytextblob_processed_data_polarity_score     -1.205e+04   6388.355     -1.887      0.060   -2.46e+04     534.813
# spacytextblob_processed_data_subjectivity_score -7004.9399   5069.173     -1.382      0.168    -1.7e+04    2983.947
# textblob_processed_data_polarity_score          -1.205e+04   6388.355     -1.887      0.060   -2.46e+04     534.813
# textblob_processed_data_subjectivity_score      -7004.9399   5069.173     -1.382      0.168    -1.7e+04    2983.947
# vader_processed_data_score                       8323.3650   7344.865      1.133      0.258   -6149.810    2.28e+04
# bert_processed_data_sentiment_score              1.029e+04   5750.544      1.789      0.075   -1045.926    2.16e+04
# roberta_processed_data_sentiment_score           9143.9983   7823.497      1.169      0.244   -6272.329    2.46e+04
# ==============================================================================
# Omnibus:                       23.822   Durbin-Watson:                   0.163
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.540
# Skew:                           0.009   Prob(JB):                       0.0231
# Kurtosis:                       2.119   Cond. No.                     4.47e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.79e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     2.780
# Date:                Fri, 22 Dec 2023   Prob (F-statistic):             0.0125
# Time:                        18:21:11   Log-Likelihood:                -2547.3
# No. Observations:                 233   AIC:                             5109.
# Df Residuals:                     226   BIC:                             5133.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.184e+04   3186.970     13.127      0.000    3.56e+04    4.81e+04
# flair_processed_data_score                      -4770.8869   3104.201     -1.537      0.126   -1.09e+04    1345.992
# spacytextblob_processed_data_polarity_score     -1.222e+04   6372.946     -1.918      0.056   -2.48e+04     335.002
# spacytextblob_processed_data_subjectivity_score -5512.7339   5056.945     -1.090      0.277   -1.55e+04    4452.059
# textblob_processed_data_polarity_score          -1.222e+04   6372.946     -1.918      0.056   -2.48e+04     335.002
# textblob_processed_data_subjectivity_score      -5512.7339   5056.945     -1.090      0.277   -1.55e+04    4452.059
# vader_processed_data_score                       5681.0978   7327.148      0.775      0.439   -8757.166    2.01e+04
# bert_processed_data_sentiment_score              1.134e+04   5736.673      1.976      0.049      33.721    2.26e+04
# roberta_processed_data_sentiment_score           8527.0179   7804.626      1.093      0.276   -6852.123    2.39e+04
# ==============================================================================
# Omnibus:                       33.072   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.851
# Skew:                          -0.028   Prob(JB):                       0.0120
# Kurtosis:                       2.047   Cond. No.                     4.47e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.79e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
