# %%
import pandas as pd
import numpy as np
import os
import datetime
os.chdir('/home/ubuntu/Masters Thesis/')
from scripts.utilities.data_joining import GetModellingData

# %% [markdown]
# Data without Bots and De-emoji text processing

# %%
bitcoin_hourly = pd.read_csv("/mnt/bitcoin_hourly_prices_till_2023-03-30.csv", lineterminator='\n')
bitcoin_minutely = pd.read_csv("/mnt/bitcoin_price_minutely_data_till_2023_03_30.csv", lineterminator='\n')

# %%
bitcoin_minutely
# Out:
#                time exchange fsym tsym     close      high       low  \
# 0        1606780800   CCCAGG  BTC  USD  19704.72  19714.44  19686.87
# 1        1606780860   CCCAGG  BTC  USD  19682.63  19706.49  19674.34
# 2        1606780920   CCCAGG  BTC  USD  19688.59  19691.33  19654.82
# 3        1606780980   CCCAGG  BTC  USD  19664.79  19697.12  19659.91
# 4        1606781040   CCCAGG  BTC  USD  19628.40  19665.60  19623.03
# ...             ...      ...  ...  ...       ...       ...       ...
# 1223995  1680220500   CCCAGG  BTC  USD  28038.57  28044.74  28032.44
# 1223996  1680220560   CCCAGG  BTC  USD  28037.36  28043.24  28031.83
# 1223997  1680220620   CCCAGG  BTC  USD  28031.20  28039.71  28030.25
# 1223998  1680220680   CCCAGG  BTC  USD  28037.81  28038.74  28029.52
# 1223999  1680220740   CCCAGG  BTC  USD  28040.71  28052.54  28036.36
#
#              open  volumefrom    volumeto
# 0        19686.87      58.620  1151502.04
# 1        19704.72     132.800  2614001.65
# 2        19682.63      55.390  1090096.41
# 3        19688.59      51.070  1004714.46
# 4        19664.79     109.540  2149088.17
# ...           ...         ...         ...
# 1223995  28032.49      11.500   322442.59
# 1223996  28038.57      20.120   564252.17
# 1223997  28037.36      12.290   344664.77
# 1223998  28031.20       8.527   239073.67
# 1223999  28037.81      75.070  2105709.79
#
# [1224000 rows x 10 columns]

# %%
data_30min = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_False_interval_30T.csv", lineterminator='\n')
data_1hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_False_interval_1H.csv", lineterminator='\n')
data_4hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_False_interval_4H.csv", lineterminator='\n')
data_6hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_False_interval_6H.csv", lineterminator='\n')
data_1day = pd.read_csv("/home/ubuntu/Masters Thesis/data/bot_data/weighted_scores_bots_processed_False_interval_D.csv", lineterminator='\n')

# %%
data_30min = data_30min[~data_30min['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_1hrs = data_1hrs[~data_1hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_4hrs = data_4hrs[~data_4hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_6hrs = data_6hrs[~data_6hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_1day = data_1day[~data_1day['spacytextblob_nonprocessed_data_polarity_score'].isna()]

data_30min = data_30min.drop(columns=['Unnamed: 0'])
data_1hrs = data_1hrs.drop(columns=['Unnamed: 0'])
data_4hrs = data_4hrs.drop(columns=['Unnamed: 0'])
data_6hrs = data_6hrs.drop(columns=['Unnamed: 0'])
data_1day = data_1day.drop(columns=['Unnamed: 0'])

# %%
bitcoin_minutely = bitcoin_minutely.rename(columns={'time': 'date'})
bitcoin_minutely['date'] = bitcoin_minutely['date'].apply(datetime.datetime.utcfromtimestamp)
bitcoin_hourly = bitcoin_hourly.rename(columns={'datetimes': 'date'})
bitcoin_hourly['date'] = pd.to_datetime(bitcoin_hourly['date'])

# %%
data_30min_joined = GetModellingData(data=data_30min, bitcoin_data=bitcoin_minutely, frequency='30T').get_data_for_feature_analysis()
data_1hr_joined = GetModellingData(data=data_1hrs, bitcoin_data=bitcoin_hourly, frequency='1H').get_data_for_feature_analysis()
data_4hr_joined = GetModellingData(data=data_4hrs, bitcoin_data=bitcoin_hourly, frequency='4H').get_data_for_feature_analysis()
data_6hr_joined = GetModellingData(data=data_6hrs, bitcoin_data=bitcoin_hourly, frequency='6H').get_data_for_feature_analysis()
data_1d_joined = GetModellingData(data=data_1day, bitcoin_data=bitcoin_hourly, frequency='1D').get_data_for_feature_analysis()
# Out:
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])

# %%
data_30min_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_30min_joined.dropna(inplace=True)
data_1hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1hr_joined.dropna(inplace=True)
data_4hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_4hr_joined.dropna(inplace=True)
data_6hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_6hr_joined.dropna(inplace=True)
data_1d_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1d_joined.dropna(inplace=True)

# %% [markdown]
# ### Plots and Analysis

# %% [markdown]
# 1. 30T Frequency

# %%
# correlation analysis - pearson
data_30min_joined.corr()
# Out:
#                                                         date  \
# date                                                1.000000
# flair_nonprocessed_data_score                       0.080227
# spacytextblob_nonprocessed_data_polarity_score      0.158670
# spacytextblob_nonprocessed_data_subjectivity_score  0.156003
# textblob_nonprocessed_data_polarity_score           0.158670
# textblob_nonprocessed_data_subjectivity_score       0.156003
# vader_nonprocessed_data_score                       0.036886
# bert_nonprocessed_data_sentiment_score              0.018110
# roberta_nonprocessed_data_sentiment_score           0.030189
# close                                              -0.715881
# close_t+1                                          -0.716094
# close_t+2                                          -0.716302
# close_t+3                                          -0.716504
# close_t+7                                          -0.717309
#
#                                                     flair_nonprocessed_data_score  \
# date                                                                     0.080227
# flair_nonprocessed_data_score                                            1.000000
# spacytextblob_nonprocessed_data_polarity_score                           0.233035
# spacytextblob_nonprocessed_data_subjectivity_score                       0.058846
# textblob_nonprocessed_data_polarity_score                                0.233035
# textblob_nonprocessed_data_subjectivity_score                            0.058846
# vader_nonprocessed_data_score                                            0.312416
# bert_nonprocessed_data_sentiment_score                                   0.550319
# roberta_nonprocessed_data_sentiment_score                                0.450290
# close                                                                   -0.044563
# close_t+1                                                               -0.044885
# close_t+2                                                               -0.045175
# close_t+3                                                               -0.045270
# close_t+7                                                               -0.045970
#
#                                                     spacytextblob_nonprocessed_data_polarity_score  \
# date                                                                                      0.158670
# flair_nonprocessed_data_score                                                             0.233035
# spacytextblob_nonprocessed_data_polarity_score                                            1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                        0.572427
# textblob_nonprocessed_data_polarity_score                                                 1.000000
# textblob_nonprocessed_data_subjectivity_score                                             0.572427
# vader_nonprocessed_data_score                                                             0.487624
# bert_nonprocessed_data_sentiment_score                                                    0.377420
# roberta_nonprocessed_data_sentiment_score                                                 0.450228
# close                                                                                    -0.070231
# close_t+1                                                                                -0.070580
# close_t+2                                                                                -0.070737
# close_t+3                                                                                -0.070736
# close_t+7                                                                                -0.070869
#
#                                                     spacytextblob_nonprocessed_data_subjectivity_score  \
# date                                                                                         0.156003
# flair_nonprocessed_data_score                                                                0.058846
# spacytextblob_nonprocessed_data_polarity_score                                               0.572427
# spacytextblob_nonprocessed_data_subjectivity_score                                           1.000000
# textblob_nonprocessed_data_polarity_score                                                    0.572427
# textblob_nonprocessed_data_subjectivity_score                                                1.000000
# vader_nonprocessed_data_score                                                                0.296411
# bert_nonprocessed_data_sentiment_score                                                       0.208882
# roberta_nonprocessed_data_sentiment_score                                                    0.258667
# close                                                                                       -0.088990
# close_t+1                                                                                   -0.089397
# close_t+2                                                                                   -0.089580
# close_t+3                                                                                   -0.089642
# close_t+7                                                                                   -0.089676
#
#                                                     textblob_nonprocessed_data_polarity_score  \
# date                                                                                 0.158670
# flair_nonprocessed_data_score                                                        0.233035
# spacytextblob_nonprocessed_data_polarity_score                                       1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.572427
# textblob_nonprocessed_data_polarity_score                                            1.000000
# textblob_nonprocessed_data_subjectivity_score                                        0.572427
# vader_nonprocessed_data_score                                                        0.487624
# bert_nonprocessed_data_sentiment_score                                               0.377420
# roberta_nonprocessed_data_sentiment_score                                            0.450228
# close                                                                               -0.070231
# close_t+1                                                                           -0.070580
# close_t+2                                                                           -0.070737
# close_t+3                                                                           -0.070736
# close_t+7                                                                           -0.070869
#
#                                                     textblob_nonprocessed_data_subjectivity_score  \
# date                                                                                     0.156003
# flair_nonprocessed_data_score                                                            0.058846
# spacytextblob_nonprocessed_data_polarity_score                                           0.572427
# spacytextblob_nonprocessed_data_subjectivity_score                                       1.000000
# textblob_nonprocessed_data_polarity_score                                                0.572427
# textblob_nonprocessed_data_subjectivity_score                                            1.000000
# vader_nonprocessed_data_score                                                            0.296411
# bert_nonprocessed_data_sentiment_score                                                   0.208882
# roberta_nonprocessed_data_sentiment_score                                                0.258667
# close                                                                                   -0.088990
# close_t+1                                                                               -0.089397
# close_t+2                                                                               -0.089580
# close_t+3                                                                               -0.089642
# close_t+7                                                                               -0.089676
#
#                                                     vader_nonprocessed_data_score  \
# date                                                                     0.036886
# flair_nonprocessed_data_score                                            0.312416
# spacytextblob_nonprocessed_data_polarity_score                           0.487624
# spacytextblob_nonprocessed_data_subjectivity_score                       0.296411
# textblob_nonprocessed_data_polarity_score                                0.487624
# textblob_nonprocessed_data_subjectivity_score                            0.296411
# vader_nonprocessed_data_score                                            1.000000
# bert_nonprocessed_data_sentiment_score                                   0.463409
# roberta_nonprocessed_data_sentiment_score                                0.580461
# close                                                                    0.007610
# close_t+1                                                                0.007641
# close_t+2                                                                0.007608
# close_t+3                                                                0.007611
# close_t+7                                                                0.007959
#
#                                                     bert_nonprocessed_data_sentiment_score  \
# date                                                                              0.018110
# flair_nonprocessed_data_score                                                     0.550319
# spacytextblob_nonprocessed_data_polarity_score                                    0.377420
# spacytextblob_nonprocessed_data_subjectivity_score                                0.208882
# textblob_nonprocessed_data_polarity_score                                         0.377420
# textblob_nonprocessed_data_subjectivity_score                                     0.208882
# vader_nonprocessed_data_score                                                     0.463409
# bert_nonprocessed_data_sentiment_score                                            1.000000
# roberta_nonprocessed_data_sentiment_score                                         0.612383
# close                                                                            -0.002890
# close_t+1                                                                        -0.002868
# close_t+2                                                                        -0.002900
# close_t+3                                                                        -0.003056
# close_t+7                                                                        -0.003114
#
#                                                     roberta_nonprocessed_data_sentiment_score  \
# date                                                                                 0.030189
# flair_nonprocessed_data_score                                                        0.450290
# spacytextblob_nonprocessed_data_polarity_score                                       0.450228
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.258667
# textblob_nonprocessed_data_polarity_score                                            0.450228
# textblob_nonprocessed_data_subjectivity_score                                        0.258667
# vader_nonprocessed_data_score                                                        0.580461
# bert_nonprocessed_data_sentiment_score                                               0.612383
# roberta_nonprocessed_data_sentiment_score                                            1.000000
# close                                                                                0.022662
# close_t+1                                                                            0.022781
# close_t+2                                                                            0.022557
# close_t+3                                                                            0.022422
# close_t+7                                                                            0.022301
#
#                                                        close  close_t+1  \
# date                                               -0.715881  -0.716094
# flair_nonprocessed_data_score                      -0.044563  -0.044885
# spacytextblob_nonprocessed_data_polarity_score     -0.070231  -0.070580
# spacytextblob_nonprocessed_data_subjectivity_score -0.088990  -0.089397
# textblob_nonprocessed_data_polarity_score          -0.070231  -0.070580
# textblob_nonprocessed_data_subjectivity_score      -0.088990  -0.089397
# vader_nonprocessed_data_score                       0.007610   0.007641
# bert_nonprocessed_data_sentiment_score             -0.002890  -0.002868
# roberta_nonprocessed_data_sentiment_score           0.022662   0.022781
# close                                               1.000000   0.999861
# close_t+1                                           0.999861   1.000000
# close_t+2                                           0.999727   0.999861
# close_t+3                                           0.999591   0.999726
# close_t+7                                           0.999026   0.999169
#
#                                                     close_t+2  close_t+3  \
# date                                                -0.716302  -0.716504
# flair_nonprocessed_data_score                       -0.045175  -0.045270
# spacytextblob_nonprocessed_data_polarity_score      -0.070737  -0.070736
# spacytextblob_nonprocessed_data_subjectivity_score  -0.089580  -0.089642
# textblob_nonprocessed_data_polarity_score           -0.070737  -0.070736
# textblob_nonprocessed_data_subjectivity_score       -0.089580  -0.089642
# vader_nonprocessed_data_score                        0.007608   0.007611
# bert_nonprocessed_data_sentiment_score              -0.002900  -0.003056
# roberta_nonprocessed_data_sentiment_score            0.022557   0.022422
# close                                                0.999727   0.999591
# close_t+1                                            0.999861   0.999726
# close_t+2                                            1.000000   0.999860
# close_t+3                                            0.999860   1.000000
# close_t+7                                            0.999312   0.999452
#
#                                                     close_t+7
# date                                                -0.717309
# flair_nonprocessed_data_score                       -0.045970
# spacytextblob_nonprocessed_data_polarity_score      -0.070869
# spacytextblob_nonprocessed_data_subjectivity_score  -0.089676
# textblob_nonprocessed_data_polarity_score           -0.070869
# textblob_nonprocessed_data_subjectivity_score       -0.089676
# vader_nonprocessed_data_score                        0.007959
# bert_nonprocessed_data_sentiment_score              -0.003114
# roberta_nonprocessed_data_sentiment_score            0.022301
# close                                                0.999026
# close_t+1                                            0.999169
# close_t+2                                            0.999312
# close_t+3                                            0.999452
# close_t+7                                            1.000000

# %% [markdown]
# Very bad correlation between all the weighted sentiment features and the closing dates

# %%
# correlation analysis - spearman
data_30min_joined.corr(method='spearman')
# Out:
#                                                         date  \
# date                                                1.000000
# flair_nonprocessed_data_score                       0.067933
# spacytextblob_nonprocessed_data_polarity_score      0.188241
# spacytextblob_nonprocessed_data_subjectivity_score  0.163059
# textblob_nonprocessed_data_polarity_score           0.188241
# textblob_nonprocessed_data_subjectivity_score       0.163059
# vader_nonprocessed_data_score                       0.060693
# bert_nonprocessed_data_sentiment_score              0.028843
# roberta_nonprocessed_data_sentiment_score           0.045918
# close                                              -0.692278
# close_t+1                                          -0.692633
# close_t+2                                          -0.692979
# close_t+3                                          -0.693322
# close_t+7                                          -0.694725
#
#                                                     flair_nonprocessed_data_score  \
# date                                                                     0.067933
# flair_nonprocessed_data_score                                            1.000000
# spacytextblob_nonprocessed_data_polarity_score                           0.191189
# spacytextblob_nonprocessed_data_subjectivity_score                       0.044621
# textblob_nonprocessed_data_polarity_score                                0.191189
# textblob_nonprocessed_data_subjectivity_score                            0.044621
# vader_nonprocessed_data_score                                            0.297956
# bert_nonprocessed_data_sentiment_score                                   0.544376
# roberta_nonprocessed_data_sentiment_score                                0.423600
# close                                                                   -0.049584
# close_t+1                                                               -0.049863
# close_t+2                                                               -0.050069
# close_t+3                                                               -0.050066
# close_t+7                                                               -0.050701
#
#                                                     spacytextblob_nonprocessed_data_polarity_score  \
# date                                                                                      0.188241
# flair_nonprocessed_data_score                                                             0.191189
# spacytextblob_nonprocessed_data_polarity_score                                            1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                        0.621249
# textblob_nonprocessed_data_polarity_score                                                 1.000000
# textblob_nonprocessed_data_subjectivity_score                                             0.621249
# vader_nonprocessed_data_score                                                             0.491529
# bert_nonprocessed_data_sentiment_score                                                    0.332815
# roberta_nonprocessed_data_sentiment_score                                                 0.416471
# close                                                                                    -0.064306
# close_t+1                                                                                -0.065053
# close_t+2                                                                                -0.065409
# close_t+3                                                                                -0.065515
# close_t+7                                                                                -0.066352
#
#                                                     spacytextblob_nonprocessed_data_subjectivity_score  \
# date                                                                                         0.163059
# flair_nonprocessed_data_score                                                                0.044621
# spacytextblob_nonprocessed_data_polarity_score                                               0.621249
# spacytextblob_nonprocessed_data_subjectivity_score                                           1.000000
# textblob_nonprocessed_data_polarity_score                                                    0.621249
# textblob_nonprocessed_data_subjectivity_score                                                1.000000
# vader_nonprocessed_data_score                                                                0.336642
# bert_nonprocessed_data_sentiment_score                                                       0.194233
# roberta_nonprocessed_data_sentiment_score                                                    0.272187
# close                                                                                       -0.076900
# close_t+1                                                                                   -0.077635
# close_t+2                                                                                   -0.077810
# close_t+3                                                                                   -0.077915
# close_t+7                                                                                   -0.078840
#
#                                                     textblob_nonprocessed_data_polarity_score  \
# date                                                                                 0.188241
# flair_nonprocessed_data_score                                                        0.191189
# spacytextblob_nonprocessed_data_polarity_score                                       1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.621249
# textblob_nonprocessed_data_polarity_score                                            1.000000
# textblob_nonprocessed_data_subjectivity_score                                        0.621249
# vader_nonprocessed_data_score                                                        0.491529
# bert_nonprocessed_data_sentiment_score                                               0.332815
# roberta_nonprocessed_data_sentiment_score                                            0.416471
# close                                                                               -0.064306
# close_t+1                                                                           -0.065053
# close_t+2                                                                           -0.065409
# close_t+3                                                                           -0.065515
# close_t+7                                                                           -0.066352
#
#                                                     textblob_nonprocessed_data_subjectivity_score  \
# date                                                                                     0.163059
# flair_nonprocessed_data_score                                                            0.044621
# spacytextblob_nonprocessed_data_polarity_score                                           0.621249
# spacytextblob_nonprocessed_data_subjectivity_score                                       1.000000
# textblob_nonprocessed_data_polarity_score                                                0.621249
# textblob_nonprocessed_data_subjectivity_score                                            1.000000
# vader_nonprocessed_data_score                                                            0.336642
# bert_nonprocessed_data_sentiment_score                                                   0.194233
# roberta_nonprocessed_data_sentiment_score                                                0.272187
# close                                                                                   -0.076900
# close_t+1                                                                               -0.077635
# close_t+2                                                                               -0.077810
# close_t+3                                                                               -0.077915
# close_t+7                                                                               -0.078840
#
#                                                     vader_nonprocessed_data_score  \
# date                                                                     0.060693
# flair_nonprocessed_data_score                                            0.297956
# spacytextblob_nonprocessed_data_polarity_score                           0.491529
# spacytextblob_nonprocessed_data_subjectivity_score                       0.336642
# textblob_nonprocessed_data_polarity_score                                0.491529
# textblob_nonprocessed_data_subjectivity_score                            0.336642
# vader_nonprocessed_data_score                                            1.000000
# bert_nonprocessed_data_sentiment_score                                   0.445829
# roberta_nonprocessed_data_sentiment_score                                0.560823
# close                                                                    0.001573
# close_t+1                                                                0.001359
# close_t+2                                                                0.001157
# close_t+3                                                                0.001023
# close_t+7                                                                0.000885
#
#                                                     bert_nonprocessed_data_sentiment_score  \
# date                                                                              0.028843
# flair_nonprocessed_data_score                                                     0.544376
# spacytextblob_nonprocessed_data_polarity_score                                    0.332815
# spacytextblob_nonprocessed_data_subjectivity_score                                0.194233
# textblob_nonprocessed_data_polarity_score                                         0.332815
# textblob_nonprocessed_data_subjectivity_score                                     0.194233
# vader_nonprocessed_data_score                                                     0.445829
# bert_nonprocessed_data_sentiment_score                                            1.000000
# roberta_nonprocessed_data_sentiment_score                                         0.583648
# close                                                                            -0.004988
# close_t+1                                                                        -0.004912
# close_t+2                                                                        -0.004907
# close_t+3                                                                        -0.005113
# close_t+7                                                                        -0.004804
#
#                                                     roberta_nonprocessed_data_sentiment_score  \
# date                                                                                 0.045918
# flair_nonprocessed_data_score                                                        0.423600
# spacytextblob_nonprocessed_data_polarity_score                                       0.416471
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.272187
# textblob_nonprocessed_data_polarity_score                                            0.416471
# textblob_nonprocessed_data_subjectivity_score                                        0.272187
# vader_nonprocessed_data_score                                                        0.560823
# bert_nonprocessed_data_sentiment_score                                               0.583648
# roberta_nonprocessed_data_sentiment_score                                            1.000000
# close                                                                                0.020962
# close_t+1                                                                            0.020951
# close_t+2                                                                            0.020679
# close_t+3                                                                            0.020436
# close_t+7                                                                            0.019932
#
#                                                        close  close_t+1  \
# date                                               -0.692278  -0.692633
# flair_nonprocessed_data_score                      -0.049584  -0.049863
# spacytextblob_nonprocessed_data_polarity_score     -0.064306  -0.065053
# spacytextblob_nonprocessed_data_subjectivity_score -0.076900  -0.077635
# textblob_nonprocessed_data_polarity_score          -0.064306  -0.065053
# textblob_nonprocessed_data_subjectivity_score      -0.076900  -0.077635
# vader_nonprocessed_data_score                       0.001573   0.001359
# bert_nonprocessed_data_sentiment_score             -0.004988  -0.004912
# roberta_nonprocessed_data_sentiment_score           0.020962   0.020951
# close                                               1.000000   0.999711
# close_t+1                                           0.999711   1.000000
# close_t+2                                           0.999433   0.999712
# close_t+3                                           0.999171   0.999433
# close_t+7                                           0.998078   0.998363
#
#                                                     close_t+2  close_t+3  \
# date                                                -0.692979  -0.693322
# flair_nonprocessed_data_score                       -0.050069  -0.050066
# spacytextblob_nonprocessed_data_polarity_score      -0.065409  -0.065515
# spacytextblob_nonprocessed_data_subjectivity_score  -0.077810  -0.077915
# textblob_nonprocessed_data_polarity_score           -0.065409  -0.065515
# textblob_nonprocessed_data_subjectivity_score       -0.077810  -0.077915
# vader_nonprocessed_data_score                        0.001157   0.001023
# bert_nonprocessed_data_sentiment_score              -0.004907  -0.005113
# roberta_nonprocessed_data_sentiment_score            0.020679   0.020436
# close                                                0.999433   0.999171
# close_t+1                                            0.999712   0.999433
# close_t+2                                            1.000000   0.999713
# close_t+3                                            0.999713   1.000000
# close_t+7                                            0.998646   0.998921
#
#                                                     close_t+7
# date                                                -0.694725
# flair_nonprocessed_data_score                       -0.050701
# spacytextblob_nonprocessed_data_polarity_score      -0.066352
# spacytextblob_nonprocessed_data_subjectivity_score  -0.078840
# textblob_nonprocessed_data_polarity_score           -0.066352
# textblob_nonprocessed_data_subjectivity_score       -0.078840
# vader_nonprocessed_data_score                        0.000885
# bert_nonprocessed_data_sentiment_score              -0.004804
# roberta_nonprocessed_data_sentiment_score            0.019932
# close                                                0.998078
# close_t+1                                            0.998363
# close_t+2                                            0.998646
# close_t+3                                            0.998921
# close_t+7                                            1.000000

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_30min_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     24.44
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           7.17e-29
# Time:                        13:25:54   Log-Likelihood:                -91051.
# No. Observations:                8329   AIC:                         1.821e+05
# Df Residuals:                    8322   BIC:                         1.822e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.922e+04    398.951     98.311      0.000    3.84e+04       4e+04
# flair_nonprocessed_data_score                      -1875.5579    306.617     -6.117      0.000   -2476.603   -1274.513
# spacytextblob_nonprocessed_data_polarity_score     -2386.5264    564.765     -4.226      0.000   -3493.607   -1279.446
# spacytextblob_nonprocessed_data_subjectivity_score -2904.3340    470.249     -6.176      0.000   -3826.139   -1982.529
# textblob_nonprocessed_data_polarity_score          -2386.5264    564.765     -4.226      0.000   -3493.607   -1279.446
# textblob_nonprocessed_data_subjectivity_score      -2904.3340    470.249     -6.176      0.000   -3826.139   -1982.529
# vader_nonprocessed_data_score                       1721.7318    710.915      2.422      0.015     328.162    3115.302
# bert_nonprocessed_data_sentiment_score               894.2286    683.545      1.308      0.191    -445.690    2234.147
# roberta_nonprocessed_data_sentiment_score           4013.5088    813.432      4.934      0.000    2418.980    5608.037
# ==============================================================================
# Omnibus:                     1191.988   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              311.239
# Skew:                           0.140   Prob(JB):                     2.60e-68
# Kurtosis:                       2.095   Cond. No.                     2.25e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.66e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     24.71
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           3.34e-29
# Time:                        13:25:54   Log-Likelihood:                -91051.
# No. Observations:                8329   AIC:                         1.821e+05
# Df Residuals:                    8322   BIC:                         1.822e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.923e+04    398.907     98.338      0.000    3.84e+04       4e+04
# flair_nonprocessed_data_score                      -1888.7578    306.583     -6.161      0.000   -2489.737   -1287.778
# spacytextblob_nonprocessed_data_polarity_score     -2399.4012    564.703     -4.249      0.000   -3506.360   -1292.442
# spacytextblob_nonprocessed_data_subjectivity_score -2917.4799    470.197     -6.205      0.000   -3839.184   -1995.776
# textblob_nonprocessed_data_polarity_score          -2399.4012    564.703     -4.249      0.000   -3506.360   -1292.442
# textblob_nonprocessed_data_subjectivity_score      -2917.4799    470.197     -6.205      0.000   -3839.184   -1995.776
# vader_nonprocessed_data_score                       1729.1083    710.837      2.432      0.015     335.692    3122.525
# bert_nonprocessed_data_sentiment_score               904.5801    683.470      1.324      0.186    -435.192    2244.352
# roberta_nonprocessed_data_sentiment_score           4034.3635    813.342      4.960      0.000    2440.010    5628.717
# ==============================================================================
# Omnibus:                     1190.455   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.808
# Skew:                           0.139   Prob(JB):                     3.23e-68
# Kurtosis:                       2.096   Cond. No.                     2.25e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.66e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     24.80
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.61e-29
# Time:                        13:25:54   Log-Likelihood:                -91050.
# No. Observations:                8329   AIC:                         1.821e+05
# Df Residuals:                    8322   BIC:                         1.822e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.924e+04    398.881     98.366      0.000    3.85e+04       4e+04
# flair_nonprocessed_data_score                      -1897.2593    306.563     -6.189      0.000   -2498.199   -1296.320
# spacytextblob_nonprocessed_data_polarity_score     -2401.0360    564.666     -4.252      0.000   -3507.922   -1294.150
# spacytextblob_nonprocessed_data_subjectivity_score -2923.7348    470.166     -6.219      0.000   -3845.378   -2002.092
# textblob_nonprocessed_data_polarity_score          -2401.0360    564.666     -4.252      0.000   -3507.922   -1294.150
# textblob_nonprocessed_data_subjectivity_score      -2923.7348    470.166     -6.219      0.000   -3845.378   -2002.092
# vader_nonprocessed_data_score                       1737.9398    710.789      2.445      0.015     344.616    3131.264
# bert_nonprocessed_data_sentiment_score               919.0920    683.425      1.345      0.179    -420.591    2258.775
# roberta_nonprocessed_data_sentiment_score           4019.0959    813.288      4.942      0.000    2424.848    5613.343
# ==============================================================================
# Omnibus:                     1193.428   Durbin-Watson:                   0.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.898
# Skew:                           0.139   Prob(JB):                     3.09e-68
# Kurtosis:                       2.095   Cond. No.                     2.25e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.66e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     24.80
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.62e-29
# Time:                        13:25:54   Log-Likelihood:                -91050.
# No. Observations:                8329   AIC:                         1.821e+05
# Df Residuals:                    8322   BIC:                         1.822e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.924e+04    398.885     98.364      0.000    3.85e+04       4e+04
# flair_nonprocessed_data_score                      -1897.5703    306.566     -6.190      0.000   -2498.517   -1296.624
# spacytextblob_nonprocessed_data_polarity_score     -2396.6222    564.672     -4.244      0.000   -3503.521   -1289.724
# spacytextblob_nonprocessed_data_subjectivity_score -2927.2851    470.172     -6.226      0.000   -3848.939   -2005.631
# textblob_nonprocessed_data_polarity_score          -2396.6222    564.672     -4.244      0.000   -3503.521   -1289.724
# textblob_nonprocessed_data_subjectivity_score      -2927.2851    470.172     -6.226      0.000   -3848.939   -2005.631
# vader_nonprocessed_data_score                       1744.4118    710.798      2.454      0.014     351.071    3137.752
# bert_nonprocessed_data_sentiment_score               912.5835    683.433      1.335      0.182    -427.115    2252.282
# roberta_nonprocessed_data_sentiment_score           4011.7080    813.298      4.933      0.000    2417.442    5605.974
# ==============================================================================
# Omnibus:                     1193.305   Durbin-Watson:                   0.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.731
# Skew:                           0.138   Prob(JB):                     3.35e-68
# Kurtosis:                       2.095   Cond. No.                     2.25e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.66e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.00
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.46e-29
# Time:                        13:25:54   Log-Likelihood:                -91050.
# No. Observations:                8329   AIC:                         1.821e+05
# Df Residuals:                    8322   BIC:                         1.822e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.924e+04    398.865     98.368      0.000    3.85e+04       4e+04
# flair_nonprocessed_data_score                      -1920.2777    306.550     -6.264      0.000   -2521.193   -1319.363
# spacytextblob_nonprocessed_data_polarity_score     -2407.6486    564.643     -4.264      0.000   -3514.489   -1300.808
# spacytextblob_nonprocessed_data_subjectivity_score -2929.5022    470.147     -6.231      0.000   -3851.108   -2007.897
# textblob_nonprocessed_data_polarity_score          -2407.6486    564.643     -4.264      0.000   -3514.489   -1300.808
# textblob_nonprocessed_data_subjectivity_score      -2929.5022    470.147     -6.231      0.000   -3851.108   -2007.897
# vader_nonprocessed_data_score                       1782.4841    710.761      2.508      0.012     389.216    3175.752
# bert_nonprocessed_data_sentiment_score               929.6586    683.397      1.360      0.174    -409.970    2269.287
# roberta_nonprocessed_data_sentiment_score           4001.1144    813.255      4.920      0.000    2406.931    5595.297
# ==============================================================================
# Omnibus:                     1192.139   Durbin-Watson:                   0.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.025
# Skew:                           0.136   Prob(JB):                     4.77e-68
# Kurtosis:                       2.095   Cond. No.                     2.25e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.66e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 2. 1H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     15.22
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.52e-17
# Time:                        13:25:54   Log-Likelihood:                -45945.
# No. Observations:                4204   AIC:                         9.190e+04
# Df Residuals:                    4197   BIC:                         9.195e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.997e+04    581.675     68.714      0.000    3.88e+04    4.11e+04
# flair_nonprocessed_data_score                      -1213.8358    457.994     -2.650      0.008   -2111.747    -315.925
# spacytextblob_nonprocessed_data_polarity_score     -4058.9955    845.347     -4.802      0.000   -5716.324   -2401.667
# spacytextblob_nonprocessed_data_subjectivity_score -3026.1139    709.334     -4.266      0.000   -4416.784   -1635.444
# textblob_nonprocessed_data_polarity_score          -4058.9955    845.347     -4.802      0.000   -5716.324   -2401.667
# textblob_nonprocessed_data_subjectivity_score      -3026.1139    709.334     -4.266      0.000   -4416.784   -1635.444
# vader_nonprocessed_data_score                       2327.8247   1079.048      2.157      0.031     212.319    4443.331
# bert_nonprocessed_data_sentiment_score              2071.4260    996.499      2.079      0.038     117.760    4025.092
# roberta_nonprocessed_data_sentiment_score           3131.2403   1197.281      2.615      0.009     783.935    5478.545
# ==============================================================================
# Omnibus:                      603.023   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              154.592
# Skew:                           0.121   Prob(JB):                     2.70e-34
# Kurtosis:                       2.092   Cond. No.                     7.35e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.26e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     15.24
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.40e-17
# Time:                        13:25:54   Log-Likelihood:                -45945.
# No. Observations:                4204   AIC:                         9.190e+04
# Df Residuals:                    4197   BIC:                         9.195e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.999e+04    581.664     68.743      0.000    3.88e+04    4.11e+04
# flair_nonprocessed_data_score                      -1228.6767    457.986     -2.683      0.007   -2126.571    -330.782
# spacytextblob_nonprocessed_data_polarity_score     -4044.7747    845.331     -4.785      0.000   -5702.072   -2387.478
# spacytextblob_nonprocessed_data_subjectivity_score -3039.4237    709.321     -4.285      0.000   -4430.068   -1648.780
# textblob_nonprocessed_data_polarity_score          -4044.7747    845.331     -4.785      0.000   -5702.072   -2387.478
# textblob_nonprocessed_data_subjectivity_score      -3039.4237    709.321     -4.285      0.000   -4430.068   -1648.780
# vader_nonprocessed_data_score                       2344.1199   1079.028      2.172      0.030     228.654    4459.586
# bert_nonprocessed_data_sentiment_score              2104.4603    996.480      2.112      0.035     150.831    4058.089
# roberta_nonprocessed_data_sentiment_score           3085.6962   1197.259      2.577      0.010     738.435    5432.957
# ==============================================================================
# Omnibus:                      603.480   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              154.506
# Skew:                           0.120   Prob(JB):                     2.82e-34
# Kurtosis:                       2.092   Cond. No.                     7.35e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.26e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     15.22
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.55e-17
# Time:                        13:25:54   Log-Likelihood:                -45945.
# No. Observations:                4204   AIC:                         9.190e+04
# Df Residuals:                    4197   BIC:                         9.195e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.999e+04    581.691     68.744      0.000    3.88e+04    4.11e+04
# flair_nonprocessed_data_score                      -1242.1180    458.007     -2.712      0.007   -2140.054    -344.182
# spacytextblob_nonprocessed_data_polarity_score     -4034.7391    845.370     -4.773      0.000   -5692.112   -2377.366
# spacytextblob_nonprocessed_data_subjectivity_score -3036.7182    709.353     -4.281      0.000   -4427.426   -1646.010
# textblob_nonprocessed_data_polarity_score          -4034.7391    845.370     -4.773      0.000   -5692.112   -2377.366
# textblob_nonprocessed_data_subjectivity_score      -3036.7182    709.353     -4.281      0.000   -4427.426   -1646.010
# vader_nonprocessed_data_score                       2368.8752   1079.078      2.195      0.028     253.312    4484.439
# bert_nonprocessed_data_sentiment_score              2144.5038    996.526      2.152      0.031     190.785    4098.223
# roberta_nonprocessed_data_sentiment_score           3047.4998   1197.314      2.545      0.011     700.131    5394.869
# ==============================================================================
# Omnibus:                      603.273   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              154.361
# Skew:                           0.119   Prob(JB):                     3.03e-34
# Kurtosis:                       2.092   Cond. No.                     7.35e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.26e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     15.22
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.54e-17
# Time:                        13:25:54   Log-Likelihood:                -45945.
# No. Observations:                4204   AIC:                         9.190e+04
# Df Residuals:                    4197   BIC:                         9.195e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.997e+04    581.676     68.708      0.000    3.88e+04    4.11e+04
# flair_nonprocessed_data_score                      -1250.8089    457.995     -2.731      0.006   -2148.722    -352.896
# spacytextblob_nonprocessed_data_polarity_score     -4046.9407    845.349     -4.787      0.000   -5704.272   -2389.609
# spacytextblob_nonprocessed_data_subjectivity_score -3026.7195    709.336     -4.267      0.000   -4417.393   -1636.046
# textblob_nonprocessed_data_polarity_score          -4046.9407    845.349     -4.787      0.000   -5704.272   -2389.609
# textblob_nonprocessed_data_subjectivity_score      -3026.7195    709.336     -4.267      0.000   -4417.393   -1636.046
# vader_nonprocessed_data_score                       2410.5459   1079.051      2.234      0.026     295.035    4526.057
# bert_nonprocessed_data_sentiment_score              2107.2465    996.501      2.115      0.035     153.576    4060.917
# roberta_nonprocessed_data_sentiment_score           3057.8067   1197.284      2.554      0.011     710.496    5405.117
# ==============================================================================
# Omnibus:                      602.279   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              154.146
# Skew:                           0.119   Prob(JB):                     3.37e-34
# Kurtosis:                       2.092   Cond. No.                     7.35e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.26e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     15.58
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           9.20e-18
# Time:                        13:25:54   Log-Likelihood:                -45943.
# No. Observations:                4204   AIC:                         9.190e+04
# Df Residuals:                    4197   BIC:                         9.194e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               4.002e+04    581.408     68.838      0.000    3.89e+04    4.12e+04
# flair_nonprocessed_data_score                      -1326.2297    457.784     -2.897      0.004   -2223.729    -428.730
# spacytextblob_nonprocessed_data_polarity_score     -4083.5585    844.959     -4.833      0.000   -5740.126   -2426.991
# spacytextblob_nonprocessed_data_subjectivity_score -3047.7009    709.009     -4.299      0.000   -4437.733   -1657.669
# textblob_nonprocessed_data_polarity_score          -4083.5585    844.959     -4.833      0.000   -5740.126   -2426.991
# textblob_nonprocessed_data_subjectivity_score      -3047.7009    709.009     -4.299      0.000   -4437.733   -1657.669
# vader_nonprocessed_data_score                       2384.2164   1078.553      2.211      0.027     269.681    4498.752
# bert_nonprocessed_data_sentiment_score              2222.6846    996.042      2.232      0.026     269.915    4175.454
# roberta_nonprocessed_data_sentiment_score           3048.6479   1196.732      2.547      0.011     702.420    5394.876
# ==============================================================================
# Omnibus:                      606.819   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              154.069
# Skew:                           0.115   Prob(JB):                     3.50e-34
# Kurtosis:                       2.091   Cond. No.                     7.35e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.26e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 3. 4H frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_4hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     4.716
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           9.45e-05
# Time:                        13:25:54   Log-Likelihood:                -12053.
# No. Observations:                1103   AIC:                         2.412e+04
# Df Residuals:                    1096   BIC:                         2.416e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                3.96e+04   1272.697     31.118      0.000    3.71e+04    4.21e+04
# flair_nonprocessed_data_score                        217.4924   1020.579      0.213      0.831   -1785.018    2220.003
# spacytextblob_nonprocessed_data_polarity_score     -5476.7178   1994.543     -2.746      0.006   -9390.272   -1563.163
# spacytextblob_nonprocessed_data_subjectivity_score -3846.1994   1687.412     -2.279      0.023   -7157.123    -535.276
# textblob_nonprocessed_data_polarity_score          -5476.7178   1994.543     -2.746      0.006   -9390.272   -1563.163
# textblob_nonprocessed_data_subjectivity_score      -3846.1994   1687.412     -2.279      0.023   -7157.123    -535.276
# vader_nonprocessed_data_score                       5542.8767   2449.800      2.263      0.024     736.050    1.03e+04
# bert_nonprocessed_data_sentiment_score              -666.2893   2174.467     -0.306      0.759   -4932.879    3600.300
# roberta_nonprocessed_data_sentiment_score           2826.1132   2607.580      1.084      0.279   -2290.300    7942.526
# ==============================================================================
# Omnibus:                      156.809   Durbin-Watson:                   0.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.084
# Skew:                           0.122   Prob(JB):                     1.20e-09
# Kurtosis:                       2.086   Cond. No.                     3.17e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.76e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     4.752
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           8.62e-05
# Time:                        13:25:54   Log-Likelihood:                -12053.
# No. Observations:                1103   AIC:                         2.412e+04
# Df Residuals:                    1096   BIC:                         2.415e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                3.96e+04   1272.366     31.127      0.000    3.71e+04    4.21e+04
# flair_nonprocessed_data_score                        179.2364   1020.314      0.176      0.861   -1822.752    2181.225
# spacytextblob_nonprocessed_data_polarity_score     -5476.0882   1994.024     -2.746      0.006   -9388.624   -1563.553
# spacytextblob_nonprocessed_data_subjectivity_score -3869.1079   1686.973     -2.294      0.022   -7179.170    -559.046
# textblob_nonprocessed_data_polarity_score          -5476.0882   1994.024     -2.746      0.006   -9388.624   -1563.553
# textblob_nonprocessed_data_subjectivity_score      -3869.1079   1686.973     -2.294      0.022   -7179.170    -559.046
# vader_nonprocessed_data_score                       5691.9516   2449.162      2.324      0.020     886.376    1.05e+04
# bert_nonprocessed_data_sentiment_score              -552.9364   2173.901     -0.254      0.799   -4818.415    3712.542
# roberta_nonprocessed_data_sentiment_score           2724.6392   2606.901      1.045      0.296   -2390.441    7839.720
# ==============================================================================
# Omnibus:                      157.836   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.999
# Skew:                           0.116   Prob(JB):                     1.25e-09
# Kurtosis:                       2.085   Cond. No.                     3.17e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.76e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     4.799
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           7.64e-05
# Time:                        13:25:54   Log-Likelihood:                -12053.
# No. Observations:                1103   AIC:                         2.412e+04
# Df Residuals:                    1096   BIC:                         2.415e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.964e+04   1272.508     31.155      0.000    3.71e+04    4.21e+04
# flair_nonprocessed_data_score                         61.1781   1020.428      0.060      0.952   -1941.035    2063.391
# spacytextblob_nonprocessed_data_polarity_score     -5534.6439   1994.247     -2.775      0.006   -9447.617   -1621.671
# spacytextblob_nonprocessed_data_subjectivity_score -3878.9439   1687.162     -2.299      0.022   -7189.376    -568.512
# textblob_nonprocessed_data_polarity_score          -5534.6439   1994.247     -2.775      0.006   -9447.617   -1621.671
# textblob_nonprocessed_data_subjectivity_score      -3878.9439   1687.162     -2.299      0.022   -7189.376    -568.512
# vader_nonprocessed_data_score                       5697.8872   2449.436      2.326      0.020     891.774    1.05e+04
# bert_nonprocessed_data_sentiment_score              -411.9610   2174.144     -0.189      0.850   -4677.917    3853.995
# roberta_nonprocessed_data_sentiment_score           2751.7061   2607.193      1.055      0.291   -2363.947    7867.359
# ==============================================================================
# Omnibus:                      159.090   Durbin-Watson:                   0.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.024
# Skew:                           0.113   Prob(JB):                     1.24e-09
# Kurtosis:                       2.083   Cond. No.                     3.17e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.76e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     4.834
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           7.00e-05
# Time:                        13:25:54   Log-Likelihood:                -12053.
# No. Observations:                1103   AIC:                         2.412e+04
# Df Residuals:                    1096   BIC:                         2.415e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.967e+04   1272.428     31.180      0.000    3.72e+04    4.22e+04
# flair_nonprocessed_data_score                        -63.7731   1020.364     -0.063      0.950   -2065.860    1938.314
# spacytextblob_nonprocessed_data_polarity_score     -5514.6006   1994.122     -2.765      0.006   -9427.328   -1601.873
# spacytextblob_nonprocessed_data_subjectivity_score -3925.5837   1687.056     -2.327      0.020   -7235.808    -615.360
# textblob_nonprocessed_data_polarity_score          -5514.6006   1994.122     -2.765      0.006   -9427.328   -1601.873
# textblob_nonprocessed_data_subjectivity_score      -3925.5837   1687.056     -2.327      0.020   -7235.808    -615.360
# vader_nonprocessed_data_score                       5726.9677   2449.282      2.338      0.020     921.157    1.05e+04
# bert_nonprocessed_data_sentiment_score              -260.7825   2174.008     -0.120      0.905   -4526.470    4004.905
# roberta_nonprocessed_data_sentiment_score           2813.1519   2607.029      1.079      0.281   -2302.180    7928.483
# ==============================================================================
# Omnibus:                      159.886   Durbin-Watson:                   0.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.065
# Skew:                           0.112   Prob(JB):                     1.21e-09
# Kurtosis:                       2.082   Cond. No.                     3.17e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.76e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     4.792
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           7.79e-05
# Time:                        13:25:54   Log-Likelihood:                -12055.
# No. Observations:                1103   AIC:                         2.412e+04
# Df Residuals:                    1096   BIC:                         2.416e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                3.97e+04   1274.522     31.148      0.000    3.72e+04    4.22e+04
# flair_nonprocessed_data_score                        -45.9874   1022.042     -0.045      0.964   -2051.368    1959.393
# spacytextblob_nonprocessed_data_polarity_score     -5496.9757   1997.402     -2.752      0.006   -9416.140   -1577.811
# spacytextblob_nonprocessed_data_subjectivity_score -3917.2059   1689.831     -2.318      0.021   -7232.876    -601.536
# textblob_nonprocessed_data_polarity_score          -5496.9757   1997.402     -2.752      0.006   -9416.140   -1577.811
# textblob_nonprocessed_data_subjectivity_score      -3917.2059   1689.831     -2.318      0.021   -7232.876    -601.536
# vader_nonprocessed_data_score                       5732.9059   2453.311      2.337      0.020     919.188    1.05e+04
# bert_nonprocessed_data_sentiment_score              -270.0564   2177.585     -0.124      0.901   -4542.762    4002.649
# roberta_nonprocessed_data_sentiment_score           2764.8476   2611.318      1.059      0.290   -2358.900    7888.595
# ==============================================================================
# Omnibus:                      163.464   Durbin-Watson:                   0.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.331
# Skew:                           0.109   Prob(JB):                     1.06e-09
# Kurtosis:                       2.077   Cond. No.                     3.17e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.76e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 4. 6H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_6hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     3.782
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):            0.00102
# Time:                        13:25:54   Log-Likelihood:                -8152.9
# No. Observations:                 746   AIC:                         1.632e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.979e+04   1620.083     24.557      0.000    3.66e+04     4.3e+04
# flair_nonprocessed_data_score                        921.1837   1311.775      0.702      0.483   -1654.066    3496.434
# spacytextblob_nonprocessed_data_polarity_score     -7367.5208   2603.324     -2.830      0.005   -1.25e+04   -2256.730
# spacytextblob_nonprocessed_data_subjectivity_score -3604.9637   2229.256     -1.617      0.106   -7981.393     771.465
# textblob_nonprocessed_data_polarity_score          -7367.5208   2603.324     -2.830      0.005   -1.25e+04   -2256.730
# textblob_nonprocessed_data_subjectivity_score      -3604.9637   2229.256     -1.617      0.106   -7981.393     771.465
# vader_nonprocessed_data_score                       6175.3968   3130.985      1.972      0.049      28.711    1.23e+04
# bert_nonprocessed_data_sentiment_score              -517.4033   2730.583     -0.189      0.850   -5878.026    4843.220
# roberta_nonprocessed_data_sentiment_score           2740.2378   3370.642      0.813      0.416   -3876.936    9357.412
# ==============================================================================
# Omnibus:                      110.930   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.425
# Skew:                           0.114   Prob(JB):                     6.72e-07
# Kurtosis:                       2.071   Cond. No.                     3.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     3.895
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           0.000774
# Time:                        13:25:54   Log-Likelihood:                -8152.4
# No. Observations:                 746   AIC:                         1.632e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.982e+04   1618.923     24.600      0.000    3.66e+04     4.3e+04
# flair_nonprocessed_data_score                        820.5437   1310.836      0.626      0.532   -1752.863    3393.951
# spacytextblob_nonprocessed_data_polarity_score     -7435.3916   2601.460     -2.858      0.004   -1.25e+04   -2328.258
# spacytextblob_nonprocessed_data_subjectivity_score -3700.3406   2227.660     -1.661      0.097   -8073.637     672.956
# textblob_nonprocessed_data_polarity_score          -7435.3916   2601.460     -2.858      0.004   -1.25e+04   -2328.258
# textblob_nonprocessed_data_subjectivity_score      -3700.3406   2227.660     -1.661      0.097   -8073.637     672.956
# vader_nonprocessed_data_score                       6431.4611   3128.745      2.056      0.040     289.175    1.26e+04
# bert_nonprocessed_data_sentiment_score              -400.6543   2728.628     -0.147      0.883   -5757.441    4956.132
# roberta_nonprocessed_data_sentiment_score           2678.8373   3368.229      0.795      0.427   -3933.601    9291.275
# ==============================================================================
# Omnibus:                      110.278   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.219
# Skew:                           0.109   Prob(JB):                     7.45e-07
# Kurtosis:                       2.072   Cond. No.                     3.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     3.925
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           0.000719
# Time:                        13:25:54   Log-Likelihood:                -8152.3
# No. Observations:                 746   AIC:                         1.632e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.995e+04   1618.735     24.681      0.000    3.68e+04    4.31e+04
# flair_nonprocessed_data_score                        661.3353   1310.684      0.505      0.614   -1911.773    3234.443
# spacytextblob_nonprocessed_data_polarity_score     -7411.8112   2601.158     -2.849      0.005   -1.25e+04   -2305.271
# spacytextblob_nonprocessed_data_subjectivity_score -3802.4003   2227.402     -1.707      0.088   -8175.189     570.389
# textblob_nonprocessed_data_polarity_score          -7411.8112   2601.158     -2.849      0.005   -1.25e+04   -2305.271
# textblob_nonprocessed_data_subjectivity_score      -3802.4003   2227.402     -1.707      0.088   -8175.189     570.389
# vader_nonprocessed_data_score                       6478.8882   3128.381      2.071      0.039     337.315    1.26e+04
# bert_nonprocessed_data_sentiment_score              -156.2531   2728.311     -0.057      0.954   -5512.418    5199.911
# roberta_nonprocessed_data_sentiment_score           2563.2410   3367.838      0.761      0.447   -4048.429    9174.911
# ==============================================================================
# Omnibus:                      111.689   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.291
# Skew:                           0.105   Prob(JB):                     7.19e-07
# Kurtosis:                       2.070   Cond. No.                     3.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     3.861
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           0.000840
# Time:                        13:25:54   Log-Likelihood:                -8154.2
# No. Observations:                 746   AIC:                         1.632e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               4.005e+04   1622.819     24.680      0.000    3.69e+04    4.32e+04
# flair_nonprocessed_data_score                        589.4923   1313.991      0.449      0.654   -1990.107    3169.091
# spacytextblob_nonprocessed_data_polarity_score     -7424.5544   2607.720     -2.847      0.005   -1.25e+04   -2305.132
# spacytextblob_nonprocessed_data_subjectivity_score -3761.2766   2233.021     -1.684      0.093   -8145.097     622.543
# textblob_nonprocessed_data_polarity_score          -7424.5544   2607.720     -2.847      0.005   -1.25e+04   -2305.132
# textblob_nonprocessed_data_subjectivity_score      -3761.2766   2233.021     -1.684      0.093   -8145.097     622.543
# vader_nonprocessed_data_score                       6182.0261   3136.273      1.971      0.049      24.960    1.23e+04
# bert_nonprocessed_data_sentiment_score                82.7535   2735.194      0.030      0.976   -5286.923    5452.430
# roberta_nonprocessed_data_sentiment_score           2651.3520   3376.334      0.785      0.433   -3976.997    9279.701
# ==============================================================================
# Omnibus:                      116.157   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.643
# Skew:                           0.100   Prob(JB):                     6.03e-07
# Kurtosis:                       2.061   Cond. No.                     3.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     3.927
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           0.000714
# Time:                        13:25:54   Log-Likelihood:                -8161.9
# No. Observations:                 746   AIC:                         1.634e+04
# Df Residuals:                     739   BIC:                         1.637e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               4.028e+04   1639.644     24.567      0.000    3.71e+04    4.35e+04
# flair_nonprocessed_data_score                        320.8421   1327.614      0.242      0.809   -2285.501    2927.185
# spacytextblob_nonprocessed_data_polarity_score     -7370.7247   2634.756     -2.797      0.005   -1.25e+04   -2198.226
# spacytextblob_nonprocessed_data_subjectivity_score -3975.3362   2256.172     -1.762      0.078   -8404.606     453.933
# textblob_nonprocessed_data_polarity_score          -7370.7247   2634.756     -2.797      0.005   -1.25e+04   -2198.226
# textblob_nonprocessed_data_subjectivity_score      -3975.3362   2256.172     -1.762      0.078   -8404.606     453.933
# vader_nonprocessed_data_score                       6914.8230   3168.789      2.182      0.029     693.923    1.31e+04
# bert_nonprocessed_data_sentiment_score               416.0397   2763.551      0.151      0.880   -5009.307    5841.386
# roberta_nonprocessed_data_sentiment_score           2215.4063   3411.339      0.649      0.516   -4481.663    8912.475
# ==============================================================================
# Omnibus:                      109.079   Durbin-Watson:                   0.069
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.082
# Skew:                           0.109   Prob(JB):                     7.98e-07
# Kurtosis:                       2.075   Cond. No.                     3.06e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 5. 1D Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1d_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     2.273
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):             0.0377
# Time:                        13:25:54   Log-Likelihood:                -2546.3
# No. Observations:                 233   AIC:                             5107.
# Df Residuals:                     226   BIC:                             5131.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.844e+04   3518.094     10.927      0.000    3.15e+04    4.54e+04
# flair_nonprocessed_data_score                       3223.1281   3088.621      1.044      0.298   -2863.049    9309.305
# spacytextblob_nonprocessed_data_polarity_score      -1.45e+04   5911.709     -2.453      0.015   -2.62e+04   -2853.584
# spacytextblob_nonprocessed_data_subjectivity_score -2592.8483   5072.717     -0.511      0.610   -1.26e+04    7403.022
# textblob_nonprocessed_data_polarity_score           -1.45e+04   5911.709     -2.453      0.015   -2.62e+04   -2853.584
# textblob_nonprocessed_data_subjectivity_score      -2592.8483   5072.717     -0.511      0.610   -1.26e+04    7403.022
# vader_nonprocessed_data_score                       1.063e+04   6907.579      1.539      0.125   -2980.299    2.42e+04
# bert_nonprocessed_data_sentiment_score             -3065.2032   5778.097     -0.530      0.596   -1.45e+04    8320.630
# roberta_nonprocessed_data_sentiment_score           5271.3054   7261.624      0.726      0.469   -9037.842    1.96e+04
# ==============================================================================
# Omnibus:                       36.312   Durbin-Watson:                   0.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.315
# Skew:                           0.056   Prob(JB):                      0.00949
# Kurtosis:                       2.027   Cond. No.                     5.97e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.06e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     2.317
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):             0.0343
# Time:                        13:25:54   Log-Likelihood:                -2545.5
# No. Observations:                 233   AIC:                             5105.
# Df Residuals:                     226   BIC:                             5129.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.818e+04   3506.772     10.888      0.000    3.13e+04    4.51e+04
# flair_nonprocessed_data_score                       2711.2904   3078.681      0.881      0.379   -3355.300    8777.881
# spacytextblob_nonprocessed_data_polarity_score     -1.474e+04   5892.683     -2.502      0.013   -2.64e+04   -3129.761
# spacytextblob_nonprocessed_data_subjectivity_score -2372.0476   5056.391     -0.469      0.639   -1.23e+04    7591.654
# textblob_nonprocessed_data_polarity_score          -1.474e+04   5892.683     -2.502      0.013   -2.64e+04   -3129.761
# textblob_nonprocessed_data_subjectivity_score      -2372.0476   5056.391     -0.469      0.639   -1.23e+04    7591.654
# vader_nonprocessed_data_score                       1.203e+04   6885.349      1.747      0.082   -1537.178    2.56e+04
# bert_nonprocessed_data_sentiment_score             -2903.4634   5759.501     -0.504      0.615   -1.43e+04    8445.727
# roberta_nonprocessed_data_sentiment_score           4611.9347   7238.254      0.637      0.525   -9651.162    1.89e+04
# ==============================================================================
# Omnibus:                       40.595   Durbin-Watson:                   0.137
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.706
# Skew:                           0.034   Prob(JB):                      0.00780
# Kurtosis:                       2.002   Cond. No.                     5.97e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.06e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     2.157
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):             0.0481
# Time:                        13:25:54   Log-Likelihood:                -2548.3
# No. Observations:                 233   AIC:                             5111.
# Df Residuals:                     226   BIC:                             5135.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.815e+04   3548.725     10.752      0.000    3.12e+04    4.51e+04
# flair_nonprocessed_data_score                       2022.8563   3115.512      0.649      0.517   -4116.311    8162.024
# spacytextblob_nonprocessed_data_polarity_score      -1.46e+04   5963.181     -2.449      0.015   -2.64e+04   -2852.608
# spacytextblob_nonprocessed_data_subjectivity_score -2166.1383   5116.884     -0.423      0.672   -1.22e+04    7916.764
# textblob_nonprocessed_data_polarity_score           -1.46e+04   5963.181     -2.449      0.015   -2.64e+04   -2852.608
# textblob_nonprocessed_data_subjectivity_score      -2166.1383   5116.884     -0.423      0.672   -1.22e+04    7916.764
# vader_nonprocessed_data_score                       1.218e+04   6967.722      1.748      0.082   -1552.524    2.59e+04
# bert_nonprocessed_data_sentiment_score             -2623.8191   5828.405     -0.450      0.653   -1.41e+04    8861.148
# roberta_nonprocessed_data_sentiment_score           4640.2017   7324.849      0.633      0.527   -9793.532    1.91e+04
# ==============================================================================
# Omnibus:                       39.802   Durbin-Watson:                   0.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.695
# Skew:                           0.057   Prob(JB):                      0.00785
# Kurtosis:                       2.007   Cond. No.                     5.97e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.06e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     2.250
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):             0.0396
# Time:                        13:25:54   Log-Likelihood:                -2550.3
# No. Observations:                 233   AIC:                             5115.
# Df Residuals:                     226   BIC:                             5139.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.834e+04   3578.988     10.714      0.000    3.13e+04    4.54e+04
# flair_nonprocessed_data_score                       2133.1852   3142.081      0.679      0.498   -4058.336    8324.707
# spacytextblob_nonprocessed_data_polarity_score     -1.516e+04   6014.034     -2.521      0.012    -2.7e+04   -3308.807
# spacytextblob_nonprocessed_data_subjectivity_score -2084.4625   5160.520     -0.404      0.687   -1.23e+04    8084.425
# textblob_nonprocessed_data_polarity_score          -1.516e+04   6014.034     -2.521      0.012    -2.7e+04   -3308.807
# textblob_nonprocessed_data_subjectivity_score      -2084.4625   5160.520     -0.404      0.687   -1.23e+04    8084.425
# vader_nonprocessed_data_score                       1.262e+04   7027.141      1.796      0.074   -1229.275    2.65e+04
# bert_nonprocessed_data_sentiment_score             -2259.8761   5878.109     -0.384      0.701   -1.38e+04    9323.033
# roberta_nonprocessed_data_sentiment_score           4434.6659   7387.314      0.600      0.549   -1.01e+04     1.9e+04
# ==============================================================================
# Omnibus:                       38.920   Durbin-Watson:                   0.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.649
# Skew:                           0.068   Prob(JB):                      0.00803
# Kurtosis:                       2.012   Cond. No.                     5.97e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.06e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     2.046
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):             0.0607
# Time:                        13:25:54   Log-Likelihood:                -2549.4
# No. Observations:                 233   AIC:                             5113.
# Df Residuals:                     226   BIC:                             5137.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.795e+04   3565.675     10.643      0.000    3.09e+04     4.5e+04
# flair_nonprocessed_data_score                       1901.0867   3130.393      0.607      0.544   -4267.404    8069.578
# spacytextblob_nonprocessed_data_polarity_score     -1.577e+04   5991.663     -2.631      0.009   -2.76e+04   -3958.921
# spacytextblob_nonprocessed_data_subjectivity_score  -310.7912   5141.324     -0.060      0.952   -1.04e+04    9820.271
# textblob_nonprocessed_data_polarity_score          -1.577e+04   5991.663     -2.631      0.009   -2.76e+04   -3958.921
# textblob_nonprocessed_data_subjectivity_score       -310.7912   5141.324     -0.060      0.952   -1.04e+04    9820.271
# vader_nonprocessed_data_score                       1.166e+04   7001.002      1.666      0.097   -2132.212    2.55e+04
# bert_nonprocessed_data_sentiment_score             -2610.5622   5856.244     -0.446      0.656   -1.42e+04    8929.261
# roberta_nonprocessed_data_sentiment_score           4400.4862   7359.835      0.598      0.551   -1.01e+04    1.89e+04
# ==============================================================================
# Omnibus:                       54.857   Durbin-Watson:                   0.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.941
# Skew:                           0.016   Prob(JB):                      0.00421
# Kurtosis:                       1.939   Cond. No.                     5.97e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.06e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
