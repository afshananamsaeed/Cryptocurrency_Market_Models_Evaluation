# %%
import pandas as pd
import numpy as np
import os
import datetime
os.chdir('/home/ubuntu/Masters Thesis/')
from scripts.utilities.data_joining import GetModellingData

# %% [markdown]
# Data without Bots and De-emoji text processing

# %%
bitcoin_hourly = pd.read_csv("/mnt/bitcoin_hourly_prices_till_2023-03-30.csv", lineterminator='\n')
bitcoin_minutely = pd.read_csv("/mnt/bitcoin_price_minutely_data_till_2023_03_30.csv", lineterminator='\n')

# %%
bitcoin_minutely
# Out:
#                time exchange fsym tsym     close      high       low  \
# 0        1606780800   CCCAGG  BTC  USD  19704.72  19714.44  19686.87
# 1        1606780860   CCCAGG  BTC  USD  19682.63  19706.49  19674.34
# 2        1606780920   CCCAGG  BTC  USD  19688.59  19691.33  19654.82
# 3        1606780980   CCCAGG  BTC  USD  19664.79  19697.12  19659.91
# 4        1606781040   CCCAGG  BTC  USD  19628.40  19665.60  19623.03
# ...             ...      ...  ...  ...       ...       ...       ...
# 1223995  1680220500   CCCAGG  BTC  USD  28038.57  28044.74  28032.44
# 1223996  1680220560   CCCAGG  BTC  USD  28037.36  28043.24  28031.83
# 1223997  1680220620   CCCAGG  BTC  USD  28031.20  28039.71  28030.25
# 1223998  1680220680   CCCAGG  BTC  USD  28037.81  28038.74  28029.52
# 1223999  1680220740   CCCAGG  BTC  USD  28040.71  28052.54  28036.36
#
#              open  volumefrom    volumeto
# 0        19686.87      58.620  1151502.04
# 1        19704.72     132.800  2614001.65
# 2        19682.63      55.390  1090096.41
# 3        19688.59      51.070  1004714.46
# 4        19664.79     109.540  2149088.17
# ...           ...         ...         ...
# 1223995  28032.49      11.500   322442.59
# 1223996  28038.57      20.120   564252.17
# 1223997  28037.36      12.290   344664.77
# 1223998  28031.20       8.527   239073.67
# 1223999  28037.81      75.070  2105709.79
#
# [1224000 rows x 10 columns]

# %%
data_30min = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_30T_processed.csv", lineterminator='\n')
data_1hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_1H_processed.csv", lineterminator='\n')
data_4hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_4H_processed.csv", lineterminator='\n')
data_6hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_6H_processed.csv", lineterminator='\n')
data_1day = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_D_processed.csv", lineterminator='\n')

# %%
data_30min = data_30min[~data_30min['spacytextblob_processed_data_polarity_score'].isna()]
data_1hrs = data_1hrs[~data_1hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_4hrs = data_4hrs[~data_4hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_6hrs = data_6hrs[~data_6hrs['spacytextblob_processed_data_polarity_score'].isna()]
data_1day = data_1day[~data_1day['spacytextblob_processed_data_polarity_score'].isna()]

data_30min = data_30min.drop(columns=['Unnamed: 0'])
data_1hrs = data_1hrs.drop(columns=['Unnamed: 0'])
data_4hrs = data_4hrs.drop(columns=['Unnamed: 0'])
data_6hrs = data_6hrs.drop(columns=['Unnamed: 0'])
data_1day = data_1day.drop(columns=['Unnamed: 0'])

# %%
bitcoin_minutely = bitcoin_minutely.rename(columns={'time': 'date'})
bitcoin_minutely['date'] = bitcoin_minutely['date'].apply(datetime.datetime.utcfromtimestamp)
bitcoin_hourly = bitcoin_hourly.rename(columns={'datetimes': 'date'})
bitcoin_hourly['date'] = pd.to_datetime(bitcoin_hourly['date'])

# %%
data_30min_joined = GetModellingData(data=data_30min, bitcoin_data=bitcoin_minutely, frequency='30T').get_data_for_feature_analysis()
data_1hr_joined = GetModellingData(data=data_1hrs, bitcoin_data=bitcoin_hourly, frequency='1H').get_data_for_feature_analysis()
data_4hr_joined = GetModellingData(data=data_4hrs, bitcoin_data=bitcoin_hourly, frequency='4H').get_data_for_feature_analysis()
data_6hr_joined = GetModellingData(data=data_6hrs, bitcoin_data=bitcoin_hourly, frequency='6H').get_data_for_feature_analysis()
data_1d_joined = GetModellingData(data=data_1day, bitcoin_data=bitcoin_hourly, frequency='1D').get_data_for_feature_analysis()
# Out:
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])

# %%
data_30min_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_30min_joined.dropna(inplace=True)
data_1hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1hr_joined.dropna(inplace=True)
data_4hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_4hr_joined.dropna(inplace=True)
data_6hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_6hr_joined.dropna(inplace=True)
data_1d_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1d_joined.dropna(inplace=True)

# %% [markdown]
# ### Plots and Analysis

# %% [markdown]
# 1. 30T Frequency

# %%
# correlation analysis - pearson
data_30min_joined.corr()
# Out:
#                                                      date  \
# date                                             1.000000
# flair_processed_data_score                      -0.043255
# spacytextblob_processed_data_polarity_score      0.028136
# spacytextblob_processed_data_subjectivity_score  0.090034
# textblob_processed_data_polarity_score           0.028136
# textblob_processed_data_subjectivity_score       0.090034
# vader_processed_data_score                       0.006109
# bert_processed_data_sentiment_score             -0.060841
# roberta_processed_data_sentiment_score          -0.053770
# close                                           -0.714941
# close_t+1                                       -0.715182
# close_t+2                                       -0.715383
# close_t+3                                       -0.715570
# close_t+7                                       -0.716378
#
#                                                  flair_processed_data_score  \
# date                                                              -0.043255
# flair_processed_data_score                                         1.000000
# spacytextblob_processed_data_polarity_score                        0.270381
# spacytextblob_processed_data_subjectivity_score                    0.097791
# textblob_processed_data_polarity_score                             0.270381
# textblob_processed_data_subjectivity_score                         0.097791
# vader_processed_data_score                                         0.354093
# bert_processed_data_sentiment_score                                0.588939
# roberta_processed_data_sentiment_score                             0.502298
# close                                                              0.058655
# close_t+1                                                          0.058785
# close_t+2                                                          0.058661
# close_t+3                                                          0.058882
# close_t+7                                                          0.059191
#
#                                                  spacytextblob_processed_data_polarity_score  \
# date                                                                                0.028136
# flair_processed_data_score                                                          0.270381
# spacytextblob_processed_data_polarity_score                                         1.000000
# spacytextblob_processed_data_subjectivity_score                                     0.312185
# textblob_processed_data_polarity_score                                              1.000000
# textblob_processed_data_subjectivity_score                                          0.312185
# vader_processed_data_score                                                          0.420263
# bert_processed_data_sentiment_score                                                 0.332118
# roberta_processed_data_sentiment_score                                              0.397540
# close                                                                              -0.007570
# close_t+1                                                                          -0.007584
# close_t+2                                                                          -0.007402
# close_t+3                                                                          -0.007260
# close_t+7                                                                          -0.007530
#
#                                                  spacytextblob_processed_data_subjectivity_score  \
# date                                                                                    0.090034
# flair_processed_data_score                                                              0.097791
# spacytextblob_processed_data_polarity_score                                             0.312185
# spacytextblob_processed_data_subjectivity_score                                         1.000000
# textblob_processed_data_polarity_score                                                  0.312185
# textblob_processed_data_subjectivity_score                                              1.000000
# vader_processed_data_score                                                              0.151613
# bert_processed_data_sentiment_score                                                     0.070915
# roberta_processed_data_sentiment_score                                                  0.087284
# close                                                                                  -0.078852
# close_t+1                                                                              -0.079069
# close_t+2                                                                              -0.079287
# close_t+3                                                                              -0.079239
# close_t+7                                                                              -0.079935
#
#                                                  textblob_processed_data_polarity_score  \
# date                                                                           0.028136
# flair_processed_data_score                                                     0.270381
# spacytextblob_processed_data_polarity_score                                    1.000000
# spacytextblob_processed_data_subjectivity_score                                0.312185
# textblob_processed_data_polarity_score                                         1.000000
# textblob_processed_data_subjectivity_score                                     0.312185
# vader_processed_data_score                                                     0.420263
# bert_processed_data_sentiment_score                                            0.332118
# roberta_processed_data_sentiment_score                                         0.397540
# close                                                                         -0.007570
# close_t+1                                                                     -0.007584
# close_t+2                                                                     -0.007402
# close_t+3                                                                     -0.007260
# close_t+7                                                                     -0.007530
#
#                                                  textblob_processed_data_subjectivity_score  \
# date                                                                               0.090034
# flair_processed_data_score                                                         0.097791
# spacytextblob_processed_data_polarity_score                                        0.312185
# spacytextblob_processed_data_subjectivity_score                                    1.000000
# textblob_processed_data_polarity_score                                             0.312185
# textblob_processed_data_subjectivity_score                                         1.000000
# vader_processed_data_score                                                         0.151613
# bert_processed_data_sentiment_score                                                0.070915
# roberta_processed_data_sentiment_score                                             0.087284
# close                                                                             -0.078852
# close_t+1                                                                         -0.079069
# close_t+2                                                                         -0.079287
# close_t+3                                                                         -0.079239
# close_t+7                                                                         -0.079935
#
#                                                  vader_processed_data_score  \
# date                                                               0.006109
# flair_processed_data_score                                         0.354093
# spacytextblob_processed_data_polarity_score                        0.420263
# spacytextblob_processed_data_subjectivity_score                    0.151613
# textblob_processed_data_polarity_score                             0.420263
# textblob_processed_data_subjectivity_score                         0.151613
# vader_processed_data_score                                         1.000000
# bert_processed_data_sentiment_score                                0.418528
# roberta_processed_data_sentiment_score                             0.562213
# close                                                              0.026065
# close_t+1                                                          0.026267
# close_t+2                                                          0.026148
# close_t+3                                                          0.025993
# close_t+7                                                          0.025586
#
#                                                  bert_processed_data_sentiment_score  \
# date                                                                       -0.060841
# flair_processed_data_score                                                  0.588939
# spacytextblob_processed_data_polarity_score                                 0.332118
# spacytextblob_processed_data_subjectivity_score                             0.070915
# textblob_processed_data_polarity_score                                      0.332118
# textblob_processed_data_subjectivity_score                                  0.070915
# vader_processed_data_score                                                  0.418528
# bert_processed_data_sentiment_score                                         1.000000
# roberta_processed_data_sentiment_score                                      0.558327
# close                                                                       0.074309
# close_t+1                                                                   0.074571
# close_t+2                                                                   0.074523
# close_t+3                                                                   0.074851
# close_t+7                                                                   0.075163
#
#                                                  roberta_processed_data_sentiment_score  \
# date                                                                          -0.053770
# flair_processed_data_score                                                     0.502298
# spacytextblob_processed_data_polarity_score                                    0.397540
# spacytextblob_processed_data_subjectivity_score                                0.087284
# textblob_processed_data_polarity_score                                         0.397540
# textblob_processed_data_subjectivity_score                                     0.087284
# vader_processed_data_score                                                     0.562213
# bert_processed_data_sentiment_score                                            0.558327
# roberta_processed_data_sentiment_score                                         1.000000
# close                                                                          0.090569
# close_t+1                                                                      0.091024
# close_t+2                                                                      0.090973
# close_t+3                                                                      0.091218
# close_t+7                                                                      0.091490
#
#                                                     close  close_t+1  \
# date                                            -0.714941  -0.715182
# flair_processed_data_score                       0.058655   0.058785
# spacytextblob_processed_data_polarity_score     -0.007570  -0.007584
# spacytextblob_processed_data_subjectivity_score -0.078852  -0.079069
# textblob_processed_data_polarity_score          -0.007570  -0.007584
# textblob_processed_data_subjectivity_score      -0.078852  -0.079069
# vader_processed_data_score                       0.026065   0.026267
# bert_processed_data_sentiment_score              0.074309   0.074571
# roberta_processed_data_sentiment_score           0.090569   0.091024
# close                                            1.000000   0.999861
# close_t+1                                        0.999861   1.000000
# close_t+2                                        0.999727   0.999861
# close_t+3                                        0.999591   0.999726
# close_t+7                                        0.999025   0.999168
#
#                                                  close_t+2  close_t+3  \
# date                                             -0.715383  -0.715570
# flair_processed_data_score                        0.058661   0.058882
# spacytextblob_processed_data_polarity_score      -0.007402  -0.007260
# spacytextblob_processed_data_subjectivity_score  -0.079287  -0.079239
# textblob_processed_data_polarity_score           -0.007402  -0.007260
# textblob_processed_data_subjectivity_score       -0.079287  -0.079239
# vader_processed_data_score                        0.026148   0.025993
# bert_processed_data_sentiment_score               0.074523   0.074851
# roberta_processed_data_sentiment_score            0.090973   0.091218
# close                                             0.999727   0.999591
# close_t+1                                         0.999861   0.999726
# close_t+2                                         1.000000   0.999860
# close_t+3                                         0.999860   1.000000
# close_t+7                                         0.999311   0.999452
#
#                                                  close_t+7
# date                                             -0.716378
# flair_processed_data_score                        0.059191
# spacytextblob_processed_data_polarity_score      -0.007530
# spacytextblob_processed_data_subjectivity_score  -0.079935
# textblob_processed_data_polarity_score           -0.007530
# textblob_processed_data_subjectivity_score       -0.079935
# vader_processed_data_score                        0.025586
# bert_processed_data_sentiment_score               0.075163
# roberta_processed_data_sentiment_score            0.091490
# close                                             0.999025
# close_t+1                                         0.999168
# close_t+2                                         0.999311
# close_t+3                                         0.999452
# close_t+7                                         1.000000

# %% [markdown]
# Very bad correlation between all the weighted sentiment features and the closing dates

# %%
# correlation analysis - spearman
data_30min_joined.corr(method='spearman')
# Out:
#                                                      date  \
# date                                             1.000000
# flair_processed_data_score                      -0.044971
# spacytextblob_processed_data_polarity_score      0.038943
# spacytextblob_processed_data_subjectivity_score  0.087288
# textblob_processed_data_polarity_score           0.038943
# textblob_processed_data_subjectivity_score       0.087288
# vader_processed_data_score                       0.007461
# bert_processed_data_sentiment_score             -0.073617
# roberta_processed_data_sentiment_score          -0.060857
# close                                           -0.691262
# close_t+1                                       -0.691650
# close_t+2                                       -0.691980
# close_t+3                                       -0.692304
# close_t+7                                       -0.693720
#
#                                                  flair_processed_data_score  \
# date                                                              -0.044971
# flair_processed_data_score                                         1.000000
# spacytextblob_processed_data_polarity_score                        0.271730
# spacytextblob_processed_data_subjectivity_score                    0.098969
# textblob_processed_data_polarity_score                             0.271730
# textblob_processed_data_subjectivity_score                         0.098969
# vader_processed_data_score                                         0.345252
# bert_processed_data_sentiment_score                                0.573466
# roberta_processed_data_sentiment_score                             0.490171
# close                                                              0.067336
# close_t+1                                                          0.067462
# close_t+2                                                          0.067166
# close_t+3                                                          0.067360
# close_t+7                                                          0.067635
#
#                                                  spacytextblob_processed_data_polarity_score  \
# date                                                                                0.038943
# flair_processed_data_score                                                          0.271730
# spacytextblob_processed_data_polarity_score                                         1.000000
# spacytextblob_processed_data_subjectivity_score                                     0.390374
# textblob_processed_data_polarity_score                                              1.000000
# textblob_processed_data_subjectivity_score                                          0.390374
# vader_processed_data_score                                                          0.418038
# bert_processed_data_sentiment_score                                                 0.307304
# roberta_processed_data_sentiment_score                                              0.374743
# close                                                                              -0.006337
# close_t+1                                                                          -0.006321
# close_t+2                                                                          -0.006212
# close_t+3                                                                          -0.006101
# close_t+7                                                                          -0.006760
#
#                                                  spacytextblob_processed_data_subjectivity_score  \
# date                                                                                    0.087288
# flair_processed_data_score                                                              0.098969
# spacytextblob_processed_data_polarity_score                                             0.390374
# spacytextblob_processed_data_subjectivity_score                                         1.000000
# textblob_processed_data_polarity_score                                                  0.390374
# textblob_processed_data_subjectivity_score                                              1.000000
# vader_processed_data_score                                                              0.186013
# bert_processed_data_sentiment_score                                                     0.072362
# roberta_processed_data_sentiment_score                                                  0.102194
# close                                                                                  -0.086102
# close_t+1                                                                              -0.086331
# close_t+2                                                                              -0.086599
# close_t+3                                                                              -0.086628
# close_t+7                                                                              -0.087628
#
#                                                  textblob_processed_data_polarity_score  \
# date                                                                           0.038943
# flair_processed_data_score                                                     0.271730
# spacytextblob_processed_data_polarity_score                                    1.000000
# spacytextblob_processed_data_subjectivity_score                                0.390374
# textblob_processed_data_polarity_score                                         1.000000
# textblob_processed_data_subjectivity_score                                     0.390374
# vader_processed_data_score                                                     0.418038
# bert_processed_data_sentiment_score                                            0.307304
# roberta_processed_data_sentiment_score                                         0.374743
# close                                                                         -0.006337
# close_t+1                                                                     -0.006321
# close_t+2                                                                     -0.006212
# close_t+3                                                                     -0.006101
# close_t+7                                                                     -0.006760
#
#                                                  textblob_processed_data_subjectivity_score  \
# date                                                                               0.087288
# flair_processed_data_score                                                         0.098969
# spacytextblob_processed_data_polarity_score                                        0.390374
# spacytextblob_processed_data_subjectivity_score                                    1.000000
# textblob_processed_data_polarity_score                                             0.390374
# textblob_processed_data_subjectivity_score                                         1.000000
# vader_processed_data_score                                                         0.186013
# bert_processed_data_sentiment_score                                                0.072362
# roberta_processed_data_sentiment_score                                             0.102194
# close                                                                             -0.086102
# close_t+1                                                                         -0.086331
# close_t+2                                                                         -0.086599
# close_t+3                                                                         -0.086628
# close_t+7                                                                         -0.087628
#
#                                                  vader_processed_data_score  \
# date                                                               0.007461
# flair_processed_data_score                                         0.345252
# spacytextblob_processed_data_polarity_score                        0.418038
# spacytextblob_processed_data_subjectivity_score                    0.186013
# textblob_processed_data_polarity_score                             0.418038
# textblob_processed_data_subjectivity_score                         0.186013
# vader_processed_data_score                                         1.000000
# bert_processed_data_sentiment_score                                0.396594
# roberta_processed_data_sentiment_score                             0.529323
# close                                                              0.028276
# close_t+1                                                          0.028607
# close_t+2                                                          0.028456
# close_t+3                                                          0.028098
# close_t+7                                                          0.027065
#
#                                                  bert_processed_data_sentiment_score  \
# date                                                                       -0.073617
# flair_processed_data_score                                                  0.573466
# spacytextblob_processed_data_polarity_score                                 0.307304
# spacytextblob_processed_data_subjectivity_score                             0.072362
# textblob_processed_data_polarity_score                                      0.307304
# textblob_processed_data_subjectivity_score                                  0.072362
# vader_processed_data_score                                                  0.396594
# bert_processed_data_sentiment_score                                         1.000000
# roberta_processed_data_sentiment_score                                      0.532638
# close                                                                       0.082668
# close_t+1                                                                   0.083170
# close_t+2                                                                   0.082966
# close_t+3                                                                   0.083546
# close_t+7                                                                   0.083466
#
#                                                  roberta_processed_data_sentiment_score  \
# date                                                                          -0.060857
# flair_processed_data_score                                                     0.490171
# spacytextblob_processed_data_polarity_score                                    0.374743
# spacytextblob_processed_data_subjectivity_score                                0.102194
# textblob_processed_data_polarity_score                                         0.374743
# textblob_processed_data_subjectivity_score                                     0.102194
# vader_processed_data_score                                                     0.529323
# bert_processed_data_sentiment_score                                            0.532638
# roberta_processed_data_sentiment_score                                         1.000000
# close                                                                          0.105835
# close_t+1                                                                      0.106529
# close_t+2                                                                      0.106595
# close_t+3                                                                      0.106732
# close_t+7                                                                      0.107064
#
#                                                     close  close_t+1  \
# date                                            -0.691262  -0.691650
# flair_processed_data_score                       0.067336   0.067462
# spacytextblob_processed_data_polarity_score     -0.006337  -0.006321
# spacytextblob_processed_data_subjectivity_score -0.086102  -0.086331
# textblob_processed_data_polarity_score          -0.006337  -0.006321
# textblob_processed_data_subjectivity_score      -0.086102  -0.086331
# vader_processed_data_score                       0.028276   0.028607
# bert_processed_data_sentiment_score              0.082668   0.083170
# roberta_processed_data_sentiment_score           0.105835   0.106529
# close                                            1.000000   0.999711
# close_t+1                                        0.999711   1.000000
# close_t+2                                        0.999433   0.999712
# close_t+3                                        0.999172   0.999435
# close_t+7                                        0.998079   0.998365
#
#                                                  close_t+2  close_t+3  \
# date                                             -0.691980  -0.692304
# flair_processed_data_score                        0.067166   0.067360
# spacytextblob_processed_data_polarity_score      -0.006212  -0.006101
# spacytextblob_processed_data_subjectivity_score  -0.086599  -0.086628
# textblob_processed_data_polarity_score           -0.006212  -0.006101
# textblob_processed_data_subjectivity_score       -0.086599  -0.086628
# vader_processed_data_score                        0.028456   0.028098
# bert_processed_data_sentiment_score               0.082966   0.083546
# roberta_processed_data_sentiment_score            0.106595   0.106732
# close                                             0.999433   0.999172
# close_t+1                                         0.999712   0.999435
# close_t+2                                         1.000000   0.999714
# close_t+3                                         0.999714   1.000000
# close_t+7                                         0.998648   0.998922
#
#                                                  close_t+7
# date                                             -0.693720
# flair_processed_data_score                        0.067635
# spacytextblob_processed_data_polarity_score      -0.006760
# spacytextblob_processed_data_subjectivity_score  -0.087628
# textblob_processed_data_polarity_score           -0.006760
# textblob_processed_data_subjectivity_score       -0.087628
# vader_processed_data_score                        0.027065
# bert_processed_data_sentiment_score               0.083466
# roberta_processed_data_sentiment_score            0.107064
# close                                             0.998079
# close_t+1                                         0.998365
# close_t+2                                         0.998648
# close_t+3                                         0.998922
# close_t+7                                         1.000000

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_30min_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.30
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           6.07e-30
# Time:                        20:38:26   Log-Likelihood:                -91099.
# No. Observations:                8334   AIC:                         1.822e+05
# Df Residuals:                    8327   BIC:                         1.823e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.036e+04    420.448     96.001      0.000    3.95e+04    4.12e+04
# flair_processed_data_score                        344.1595    408.245      0.843      0.399    -456.102    1144.421
# spacytextblob_processed_data_polarity_score     -1484.6158    728.987     -2.037      0.042   -2913.611     -55.620
# spacytextblob_processed_data_subjectivity_score -3678.2750    533.349     -6.897      0.000   -4723.772   -2632.778
# textblob_processed_data_polarity_score          -1484.6158    728.987     -2.037      0.042   -2913.611     -55.620
# textblob_processed_data_subjectivity_score      -3678.2750    533.349     -6.897      0.000   -4723.772   -2632.778
# vader_processed_data_score                      -1566.7609    886.828     -1.767      0.077   -3305.165     171.644
# bert_processed_data_sentiment_score              2177.9552    806.430      2.701      0.007     597.152    3758.758
# roberta_processed_data_sentiment_score           5354.8707    864.118      6.197      0.000    3660.984    7048.757
# ==============================================================================
# Omnibus:                     1149.313   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.000
# Skew:                           0.150   Prob(JB):                     4.84e-68
# Kurtosis:                       2.104   Cond. No.                     4.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.71e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.50
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           3.48e-30
# Time:                        20:38:26   Log-Likelihood:                -91099.
# No. Observations:                8334   AIC:                         1.822e+05
# Df Residuals:                    8327   BIC:                         1.823e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.037e+04    420.413     96.016      0.000    3.95e+04    4.12e+04
# flair_processed_data_score                        339.8631    408.211      0.833      0.405    -460.332    1140.059
# spacytextblob_processed_data_polarity_score     -1493.8890    728.927     -2.049      0.040   -2922.767     -65.011
# spacytextblob_processed_data_subjectivity_score -3687.8710    533.305     -6.915      0.000   -4733.282   -2642.460
# textblob_processed_data_polarity_score          -1493.8890    728.927     -2.049      0.040   -2922.767     -65.011
# textblob_processed_data_subjectivity_score      -3687.8710    533.305     -6.915      0.000   -4733.282   -2642.460
# vader_processed_data_score                      -1566.9186    886.756     -1.767      0.077   -3305.180     171.343
# bert_processed_data_sentiment_score              2184.0657    806.363      2.709      0.007     603.393    3764.739
# roberta_processed_data_sentiment_score           5386.3131    864.047      6.234      0.000    3692.566    7080.060
# ==============================================================================
# Omnibus:                     1149.413   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.751
# Skew:                           0.149   Prob(JB):                     5.48e-68
# Kurtosis:                       2.104   Cond. No.                     4.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.71e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.52
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           3.28e-30
# Time:                        20:38:26   Log-Likelihood:                -91098.
# No. Observations:                8334   AIC:                         1.822e+05
# Df Residuals:                    8327   BIC:                         1.823e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.037e+04    420.395     96.031      0.000    3.95e+04    4.12e+04
# flair_processed_data_score                        335.9862    408.193      0.823      0.410    -464.174    1136.146
# spacytextblob_processed_data_polarity_score     -1471.5547    728.895     -2.019      0.044   -2900.370     -42.740
# spacytextblob_processed_data_subjectivity_score -3701.6298    533.282     -6.941      0.000   -4746.995   -2656.265
# textblob_processed_data_polarity_score          -1471.5547    728.895     -2.019      0.044   -2900.370     -42.740
# textblob_processed_data_subjectivity_score      -3701.6298    533.282     -6.941      0.000   -4746.995   -2656.265
# vader_processed_data_score                      -1578.9201    886.717     -1.781      0.075   -3317.105     159.265
# bert_processed_data_sentiment_score              2184.2328    806.328      2.709      0.007     603.629    3764.836
# roberta_processed_data_sentiment_score           5385.4441    864.009      6.233      0.000    3691.771    7079.117
# ==============================================================================
# Omnibus:                     1149.775   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.644
# Skew:                           0.148   Prob(JB):                     5.78e-68
# Kurtosis:                       2.104   Cond. No.                     4.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.71e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.62
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.45e-30
# Time:                        20:38:26   Log-Likelihood:                -91098.
# No. Observations:                8334   AIC:                         1.822e+05
# Df Residuals:                    8327   BIC:                         1.823e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.037e+04    420.379     96.037      0.000    3.95e+04    4.12e+04
# flair_processed_data_score                        336.9946    408.178      0.826      0.409    -463.135    1137.124
# spacytextblob_processed_data_polarity_score     -1465.0161    728.867     -2.010      0.044   -2893.777     -36.256
# spacytextblob_processed_data_subjectivity_score -3699.7777    533.261     -6.938      0.000   -4745.103   -2654.453
# textblob_processed_data_polarity_score          -1465.0161    728.867     -2.010      0.044   -2893.777     -36.256
# textblob_processed_data_subjectivity_score      -3699.7777    533.261     -6.938      0.000   -4745.103   -2654.453
# vader_processed_data_score                      -1612.5226    886.683     -1.819      0.069   -3350.641     125.596
# bert_processed_data_sentiment_score              2201.9103    806.297      2.731      0.006     621.367    3782.453
# roberta_processed_data_sentiment_score           5402.1071    863.976      6.253      0.000    3708.499    7095.715
# ==============================================================================
# Omnibus:                     1148.356   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.281
# Skew:                           0.148   Prob(JB):                     6.92e-68
# Kurtosis:                       2.104   Cond. No.                     4.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.71e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     25.95
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           9.51e-31
# Time:                        20:38:26   Log-Likelihood:                -91097.
# No. Observations:                8334   AIC:                         1.822e+05
# Df Residuals:                    8327   BIC:                         1.823e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                             4.04e+04    420.342     96.110      0.000    3.96e+04    4.12e+04
# flair_processed_data_score                        344.1900    408.142      0.843      0.399    -455.871    1144.251
# spacytextblob_processed_data_polarity_score     -1471.8750    728.804     -2.020      0.043   -2900.512     -43.238
# spacytextblob_processed_data_subjectivity_score -3729.2922    533.215     -6.994      0.000   -4774.527   -2684.057
# textblob_processed_data_polarity_score          -1471.8750    728.804     -2.020      0.043   -2900.512     -43.238
# textblob_processed_data_subjectivity_score      -3729.2922    533.215     -6.994      0.000   -4774.527   -2684.057
# vader_processed_data_score                      -1661.5307    886.606     -1.874      0.061   -3399.499      76.438
# bert_processed_data_sentiment_score              2217.2229    806.228      2.750      0.006     636.816    3797.629
# roberta_processed_data_sentiment_score           5432.1827    863.901      6.288      0.000    3738.721    7125.645
# ==============================================================================
# Omnibus:                     1148.661   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.335
# Skew:                           0.145   Prob(JB):                     1.11e-67
# Kurtosis:                       2.104   Cond. No.                     4.96e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.71e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 2. 1H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1hr_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     16.43
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           8.43e-19
# Time:                        20:39:36   Log-Likelihood:                -45986.
# No. Observations:                4208   AIC:                         9.199e+04
# Df Residuals:                    4201   BIC:                         9.203e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.072e+04    671.037     60.682      0.000    3.94e+04     4.2e+04
# flair_processed_data_score                        340.8333    673.196      0.506      0.613    -978.986    1660.653
# spacytextblob_processed_data_polarity_score     -2468.7587   1169.995     -2.110      0.035   -4762.567    -174.951
# spacytextblob_processed_data_subjectivity_score -3918.0164    862.211     -4.544      0.000   -5608.406   -2227.626
# textblob_processed_data_polarity_score          -2468.7587   1169.995     -2.110      0.035   -4762.567    -174.951
# textblob_processed_data_subjectivity_score      -3918.0164    862.211     -4.544      0.000   -5608.406   -2227.626
# vader_processed_data_score                      -2133.8228   1462.887     -1.459      0.145   -5001.856     734.210
# bert_processed_data_sentiment_score              3560.5681   1328.878      2.679      0.007     955.264    6165.872
# roberta_processed_data_sentiment_score           7269.6916   1413.464      5.143      0.000    4498.554       1e+04
# ==============================================================================
# Omnibus:                      544.431   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.390
# Skew:                           0.148   Prob(JB):                     8.11e-34
# Kurtosis:                       2.116   Cond. No.                     5.46e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.95e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     16.60
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           5.26e-19
# Time:                        20:39:36   Log-Likelihood:                -45985.
# No. Observations:                4208   AIC:                         9.198e+04
# Df Residuals:                    4201   BIC:                         9.203e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.074e+04    670.949     60.725      0.000    3.94e+04    4.21e+04
# flair_processed_data_score                        345.2089    673.107      0.513      0.608    -974.436    1664.854
# spacytextblob_processed_data_polarity_score     -2427.7362   1169.840     -2.075      0.038   -4721.241    -134.231
# spacytextblob_processed_data_subjectivity_score -3952.5904    862.097     -4.585      0.000   -5642.757   -2262.423
# textblob_processed_data_polarity_score          -2427.7362   1169.840     -2.075      0.038   -4721.241    -134.231
# textblob_processed_data_subjectivity_score      -3952.5904    862.097     -4.585      0.000   -5642.757   -2262.423
# vader_processed_data_score                      -2199.1865   1462.694     -1.504      0.133   -5066.841     668.468
# bert_processed_data_sentiment_score              3592.2483   1328.703      2.704      0.007     987.288    6197.208
# roberta_processed_data_sentiment_score           7294.5832   1413.278      5.161      0.000    4523.811    1.01e+04
# ==============================================================================
# Omnibus:                      543.964   Durbin-Watson:                   0.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.119
# Skew:                           0.146   Prob(JB):                     9.29e-34
# Kurtosis:                       2.116   Cond. No.                     5.46e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.95e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     16.78
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           3.17e-19
# Time:                        20:39:36   Log-Likelihood:                -45985.
# No. Observations:                4208   AIC:                         9.198e+04
# Df Residuals:                    4201   BIC:                         9.203e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.076e+04    670.876     60.763      0.000    3.94e+04    4.21e+04
# flair_processed_data_score                        345.2556    673.034      0.513      0.608    -974.246    1664.757
# spacytextblob_processed_data_polarity_score     -2412.2042   1169.713     -2.062      0.039   -4705.460    -118.948
# spacytextblob_processed_data_subjectivity_score -3983.0936    862.004     -4.621      0.000   -5673.077   -2293.110
# textblob_processed_data_polarity_score          -2412.2042   1169.713     -2.062      0.039   -4705.460    -118.948
# textblob_processed_data_subjectivity_score      -3983.0936    862.004     -4.621      0.000   -5673.077   -2293.110
# vader_processed_data_score                      -2227.2283   1462.535     -1.523      0.128   -5094.571     640.114
# bert_processed_data_sentiment_score              3627.3921   1328.558      2.730      0.006    1022.715    6232.069
# roberta_processed_data_sentiment_score           7318.0039   1413.124      5.179      0.000    4547.533    1.01e+04
# ==============================================================================
# Omnibus:                      544.530   Durbin-Watson:                   0.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.849
# Skew:                           0.145   Prob(JB):                     1.06e-33
# Kurtosis:                       2.115   Cond. No.                     5.46e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.95e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     16.92
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.09e-19
# Time:                        20:39:36   Log-Likelihood:                -45984.
# No. Observations:                4208   AIC:                         9.198e+04
# Df Residuals:                    4201   BIC:                         9.203e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.079e+04    670.789     60.810      0.000    3.95e+04    4.21e+04
# flair_processed_data_score                        358.8972    672.946      0.533      0.594    -960.433    1678.228
# spacytextblob_processed_data_polarity_score     -2462.1840   1169.561     -2.105      0.035   -4755.143    -169.225
# spacytextblob_processed_data_subjectivity_score -4005.1807    861.892     -4.647      0.000   -5694.945   -2315.417
# textblob_processed_data_polarity_score          -2462.1840   1169.561     -2.105      0.035   -4755.143    -169.225
# textblob_processed_data_subjectivity_score      -4005.1807    861.892     -4.647      0.000   -5694.945   -2315.417
# vader_processed_data_score                      -2238.0007   1462.346     -1.530      0.126   -5104.972     628.970
# bert_processed_data_sentiment_score              3626.8970   1328.386      2.730      0.006    1022.558    6231.236
# roberta_processed_data_sentiment_score           7342.1479   1412.941      5.196      0.000    4572.036    1.01e+04
# ==============================================================================
# Omnibus:                      542.896   Durbin-Watson:                   0.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.431
# Skew:                           0.143   Prob(JB):                     1.31e-33
# Kurtosis:                       2.116   Cond. No.                     5.46e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.95e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     17.14
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           1.15e-19
# Time:                        20:39:36   Log-Likelihood:                -45983.
# No. Observations:                4208   AIC:                         9.198e+04
# Df Residuals:                    4201   BIC:                         9.202e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.083e+04    670.557     60.896      0.000    3.95e+04    4.21e+04
# flair_processed_data_score                        344.3206    672.713      0.512      0.609    -974.553    1663.194
# spacytextblob_processed_data_polarity_score     -2408.8159   1169.156     -2.060      0.039   -4700.980    -116.651
# spacytextblob_processed_data_subjectivity_score -4062.2466    861.594     -4.715      0.000   -5751.426   -2373.068
# textblob_processed_data_polarity_score          -2408.8159   1169.156     -2.060      0.039   -4700.980    -116.651
# textblob_processed_data_subjectivity_score      -4062.2466    861.594     -4.715      0.000   -5751.426   -2373.068
# vader_processed_data_score                      -2418.0101   1461.839     -1.654      0.098   -5283.988     447.968
# bert_processed_data_sentiment_score              3666.2848   1327.926      2.761      0.006    1062.847    6269.722
# roberta_processed_data_sentiment_score           7409.2336   1412.452      5.246      0.000    4640.081    1.02e+04
# ==============================================================================
# Omnibus:                      550.943   Durbin-Watson:                   0.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.502
# Skew:                           0.138   Prob(JB):                     1.26e-33
# Kurtosis:                       2.112   Cond. No.                     5.46e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.95e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 3. 4H frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_4hr_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     6.530
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           8.71e-07
# Time:                        20:40:12   Log-Likelihood:                -12048.
# No. Observations:                1103   AIC:                         2.411e+04
# Df Residuals:                    1096   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.253e+04   1766.721     24.072      0.000    3.91e+04     4.6e+04
# flair_processed_data_score                       1204.8324   1929.285      0.624      0.532   -2580.678    4990.342
# spacytextblob_processed_data_polarity_score     -5379.5557   3210.539     -1.676      0.094   -1.17e+04     919.942
# spacytextblob_processed_data_subjectivity_score -5874.5306   2413.797     -2.434      0.015   -1.06e+04   -1138.345
# textblob_processed_data_polarity_score          -5379.5557   3210.539     -1.676      0.094   -1.17e+04     919.942
# textblob_processed_data_subjectivity_score      -5874.5306   2413.797     -2.434      0.015   -1.06e+04   -1138.345
# vader_processed_data_score                       -907.5859   4001.299     -0.227      0.821   -8758.658    6943.486
# bert_processed_data_sentiment_score              7068.8981   3697.756      1.912      0.056    -186.582    1.43e+04
# roberta_processed_data_sentiment_score           1.073e+04   3770.291      2.845      0.005    3330.292    1.81e+04
# ==============================================================================
# Omnibus:                      116.637   Durbin-Watson:                   0.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.292
# Skew:                           0.153   Prob(JB):                     7.98e-09
# Kurtosis:                       2.153   Cond. No.                     5.80e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.53e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     6.971
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.74e-07
# Time:                        20:40:12   Log-Likelihood:                -12046.
# No. Observations:                1103   AIC:                         2.411e+04
# Df Residuals:                    1096   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.269e+04   1764.334     24.196      0.000    3.92e+04    4.62e+04
# flair_processed_data_score                       1083.2302   1926.678      0.562      0.574   -2697.164    4863.625
# spacytextblob_processed_data_polarity_score     -5456.0465   3206.201     -1.702      0.089   -1.17e+04     834.939
# spacytextblob_processed_data_subjectivity_score -6115.8266   2410.535     -2.537      0.011   -1.08e+04   -1386.041
# textblob_processed_data_polarity_score          -5456.0465   3206.201     -1.702      0.089   -1.17e+04     834.939
# textblob_processed_data_subjectivity_score      -6115.8266   2410.535     -2.537      0.011   -1.08e+04   -1386.041
# vader_processed_data_score                      -1350.9886   3995.892     -0.338      0.735   -9191.451    6489.474
# bert_processed_data_sentiment_score              7419.4396   3692.759      2.009      0.045     173.764    1.47e+04
# roberta_processed_data_sentiment_score           1.131e+04   3765.196      3.004      0.003    3921.048    1.87e+04
# ==============================================================================
# Omnibus:                      116.366   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.912
# Skew:                           0.145   Prob(JB):                     9.65e-09
# Kurtosis:                       2.152   Cond. No.                     5.80e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.53e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     7.003
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.52e-07
# Time:                        20:40:12   Log-Likelihood:                -12046.
# No. Observations:                1103   AIC:                         2.411e+04
# Df Residuals:                    1096   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.269e+04   1764.519     24.192      0.000    3.92e+04    4.61e+04
# flair_processed_data_score                        956.8174   1926.881      0.497      0.620   -2823.975    4737.610
# spacytextblob_processed_data_polarity_score     -5200.6143   3206.539     -1.622      0.105   -1.15e+04    1091.034
# spacytextblob_processed_data_subjectivity_score -6241.9769   2410.789     -2.589      0.010    -1.1e+04   -1511.693
# textblob_processed_data_polarity_score          -5200.6143   3206.539     -1.622      0.105   -1.15e+04    1091.034
# textblob_processed_data_subjectivity_score      -6241.9769   2410.789     -2.589      0.010    -1.1e+04   -1511.693
# vader_processed_data_score                      -1657.4151   3996.313     -0.415      0.678   -9498.704    6183.873
# bert_processed_data_sentiment_score              7390.0261   3693.148      2.001      0.046     143.587    1.46e+04
# roberta_processed_data_sentiment_score           1.162e+04   3765.593      3.085      0.002    4227.364     1.9e+04
# ==============================================================================
# Omnibus:                      117.012   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.789
# Skew:                           0.141   Prob(JB):                     1.03e-08
# Kurtosis:                       2.151   Cond. No.                     5.80e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.53e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     6.956
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.85e-07
# Time:                        20:40:12   Log-Likelihood:                -12047.
# No. Observations:                1103   AIC:                         2.411e+04
# Df Residuals:                    1096   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.262e+04   1765.023     24.146      0.000    3.92e+04    4.61e+04
# flair_processed_data_score                       1120.8341   1927.432      0.582      0.561   -2661.039    4902.707
# spacytextblob_processed_data_polarity_score     -5291.8466   3207.455     -1.650      0.099   -1.16e+04    1001.599
# spacytextblob_processed_data_subjectivity_score -6101.3142   2411.478     -2.530      0.012   -1.08e+04   -1369.679
# textblob_processed_data_polarity_score          -5291.8466   3207.455     -1.650      0.099   -1.16e+04    1001.599
# textblob_processed_data_subjectivity_score      -6101.3142   2411.478     -2.530      0.012   -1.08e+04   -1369.679
# vader_processed_data_score                      -1533.4211   3997.454     -0.384      0.701   -9376.950    6310.107
# bert_processed_data_sentiment_score              7126.6038   3694.203      1.929      0.054    -121.905    1.44e+04
# roberta_processed_data_sentiment_score           1.162e+04   3766.669      3.084      0.002    4227.540     1.9e+04
# ==============================================================================
# Omnibus:                      118.184   Durbin-Watson:                   0.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.918
# Skew:                           0.140   Prob(JB):                     9.63e-09
# Kurtosis:                       2.148   Cond. No.                     5.80e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.53e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     6.900
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           3.30e-07
# Time:                        20:40:12   Log-Likelihood:                -12048.
# No. Observations:                1103   AIC:                         2.411e+04
# Df Residuals:                    1096   BIC:                         2.415e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.272e+04   1767.829     24.165      0.000    3.93e+04    4.62e+04
# flair_processed_data_score                       1292.4054   1930.495      0.669      0.503   -2495.478    5080.288
# spacytextblob_processed_data_polarity_score     -5308.5436   3212.552     -1.652      0.099   -1.16e+04     994.904
# spacytextblob_processed_data_subjectivity_score -6108.5488   2415.310     -2.529      0.012   -1.08e+04   -1369.394
# textblob_processed_data_polarity_score          -5308.5436   3212.552     -1.652      0.099   -1.16e+04     994.904
# textblob_processed_data_subjectivity_score      -6108.5488   2415.310     -2.529      0.012   -1.08e+04   -1369.394
# vader_processed_data_score                      -1704.7615   4003.807     -0.426      0.670   -9560.755    6151.232
# bert_processed_data_sentiment_score              6947.0231   3700.074      1.878      0.061    -313.005    1.42e+04
# roberta_processed_data_sentiment_score           1.153e+04   3772.655      3.057      0.002    4129.678    1.89e+04
# ==============================================================================
# Omnibus:                      117.550   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.786
# Skew:                           0.139   Prob(JB):                     1.03e-08
# Kurtosis:                       2.149   Cond. No.                     5.80e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.53e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 4. 6H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_6hr_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     4.788
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           8.39e-05
# Time:                        20:40:43   Log-Likelihood:                -8150.0
# No. Observations:                 746   AIC:                         1.631e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.352e+04   2393.411     18.184      0.000    3.88e+04    4.82e+04
# flair_processed_data_score                       2701.8284   2630.628      1.027      0.305   -2462.566    7866.223
# spacytextblob_processed_data_polarity_score     -5270.0468   4274.852     -1.233      0.218   -1.37e+04    3122.254
# spacytextblob_processed_data_subjectivity_score -7231.9598   3237.034     -2.234      0.026   -1.36e+04    -877.083
# textblob_processed_data_polarity_score          -5270.0468   4274.852     -1.233      0.218   -1.37e+04    3122.254
# textblob_processed_data_subjectivity_score      -7231.9598   3237.034     -2.234      0.026   -1.36e+04    -877.083
# vader_processed_data_score                      -4409.3066   5345.549     -0.825      0.410   -1.49e+04    6084.964
# bert_processed_data_sentiment_score              4688.9027   4989.098      0.940      0.348   -5105.592    1.45e+04
# roberta_processed_data_sentiment_score           1.535e+04   5147.501      2.981      0.003    5240.143    2.55e+04
# ==============================================================================
# Omnibus:                       80.659   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.711
# Skew:                           0.152   Prob(JB):                     2.61e-06
# Kurtosis:                       2.143   Cond. No.                     9.34e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     5.316
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.21e-05
# Time:                        20:40:43   Log-Likelihood:                -8148.2
# No. Observations:                 746   AIC:                         1.631e+04
# Df Residuals:                     739   BIC:                         1.634e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.379e+04   2387.844     18.340      0.000    3.91e+04    4.85e+04
# flair_processed_data_score                       2525.8503   2624.509      0.962      0.336   -2626.532    7678.232
# spacytextblob_processed_data_polarity_score     -5056.0069   4264.909     -1.185      0.236   -1.34e+04    3316.774
# spacytextblob_processed_data_subjectivity_score -7720.8797   3229.504     -2.391      0.017   -1.41e+04   -1380.784
# textblob_processed_data_polarity_score          -5056.0069   4264.909     -1.185      0.236   -1.34e+04    3316.774
# textblob_processed_data_subjectivity_score      -7720.8797   3229.504     -2.391      0.017   -1.41e+04   -1380.784
# vader_processed_data_score                      -5309.9669   5333.115     -0.996      0.320   -1.58e+04    5159.894
# bert_processed_data_sentiment_score              5192.3929   4977.494      1.043      0.297   -4579.320     1.5e+04
# roberta_processed_data_sentiment_score           1.647e+04   5135.528      3.207      0.001    6389.321    2.66e+04
# ==============================================================================
# Omnibus:                       78.665   Durbin-Watson:                   0.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.093
# Skew:                           0.142   Prob(JB):                     3.56e-06
# Kurtosis:                       2.148   Cond. No.                     9.34e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     5.322
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.18e-05
# Time:                        20:40:43   Log-Likelihood:                -8148.2
# No. Observations:                 746   AIC:                         1.631e+04
# Df Residuals:                     739   BIC:                         1.634e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                             4.38e+04   2387.797     18.345      0.000    3.91e+04    4.85e+04
# flair_processed_data_score                       2472.4145   2624.457      0.942      0.346   -2679.866    7624.695
# spacytextblob_processed_data_polarity_score     -4994.8759   4264.825     -1.171      0.242   -1.34e+04    3377.740
# spacytextblob_processed_data_subjectivity_score -7786.4642   3229.441     -2.411      0.016   -1.41e+04   -1446.493
# textblob_processed_data_polarity_score          -4994.8759   4264.825     -1.171      0.242   -1.34e+04    3377.740
# textblob_processed_data_subjectivity_score      -7786.4642   3229.441     -2.411      0.016   -1.41e+04   -1446.493
# vader_processed_data_score                      -5504.3190   5333.010     -1.032      0.302    -1.6e+04    4965.335
# bert_processed_data_sentiment_score              5075.5888   4977.396      1.020      0.308   -4695.931    1.48e+04
# roberta_processed_data_sentiment_score           1.668e+04   5135.427      3.247      0.001    6594.395    2.68e+04
# ==============================================================================
# Omnibus:                       80.519   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.198
# Skew:                           0.136   Prob(JB):                     3.38e-06
# Kurtosis:                       2.142   Cond. No.                     9.34e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     5.318
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           2.20e-05
# Time:                        20:40:43   Log-Likelihood:                -8149.9
# No. Observations:                 746   AIC:                         1.631e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.399e+04   2393.255     18.380      0.000    3.93e+04    4.87e+04
# flair_processed_data_score                       2799.3699   2630.457      1.064      0.288   -2364.688    7963.428
# spacytextblob_processed_data_polarity_score     -5021.1478   4274.574     -1.175      0.241   -1.34e+04    3370.607
# spacytextblob_processed_data_subjectivity_score -7799.5078   3236.823     -2.410      0.016   -1.42e+04   -1445.045
# textblob_processed_data_polarity_score          -5021.1478   4274.574     -1.175      0.241   -1.34e+04    3370.607
# textblob_processed_data_subjectivity_score      -7799.5078   3236.823     -2.410      0.016   -1.42e+04   -1445.045
# vader_processed_data_score                      -5806.3018   5345.200     -1.086      0.278   -1.63e+04    4687.285
# bert_processed_data_sentiment_score              4869.8775   4988.773      0.976      0.329   -4923.979    1.47e+04
# roberta_processed_data_sentiment_score           1.651e+04   5147.166      3.207      0.001    6403.818    2.66e+04
# ==============================================================================
# Omnibus:                       79.851   Durbin-Watson:                   0.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.061
# Skew:                           0.135   Prob(JB):                     3.61e-06
# Kurtosis:                       2.144   Cond. No.                     9.34e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     5.465
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):           1.52e-05
# Time:                        20:40:43   Log-Likelihood:                -8157.4
# No. Observations:                 746   AIC:                         1.633e+04
# Df Residuals:                     739   BIC:                         1.636e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                              4.5e+04   2417.320     18.617      0.000    4.03e+04    4.97e+04
# flair_processed_data_score                       2957.7071   2656.906      1.113      0.266   -2258.275    8173.689
# spacytextblob_processed_data_polarity_score     -5141.4661   4317.554     -1.191      0.234   -1.36e+04    3334.667
# spacytextblob_processed_data_subjectivity_score -8781.2418   3269.369     -2.686      0.007   -1.52e+04   -2362.885
# textblob_processed_data_polarity_score          -5141.4661   4317.554     -1.191      0.234   -1.36e+04    3334.667
# textblob_processed_data_subjectivity_score      -8781.2418   3269.369     -2.686      0.007   -1.52e+04   -2362.885
# vader_processed_data_score                      -5658.9772   5398.946     -1.048      0.295   -1.63e+04    4940.122
# bert_processed_data_sentiment_score              5483.2371   5038.935      1.088      0.277   -4409.096    1.54e+04
# roberta_processed_data_sentiment_score           1.561e+04   5198.920      3.003      0.003    5405.143    2.58e+04
# ==============================================================================
# Omnibus:                       77.886   Durbin-Watson:                   0.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.937
# Skew:                           0.141   Prob(JB):                     3.85e-06
# Kurtosis:                       2.150   Cond. No.                     9.34e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 5. 1D Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1d_joined[['flair_processed_data_score', 'spacytextblob_processed_data_polarity_score', 'spacytextblob_processed_data_subjectivity_score', 'textblob_processed_data_polarity_score', 'textblob_processed_data_subjectivity_score', 'vader_processed_data_score', 'bert_processed_data_sentiment_score', 'roberta_processed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     2.824
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):             0.0114
# Time:                        20:41:25   Log-Likelihood:                -2544.7
# No. Observations:                 233   AIC:                             5103.
# Df Residuals:                     226   BIC:                             5128.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.919e+04   5503.329      7.122      0.000    2.83e+04       5e+04
# flair_processed_data_score                       5142.4950   6362.372      0.808      0.420   -7394.663    1.77e+04
# spacytextblob_processed_data_polarity_score     -2.127e+04   1.09e+04     -1.944      0.053   -4.28e+04     290.893
# spacytextblob_processed_data_subjectivity_score -2220.3639   7497.187     -0.296      0.767    -1.7e+04    1.26e+04
# textblob_processed_data_polarity_score          -2.127e+04   1.09e+04     -1.944      0.053   -4.28e+04     290.893
# textblob_processed_data_subjectivity_score      -2220.3639   7497.187     -0.296      0.767    -1.7e+04    1.26e+04
# vader_processed_data_score                       1.662e+04   1.43e+04      1.164      0.246   -1.15e+04    4.48e+04
# bert_processed_data_sentiment_score              1530.7836   1.34e+04      0.115      0.909   -2.48e+04    2.79e+04
# roberta_processed_data_sentiment_score           2.485e+04   1.32e+04      1.887      0.061   -1106.697    5.08e+04
# ==============================================================================
# Omnibus:                       15.740   Durbin-Watson:                   0.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.460
# Skew:                           0.217   Prob(JB):                       0.0240
# Kurtosis:                       2.238   Cond. No.                     1.56e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     3.332
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):            0.00365
# Time:                        20:41:25   Log-Likelihood:                -2542.6
# No. Observations:                 233   AIC:                             5099.
# Df Residuals:                     226   BIC:                             5123.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            3.936e+04   5454.515      7.216      0.000    2.86e+04    5.01e+04
# flair_processed_data_score                       4847.9005   6305.938      0.769      0.443   -7578.053    1.73e+04
# spacytextblob_processed_data_polarity_score     -2.205e+04   1.08e+04     -2.033      0.043   -4.34e+04    -677.218
# spacytextblob_processed_data_subjectivity_score -2861.4240   7430.687     -0.385      0.701   -1.75e+04    1.18e+04
# textblob_processed_data_polarity_score          -2.205e+04   1.08e+04     -2.033      0.043   -4.34e+04    -677.218
# textblob_processed_data_subjectivity_score      -2861.4240   7430.687     -0.385      0.701   -1.75e+04    1.18e+04
# vader_processed_data_score                       1.405e+04   1.42e+04      0.993      0.322   -1.38e+04    4.19e+04
# bert_processed_data_sentiment_score              1253.4918   1.32e+04      0.095      0.925   -2.48e+04    2.74e+04
# roberta_processed_data_sentiment_score           3.032e+04   1.31e+04      2.322      0.021    4584.848     5.6e+04
# ==============================================================================
# Omnibus:                       15.097   Durbin-Watson:                   0.157
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                6.953
# Skew:                           0.187   Prob(JB):                       0.0309
# Kurtosis:                       2.241   Cond. No.                     1.56e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     3.294
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):            0.00398
# Time:                        20:41:25   Log-Likelihood:                -2545.0
# No. Observations:                 233   AIC:                             5104.
# Df Residuals:                     226   BIC:                             5128.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.057e+04   5511.319      7.360      0.000    2.97e+04    5.14e+04
# flair_processed_data_score                       5773.6094   6371.609      0.906      0.366   -6781.750    1.83e+04
# spacytextblob_processed_data_polarity_score     -2.239e+04    1.1e+04     -2.043      0.042    -4.4e+04    -794.071
# spacytextblob_processed_data_subjectivity_score -3413.0913   7508.071     -0.455      0.650   -1.82e+04    1.14e+04
# textblob_processed_data_polarity_score          -2.239e+04    1.1e+04     -2.043      0.042    -4.4e+04    -794.071
# textblob_processed_data_subjectivity_score      -3413.0913   7508.071     -0.455      0.650   -1.82e+04    1.14e+04
# vader_processed_data_score                       1.184e+04   1.43e+04      0.828      0.409   -1.63e+04       4e+04
# bert_processed_data_sentiment_score              1745.1656   1.34e+04      0.130      0.896   -2.46e+04    2.81e+04
# roberta_processed_data_sentiment_score           2.996e+04   1.32e+04      2.271      0.024    3959.515     5.6e+04
# ==============================================================================
# Omnibus:                       15.493   Durbin-Watson:                   0.174
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.125
# Skew:                           0.194   Prob(JB):                       0.0284
# Kurtosis:                       2.236   Cond. No.                     1.56e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     3.266
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):            0.00424
# Time:                        20:41:25   Log-Likelihood:                -2547.4
# No. Observations:                 233   AIC:                             5109.
# Df Residuals:                     226   BIC:                             5133.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.241e+04   5566.656      7.619      0.000    3.14e+04    5.34e+04
# flair_processed_data_score                       5280.0083   6435.584      0.820      0.413   -7401.415     1.8e+04
# spacytextblob_processed_data_polarity_score     -2.423e+04   1.11e+04     -2.190      0.030    -4.6e+04   -2426.438
# spacytextblob_processed_data_subjectivity_score -4991.4389   7583.457     -0.658      0.511   -1.99e+04    9951.887
# textblob_processed_data_polarity_score          -2.423e+04   1.11e+04     -2.190      0.030    -4.6e+04   -2426.438
# textblob_processed_data_subjectivity_score      -4991.4389   7583.457     -0.658      0.511   -1.99e+04    9951.887
# vader_processed_data_score                       9763.8431   1.44e+04      0.676      0.500   -1.87e+04    3.82e+04
# bert_processed_data_sentiment_score              3288.9620   1.35e+04      0.243      0.808   -2.34e+04    2.99e+04
# roberta_processed_data_sentiment_score           3.022e+04   1.33e+04      2.268      0.024    3959.240    5.65e+04
# ==============================================================================
# Omnibus:                       13.207   Durbin-Watson:                   0.183
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                6.619
# Skew:                           0.198   Prob(JB):                       0.0365
# Kurtosis:                       2.276   Cond. No.                     1.56e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     3.861
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):            0.00109
# Time:                        20:41:25   Log-Likelihood:                -2544.2
# No. Observations:                 233   AIC:                             5102.
# Df Residuals:                     226   BIC:                             5127.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            4.426e+04   5491.938      8.058      0.000    3.34e+04    5.51e+04
# flair_processed_data_score                       5187.4283   6349.203      0.817      0.415   -7323.780    1.77e+04
# spacytextblob_processed_data_polarity_score     -2.608e+04   1.09e+04     -2.388      0.018   -4.76e+04   -4563.364
# spacytextblob_processed_data_subjectivity_score -6467.4201   7481.669     -0.864      0.388   -2.12e+04    8275.329
# textblob_processed_data_polarity_score          -2.608e+04   1.09e+04     -2.388      0.018   -4.76e+04   -4563.364
# textblob_processed_data_subjectivity_score      -6467.4201   7481.669     -0.864      0.388   -2.12e+04    8275.329
# vader_processed_data_score                       9224.4471   1.42e+04      0.647      0.518   -1.89e+04    3.73e+04
# bert_processed_data_sentiment_score              5843.5251   1.33e+04      0.438      0.662   -2.04e+04    3.21e+04
# roberta_processed_data_sentiment_score           3.126e+04   1.31e+04      2.378      0.018    5353.402    5.72e+04
# ==============================================================================
# Omnibus:                       22.527   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.548
# Skew:                           0.083   Prob(JB):                       0.0230
# Kurtosis:                       2.134   Cond. No.                     1.56e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
