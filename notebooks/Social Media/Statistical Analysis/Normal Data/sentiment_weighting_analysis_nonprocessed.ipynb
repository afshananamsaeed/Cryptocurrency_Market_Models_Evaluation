# %%
import pandas as pd
import numpy as np
import os
import datetime
os.chdir('/home/ubuntu/Masters Thesis/')
from scripts.utilities.data_joining import GetModellingData

# %% [markdown]
# Data without Bots and no text processing

# %%
bitcoin_hourly = pd.read_csv("/mnt/bitcoin_hourly_prices_till_2023-03-30.csv", lineterminator='\n')
bitcoin_minutely = pd.read_csv("/mnt/bitcoin_price_minutely_data_till_2023_03_30.csv", lineterminator='\n')

# %%
bitcoin_minutely
# Out:
#                time exchange fsym tsym     close      high       low  \
# 0        1606780800   CCCAGG  BTC  USD  19704.72  19714.44  19686.87
# 1        1606780860   CCCAGG  BTC  USD  19682.63  19706.49  19674.34
# 2        1606780920   CCCAGG  BTC  USD  19688.59  19691.33  19654.82
# 3        1606780980   CCCAGG  BTC  USD  19664.79  19697.12  19659.91
# 4        1606781040   CCCAGG  BTC  USD  19628.40  19665.60  19623.03
# ...             ...      ...  ...  ...       ...       ...       ...
# 1223995  1680220500   CCCAGG  BTC  USD  28038.57  28044.74  28032.44
# 1223996  1680220560   CCCAGG  BTC  USD  28037.36  28043.24  28031.83
# 1223997  1680220620   CCCAGG  BTC  USD  28031.20  28039.71  28030.25
# 1223998  1680220680   CCCAGG  BTC  USD  28037.81  28038.74  28029.52
# 1223999  1680220740   CCCAGG  BTC  USD  28040.71  28052.54  28036.36
#
#              open  volumefrom    volumeto
# 0        19686.87      58.620  1151502.04
# 1        19704.72     132.800  2614001.65
# 2        19682.63      55.390  1090096.41
# 3        19688.59      51.070  1004714.46
# 4        19664.79     109.540  2149088.17
# ...           ...         ...         ...
# 1223995  28032.49      11.500   322442.59
# 1223996  28038.57      20.120   564252.17
# 1223997  28037.36      12.290   344664.77
# 1223998  28031.20       8.527   239073.67
# 1223999  28037.81      75.070  2105709.79
#
# [1224000 rows x 10 columns]

# %%
data_30min = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_30T_nonprocessed.csv", lineterminator='\n')
data_1hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_1H_nonprocessed.csv", lineterminator='\n')
data_4hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_4H_nonprocessed.csv", lineterminator='\n')
data_6hrs = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_6H_nonprocessed.csv", lineterminator='\n')
data_1day = pd.read_csv("/home/ubuntu/Masters Thesis/data/final/sentiment_weighted_scores/Without_bots/weighted_scores_bitcoin_tweets_wo_bots_interval_D_nonprocessed.csv", lineterminator='\n')

# %%
data_30min = data_30min[~data_30min['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_1hrs = data_1hrs[~data_1hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_4hrs = data_4hrs[~data_4hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_6hrs = data_6hrs[~data_6hrs['spacytextblob_nonprocessed_data_polarity_score'].isna()]
data_1day = data_1day[~data_1day['spacytextblob_nonprocessed_data_polarity_score'].isna()]

data_30min = data_30min.drop(columns=['Unnamed: 0'])
data_1hrs = data_1hrs.drop(columns=['Unnamed: 0'])
data_4hrs = data_4hrs.drop(columns=['Unnamed: 0'])
data_6hrs = data_6hrs.drop(columns=['Unnamed: 0'])
data_1day = data_1day.drop(columns=['Unnamed: 0'])

# %%
bitcoin_minutely = bitcoin_minutely.rename(columns={'time': 'date'})
bitcoin_minutely['date'] = bitcoin_minutely['date'].apply(datetime.datetime.utcfromtimestamp)
bitcoin_hourly = bitcoin_hourly.rename(columns={'datetimes': 'date'})
bitcoin_hourly['date'] = pd.to_datetime(bitcoin_hourly['date'])

# %%
data_30min_joined = GetModellingData(data=data_30min, bitcoin_data=bitcoin_minutely, frequency='30T').get_data_for_feature_analysis()
data_1hr_joined = GetModellingData(data=data_1hrs, bitcoin_data=bitcoin_hourly, frequency='1H').get_data_for_feature_analysis()
data_4hr_joined = GetModellingData(data=data_4hrs, bitcoin_data=bitcoin_hourly, frequency='4H').get_data_for_feature_analysis()
data_6hr_joined = GetModellingData(data=data_6hrs, bitcoin_data=bitcoin_hourly, frequency='6H').get_data_for_feature_analysis()
data_1d_joined = GetModellingData(data=data_1day, bitcoin_data=bitcoin_hourly, frequency='1D').get_data_for_feature_analysis()
# Out:
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])
# /home/ubuntu/Masters Thesis/scripts/utilities/data_joining.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_data['date'] = pd.to_datetime(bitcoin_data['date'])

# %%
data_30min_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_30min_joined.dropna(inplace=True)
data_1hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1hr_joined.dropna(inplace=True)
data_4hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_4hr_joined.dropna(inplace=True)
data_6hr_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_6hr_joined.dropna(inplace=True)
data_1d_joined.replace([np.inf, -np.inf], np.nan, inplace=True)
data_1d_joined.dropna(inplace=True)

# %% [markdown]
# ### Plots and Analysis

# %% [markdown]
# 1. 30T Frequency

# %%
# correlation analysis - pearson
data_30min_joined.corr()
# Out:
#                                                         date  \
# date                                                1.000000
# flair_nonprocessed_data_score                      -0.055295
# spacytextblob_nonprocessed_data_polarity_score      0.051786
# spacytextblob_nonprocessed_data_subjectivity_score  0.076462
# textblob_nonprocessed_data_polarity_score           0.051786
# textblob_nonprocessed_data_subjectivity_score       0.076462
# vader_nonprocessed_data_score                      -0.009707
# bert_nonprocessed_data_sentiment_score              0.044591
# roberta_nonprocessed_data_sentiment_score          -0.003914
# close                                              -0.715462
# close_t+1                                          -0.715688
# close_t+2                                          -0.715899
# close_t+3                                          -0.716097
# close_t+7                                          -0.716907
#
#                                                     flair_nonprocessed_data_score  \
# date                                                                    -0.055295
# flair_nonprocessed_data_score                                            1.000000
# spacytextblob_nonprocessed_data_polarity_score                           0.280550
# spacytextblob_nonprocessed_data_subjectivity_score                       0.084409
# textblob_nonprocessed_data_polarity_score                                0.280550
# textblob_nonprocessed_data_subjectivity_score                            0.084409
# vader_nonprocessed_data_score                                            0.302344
# bert_nonprocessed_data_sentiment_score                                   0.600137
# roberta_nonprocessed_data_sentiment_score                                0.456380
# close                                                                    0.066968
# close_t+1                                                                0.067005
# close_t+2                                                                0.067114
# close_t+3                                                                0.067427
# close_t+7                                                                0.067230
#
#                                                     spacytextblob_nonprocessed_data_polarity_score  \
# date                                                                                      0.051786
# flair_nonprocessed_data_score                                                             0.280550
# spacytextblob_nonprocessed_data_polarity_score                                            1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                        0.323461
# textblob_nonprocessed_data_polarity_score                                                 1.000000
# textblob_nonprocessed_data_subjectivity_score                                             0.323461
# vader_nonprocessed_data_score                                                             0.401775
# bert_nonprocessed_data_sentiment_score                                                    0.371176
# roberta_nonprocessed_data_sentiment_score                                                 0.385304
# close                                                                                    -0.026311
# close_t+1                                                                                -0.026331
# close_t+2                                                                                -0.026289
# close_t+3                                                                                -0.026223
# close_t+7                                                                                -0.026688
#
#                                                     spacytextblob_nonprocessed_data_subjectivity_score  \
# date                                                                                         0.076462
# flair_nonprocessed_data_score                                                                0.084409
# spacytextblob_nonprocessed_data_polarity_score                                               0.323461
# spacytextblob_nonprocessed_data_subjectivity_score                                           1.000000
# textblob_nonprocessed_data_polarity_score                                                    0.323461
# textblob_nonprocessed_data_subjectivity_score                                                1.000000
# vader_nonprocessed_data_score                                                                0.163166
# bert_nonprocessed_data_sentiment_score                                                       0.127113
# roberta_nonprocessed_data_sentiment_score                                                    0.104720
# close                                                                                       -0.064890
# close_t+1                                                                                   -0.065046
# close_t+2                                                                                   -0.065332
# close_t+3                                                                                   -0.065288
# close_t+7                                                                                   -0.066001
#
#                                                     textblob_nonprocessed_data_polarity_score  \
# date                                                                                 0.051786
# flair_nonprocessed_data_score                                                        0.280550
# spacytextblob_nonprocessed_data_polarity_score                                       1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.323461
# textblob_nonprocessed_data_polarity_score                                            1.000000
# textblob_nonprocessed_data_subjectivity_score                                        0.323461
# vader_nonprocessed_data_score                                                        0.401775
# bert_nonprocessed_data_sentiment_score                                               0.371176
# roberta_nonprocessed_data_sentiment_score                                            0.385304
# close                                                                               -0.026311
# close_t+1                                                                           -0.026331
# close_t+2                                                                           -0.026289
# close_t+3                                                                           -0.026223
# close_t+7                                                                           -0.026688
#
#                                                     textblob_nonprocessed_data_subjectivity_score  \
# date                                                                                     0.076462
# flair_nonprocessed_data_score                                                            0.084409
# spacytextblob_nonprocessed_data_polarity_score                                           0.323461
# spacytextblob_nonprocessed_data_subjectivity_score                                       1.000000
# textblob_nonprocessed_data_polarity_score                                                0.323461
# textblob_nonprocessed_data_subjectivity_score                                            1.000000
# vader_nonprocessed_data_score                                                            0.163166
# bert_nonprocessed_data_sentiment_score                                                   0.127113
# roberta_nonprocessed_data_sentiment_score                                                0.104720
# close                                                                                   -0.064890
# close_t+1                                                                               -0.065046
# close_t+2                                                                               -0.065332
# close_t+3                                                                               -0.065288
# close_t+7                                                                               -0.066001
#
#                                                     vader_nonprocessed_data_score  \
# date                                                                    -0.009707
# flair_nonprocessed_data_score                                            0.302344
# spacytextblob_nonprocessed_data_polarity_score                           0.401775
# spacytextblob_nonprocessed_data_subjectivity_score                       0.163166
# textblob_nonprocessed_data_polarity_score                                0.401775
# textblob_nonprocessed_data_subjectivity_score                            0.163166
# vader_nonprocessed_data_score                                            1.000000
# bert_nonprocessed_data_sentiment_score                                   0.434742
# roberta_nonprocessed_data_sentiment_score                                0.534844
# close                                                                    0.042573
# close_t+1                                                                0.042776
# close_t+2                                                                0.042706
# close_t+3                                                                0.042633
# close_t+7                                                                0.042658
#
#                                                     bert_nonprocessed_data_sentiment_score  \
# date                                                                              0.044591
# flair_nonprocessed_data_score                                                     0.600137
# spacytextblob_nonprocessed_data_polarity_score                                    0.371176
# spacytextblob_nonprocessed_data_subjectivity_score                                0.127113
# textblob_nonprocessed_data_polarity_score                                         0.371176
# textblob_nonprocessed_data_subjectivity_score                                     0.127113
# vader_nonprocessed_data_score                                                     0.434742
# bert_nonprocessed_data_sentiment_score                                            1.000000
# roberta_nonprocessed_data_sentiment_score                                         0.562091
# close                                                                            -0.002739
# close_t+1                                                                        -0.002491
# close_t+2                                                                        -0.002548
# close_t+3                                                                        -0.002269
# close_t+7                                                                        -0.002057
#
#                                                     roberta_nonprocessed_data_sentiment_score  \
# date                                                                                -0.003914
# flair_nonprocessed_data_score                                                        0.456380
# spacytextblob_nonprocessed_data_polarity_score                                       0.385304
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.104720
# textblob_nonprocessed_data_polarity_score                                            0.385304
# textblob_nonprocessed_data_subjectivity_score                                        0.104720
# vader_nonprocessed_data_score                                                        0.534844
# bert_nonprocessed_data_sentiment_score                                               0.562091
# roberta_nonprocessed_data_sentiment_score                                            1.000000
# close                                                                                0.060464
# close_t+1                                                                            0.060933
# close_t+2                                                                            0.060807
# close_t+3                                                                            0.061032
# close_t+7                                                                            0.061104
#
#                                                        close  close_t+1  \
# date                                               -0.715462  -0.715688
# flair_nonprocessed_data_score                       0.066968   0.067005
# spacytextblob_nonprocessed_data_polarity_score     -0.026311  -0.026331
# spacytextblob_nonprocessed_data_subjectivity_score -0.064890  -0.065046
# textblob_nonprocessed_data_polarity_score          -0.026311  -0.026331
# textblob_nonprocessed_data_subjectivity_score      -0.064890  -0.065046
# vader_nonprocessed_data_score                       0.042573   0.042776
# bert_nonprocessed_data_sentiment_score             -0.002739  -0.002491
# roberta_nonprocessed_data_sentiment_score           0.060464   0.060933
# close                                               1.000000   0.999861
# close_t+1                                           0.999861   1.000000
# close_t+2                                           0.999727   0.999861
# close_t+3                                           0.999591   0.999726
# close_t+7                                           0.999026   0.999169
#
#                                                     close_t+2  close_t+3  \
# date                                                -0.715899  -0.716097
# flair_nonprocessed_data_score                        0.067114   0.067427
# spacytextblob_nonprocessed_data_polarity_score      -0.026289  -0.026223
# spacytextblob_nonprocessed_data_subjectivity_score  -0.065332  -0.065288
# textblob_nonprocessed_data_polarity_score           -0.026289  -0.026223
# textblob_nonprocessed_data_subjectivity_score       -0.065332  -0.065288
# vader_nonprocessed_data_score                        0.042706   0.042633
# bert_nonprocessed_data_sentiment_score              -0.002548  -0.002269
# roberta_nonprocessed_data_sentiment_score            0.060807   0.061032
# close                                                0.999727   0.999591
# close_t+1                                            0.999861   0.999726
# close_t+2                                            1.000000   0.999861
# close_t+3                                            0.999861   1.000000
# close_t+7                                            0.999311   0.999452
#
#                                                     close_t+7
# date                                                -0.716907
# flair_nonprocessed_data_score                        0.067230
# spacytextblob_nonprocessed_data_polarity_score      -0.026688
# spacytextblob_nonprocessed_data_subjectivity_score  -0.066001
# textblob_nonprocessed_data_polarity_score           -0.026688
# textblob_nonprocessed_data_subjectivity_score       -0.066001
# vader_nonprocessed_data_score                        0.042658
# bert_nonprocessed_data_sentiment_score              -0.002057
# roberta_nonprocessed_data_sentiment_score            0.061104
# close                                                0.999026
# close_t+1                                            0.999169
# close_t+2                                            0.999311
# close_t+3                                            0.999452
# close_t+7                                            1.000000

# %% [markdown]
# Very bad correlation between all the weighted sentiment features and the closing dates

# %%
# correlation analysis - spearman
data_30min_joined.corr(method='spearman')
# Out:
#                                                         date  \
# date                                                1.000000
# flair_nonprocessed_data_score                      -0.054614
# spacytextblob_nonprocessed_data_polarity_score      0.058065
# spacytextblob_nonprocessed_data_subjectivity_score  0.073617
# textblob_nonprocessed_data_polarity_score           0.058065
# textblob_nonprocessed_data_subjectivity_score       0.073617
# vader_nonprocessed_data_score                      -0.014358
# bert_nonprocessed_data_sentiment_score              0.036793
# roberta_nonprocessed_data_sentiment_score          -0.004727
# close                                              -0.691603
# close_t+1                                          -0.691964
# close_t+2                                          -0.692305
# close_t+3                                          -0.692642
# close_t+7                                          -0.694032
#
#                                                     flair_nonprocessed_data_score  \
# date                                                                    -0.054614
# flair_nonprocessed_data_score                                            1.000000
# spacytextblob_nonprocessed_data_polarity_score                           0.277893
# spacytextblob_nonprocessed_data_subjectivity_score                       0.084542
# textblob_nonprocessed_data_polarity_score                                0.277893
# textblob_nonprocessed_data_subjectivity_score                            0.084542
# vader_nonprocessed_data_score                                            0.293418
# bert_nonprocessed_data_sentiment_score                                   0.585134
# roberta_nonprocessed_data_sentiment_score                                0.438993
# close                                                                    0.075447
# close_t+1                                                                0.075311
# close_t+2                                                                0.075472
# close_t+3                                                                0.075814
# close_t+7                                                                0.075264
#
#                                                     spacytextblob_nonprocessed_data_polarity_score  \
# date                                                                                      0.058065
# flair_nonprocessed_data_score                                                             0.277893
# spacytextblob_nonprocessed_data_polarity_score                                            1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                        0.399892
# textblob_nonprocessed_data_polarity_score                                                 1.000000
# textblob_nonprocessed_data_subjectivity_score                                             0.399892
# vader_nonprocessed_data_score                                                             0.400431
# bert_nonprocessed_data_sentiment_score                                                    0.350227
# roberta_nonprocessed_data_sentiment_score                                                 0.369771
# close                                                                                    -0.019903
# close_t+1                                                                                -0.019891
# close_t+2                                                                                -0.019926
# close_t+3                                                                                -0.019858
# close_t+7                                                                                -0.020696
#
#                                                     spacytextblob_nonprocessed_data_subjectivity_score  \
# date                                                                                         0.073617
# flair_nonprocessed_data_score                                                                0.084542
# spacytextblob_nonprocessed_data_polarity_score                                               0.399892
# spacytextblob_nonprocessed_data_subjectivity_score                                           1.000000
# textblob_nonprocessed_data_polarity_score                                                    0.399892
# textblob_nonprocessed_data_subjectivity_score                                                1.000000
# vader_nonprocessed_data_score                                                                0.199156
# bert_nonprocessed_data_sentiment_score                                                       0.122171
# roberta_nonprocessed_data_sentiment_score                                                    0.115852
# close                                                                                       -0.069638
# close_t+1                                                                                   -0.069725
# close_t+2                                                                                   -0.070141
# close_t+3                                                                                   -0.070069
# close_t+7                                                                                   -0.071113
#
#                                                     textblob_nonprocessed_data_polarity_score  \
# date                                                                                 0.058065
# flair_nonprocessed_data_score                                                        0.277893
# spacytextblob_nonprocessed_data_polarity_score                                       1.000000
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.399892
# textblob_nonprocessed_data_polarity_score                                            1.000000
# textblob_nonprocessed_data_subjectivity_score                                        0.399892
# vader_nonprocessed_data_score                                                        0.400431
# bert_nonprocessed_data_sentiment_score                                               0.350227
# roberta_nonprocessed_data_sentiment_score                                            0.369771
# close                                                                               -0.019903
# close_t+1                                                                           -0.019891
# close_t+2                                                                           -0.019926
# close_t+3                                                                           -0.019858
# close_t+7                                                                           -0.020696
#
#                                                     textblob_nonprocessed_data_subjectivity_score  \
# date                                                                                     0.073617
# flair_nonprocessed_data_score                                                            0.084542
# spacytextblob_nonprocessed_data_polarity_score                                           0.399892
# spacytextblob_nonprocessed_data_subjectivity_score                                       1.000000
# textblob_nonprocessed_data_polarity_score                                                0.399892
# textblob_nonprocessed_data_subjectivity_score                                            1.000000
# vader_nonprocessed_data_score                                                            0.199156
# bert_nonprocessed_data_sentiment_score                                                   0.122171
# roberta_nonprocessed_data_sentiment_score                                                0.115852
# close                                                                                   -0.069638
# close_t+1                                                                               -0.069725
# close_t+2                                                                               -0.070141
# close_t+3                                                                               -0.070069
# close_t+7                                                                               -0.071113
#
#                                                     vader_nonprocessed_data_score  \
# date                                                                    -0.014358
# flair_nonprocessed_data_score                                            0.293418
# spacytextblob_nonprocessed_data_polarity_score                           0.400431
# spacytextblob_nonprocessed_data_subjectivity_score                       0.199156
# textblob_nonprocessed_data_polarity_score                                0.400431
# textblob_nonprocessed_data_subjectivity_score                            0.199156
# vader_nonprocessed_data_score                                            1.000000
# bert_nonprocessed_data_sentiment_score                                   0.409106
# roberta_nonprocessed_data_sentiment_score                                0.502452
# close                                                                    0.049050
# close_t+1                                                                0.049306
# close_t+2                                                                0.049296
# close_t+3                                                                0.048989
# close_t+7                                                                0.048656
#
#                                                     bert_nonprocessed_data_sentiment_score  \
# date                                                                              0.036793
# flair_nonprocessed_data_score                                                     0.585134
# spacytextblob_nonprocessed_data_polarity_score                                    0.350227
# spacytextblob_nonprocessed_data_subjectivity_score                                0.122171
# textblob_nonprocessed_data_polarity_score                                         0.350227
# textblob_nonprocessed_data_subjectivity_score                                     0.122171
# vader_nonprocessed_data_score                                                     0.409106
# bert_nonprocessed_data_sentiment_score                                            1.000000
# roberta_nonprocessed_data_sentiment_score                                         0.532980
# close                                                                             0.005088
# close_t+1                                                                         0.005457
# close_t+2                                                                         0.005355
# close_t+3                                                                         0.005613
# close_t+7                                                                         0.005416
#
#                                                     roberta_nonprocessed_data_sentiment_score  \
# date                                                                                -0.004727
# flair_nonprocessed_data_score                                                        0.438993
# spacytextblob_nonprocessed_data_polarity_score                                       0.369771
# spacytextblob_nonprocessed_data_subjectivity_score                                   0.115852
# textblob_nonprocessed_data_polarity_score                                            0.369771
# textblob_nonprocessed_data_subjectivity_score                                        0.115852
# vader_nonprocessed_data_score                                                        0.502452
# bert_nonprocessed_data_sentiment_score                                               0.532980
# roberta_nonprocessed_data_sentiment_score                                            1.000000
# close                                                                                0.070114
# close_t+1                                                                            0.070676
# close_t+2                                                                            0.070728
# close_t+3                                                                            0.070782
# close_t+7                                                                            0.070812
#
#                                                        close  close_t+1  \
# date                                               -0.691603  -0.691964
# flair_nonprocessed_data_score                       0.075447   0.075311
# spacytextblob_nonprocessed_data_polarity_score     -0.019903  -0.019891
# spacytextblob_nonprocessed_data_subjectivity_score -0.069638  -0.069725
# textblob_nonprocessed_data_polarity_score          -0.019903  -0.019891
# textblob_nonprocessed_data_subjectivity_score      -0.069638  -0.069725
# vader_nonprocessed_data_score                       0.049050   0.049306
# bert_nonprocessed_data_sentiment_score              0.005088   0.005457
# roberta_nonprocessed_data_sentiment_score           0.070114   0.070676
# close                                               1.000000   0.999712
# close_t+1                                           0.999712   1.000000
# close_t+2                                           0.999436   0.999714
# close_t+3                                           0.999177   0.999437
# close_t+7                                           0.998089   0.998373
#
#                                                     close_t+2  close_t+3  \
# date                                                -0.692305  -0.692642
# flair_nonprocessed_data_score                        0.075472   0.075814
# spacytextblob_nonprocessed_data_polarity_score      -0.019926  -0.019858
# spacytextblob_nonprocessed_data_subjectivity_score  -0.070141  -0.070069
# textblob_nonprocessed_data_polarity_score           -0.019926  -0.019858
# textblob_nonprocessed_data_subjectivity_score       -0.070141  -0.070069
# vader_nonprocessed_data_score                        0.049296   0.048989
# bert_nonprocessed_data_sentiment_score               0.005355   0.005613
# roberta_nonprocessed_data_sentiment_score            0.070728   0.070782
# close                                                0.999436   0.999177
# close_t+1                                            0.999714   0.999437
# close_t+2                                            1.000000   0.999715
# close_t+3                                            0.999715   1.000000
# close_t+7                                            0.998654   0.998927
#
#                                                     close_t+7
# date                                                -0.694032
# flair_nonprocessed_data_score                        0.075264
# spacytextblob_nonprocessed_data_polarity_score      -0.020696
# spacytextblob_nonprocessed_data_subjectivity_score  -0.071113
# textblob_nonprocessed_data_polarity_score           -0.020696
# textblob_nonprocessed_data_subjectivity_score       -0.071113
# vader_nonprocessed_data_score                        0.048656
# bert_nonprocessed_data_sentiment_score               0.005416
# roberta_nonprocessed_data_sentiment_score            0.070812
# close                                                0.998089
# close_t+1                                            0.998373
# close_t+2                                            0.998654
# close_t+3                                            0.998927
# close_t+7                                            1.000000

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_30min_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_30min_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.41
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           4.48e-30
# Time:                        13:09:19   Log-Likelihood:                -91458.
# No. Observations:                8367   AIC:                         1.829e+05
# Df Residuals:                    8360   BIC:                         1.830e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.876e+04    437.344     88.622      0.000    3.79e+04    3.96e+04
# flair_nonprocessed_data_score                       2817.2521    403.986      6.974      0.000    2025.340    3609.165
# spacytextblob_nonprocessed_data_polarity_score     -2294.5241    689.060     -3.330      0.001   -3645.252    -943.797
# spacytextblob_nonprocessed_data_subjectivity_score -2785.2381    518.116     -5.376      0.000   -3800.874   -1769.602
# textblob_nonprocessed_data_polarity_score          -2294.5241    689.060     -3.330      0.001   -3645.252    -943.797
# textblob_nonprocessed_data_subjectivity_score      -2785.2381    518.116     -5.376      0.000   -3800.874   -1769.602
# vader_nonprocessed_data_score                       2918.7888    864.498      3.376      0.001    1224.158    4613.419
# bert_nonprocessed_data_sentiment_score             -5651.7794    902.401     -6.263      0.000   -7420.710   -3882.849
# roberta_nonprocessed_data_sentiment_score           3830.5576    812.616      4.714      0.000    2237.630    5423.485
# ==============================================================================
# Omnibus:                     1135.159   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.535
# Skew:                           0.153   Prob(JB):                     3.70e-68
# Kurtosis:                       2.108   Cond. No.                     2.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.50
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           3.44e-30
# Time:                        13:09:19   Log-Likelihood:                -91458.
# No. Observations:                8367   AIC:                         1.829e+05
# Df Residuals:                    8360   BIC:                         1.830e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.876e+04    437.323     88.625      0.000    3.79e+04    3.96e+04
# flair_nonprocessed_data_score                       2809.4574    403.966      6.955      0.000    2017.584    3601.331
# spacytextblob_nonprocessed_data_polarity_score     -2304.0823    689.025     -3.344      0.001   -3654.743    -953.422
# spacytextblob_nonprocessed_data_subjectivity_score -2792.3137    518.090     -5.390      0.000   -3807.899   -1776.728
# textblob_nonprocessed_data_polarity_score          -2304.0823    689.025     -3.344      0.001   -3654.743    -953.422
# textblob_nonprocessed_data_subjectivity_score      -2792.3137    518.090     -5.390      0.000   -3807.899   -1776.728
# vader_nonprocessed_data_score                       2918.4813    864.455      3.376      0.001    1223.935    4613.027
# bert_nonprocessed_data_sentiment_score             -5641.7118    902.356     -6.252      0.000   -7410.554   -3872.869
# roberta_nonprocessed_data_sentiment_score           3862.9455    812.575      4.754      0.000    2270.097    5455.794
# ==============================================================================
# Omnibus:                     1134.306   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.189
# Skew:                           0.153   Prob(JB):                     4.40e-68
# Kurtosis:                       2.108   Cond. No.                     2.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.56
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.91e-30
# Time:                        13:09:19   Log-Likelihood:                -91458.
# No. Observations:                8367   AIC:                         1.829e+05
# Df Residuals:                    8360   BIC:                         1.830e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.877e+04    437.300     88.651      0.000    3.79e+04    3.96e+04
# flair_nonprocessed_data_score                       2816.6811    403.945      6.973      0.000    2024.848    3608.514
# spacytextblob_nonprocessed_data_polarity_score     -2292.7550    688.990     -3.328      0.001   -3643.347    -942.163
# spacytextblob_nonprocessed_data_subjectivity_score -2807.3991    518.064     -5.419      0.000   -3822.933   -1791.865
# textblob_nonprocessed_data_polarity_score          -2292.7550    688.990     -3.328      0.001   -3643.347    -942.163
# textblob_nonprocessed_data_subjectivity_score      -2807.3991    518.064     -5.419      0.000   -3822.933   -1791.865
# vader_nonprocessed_data_score                       2917.7906    864.411      3.375      0.001    1223.331    4612.251
# bert_nonprocessed_data_sentiment_score             -5648.5939    902.311     -6.260      0.000   -7417.346   -3879.842
# roberta_nonprocessed_data_sentiment_score           3850.9466    812.534      4.739      0.000    2258.179    5443.714
# ==============================================================================
# Omnibus:                     1132.662   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.835
# Skew:                           0.152   Prob(JB):                     5.25e-68
# Kurtosis:                       2.108   Cond. No.                     2.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.59
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.67e-30
# Time:                        13:09:19   Log-Likelihood:                -91457.
# No. Observations:                8367   AIC:                         1.829e+05
# Df Residuals:                    8360   BIC:                         1.830e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.877e+04    437.298     88.658      0.000    3.79e+04    3.96e+04
# flair_nonprocessed_data_score                       2822.9366    403.943      6.988      0.000    2031.108    3614.765
# spacytextblob_nonprocessed_data_polarity_score     -2293.9924    688.986     -3.330      0.001   -3644.576    -943.409
# spacytextblob_nonprocessed_data_subjectivity_score -2805.5337    518.061     -5.415      0.000   -3821.061   -1790.006
# textblob_nonprocessed_data_polarity_score          -2293.9924    688.986     -3.330      0.001   -3644.576    -943.409
# textblob_nonprocessed_data_subjectivity_score      -2805.5337    518.061     -5.415      0.000   -3821.061   -1790.006
# vader_nonprocessed_data_score                       2897.0238    864.406      3.351      0.001    1202.574    4591.474
# bert_nonprocessed_data_sentiment_score             -5637.8645    902.305     -6.248      0.000   -7406.606   -3869.123
# roberta_nonprocessed_data_sentiment_score           3862.2754    812.529      4.753      0.000    2269.517    5455.034
# ==============================================================================
# Omnibus:                     1130.241   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.366
# Skew:                           0.152   Prob(JB):                     6.64e-68
# Kurtosis:                       2.108   Cond. No.                     2.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     25.68
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.05e-30
# Time:                        13:09:19   Log-Likelihood:                -91457.
# No. Observations:                8367   AIC:                         1.829e+05
# Df Residuals:                    8360   BIC:                         1.830e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.879e+04    437.296     88.711      0.000    3.79e+04    3.97e+04
# flair_nonprocessed_data_score                       2808.7156    403.941      6.953      0.000    2016.891    3600.541
# spacytextblob_nonprocessed_data_polarity_score     -2318.2071    688.983     -3.365      0.001   -3668.785    -967.629
# spacytextblob_nonprocessed_data_subjectivity_score -2834.4484    518.059     -5.471      0.000   -3849.972   -1818.925
# textblob_nonprocessed_data_polarity_score          -2318.2071    688.983     -3.365      0.001   -3668.785    -967.629
# textblob_nonprocessed_data_subjectivity_score      -2834.4484    518.059     -5.471      0.000   -3849.972   -1818.925
# vader_nonprocessed_data_score                       2904.8890    864.402      3.361      0.001    1210.446    4599.332
# bert_nonprocessed_data_sentiment_score             -5600.1132    902.302     -6.206      0.000   -7368.848   -3831.379
# roberta_nonprocessed_data_sentiment_score           3868.6294    812.526      4.761      0.000    2275.878    5461.381
# ==============================================================================
# Omnibus:                     1134.599   Durbin-Watson:                   0.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.922
# Skew:                           0.149   Prob(JB):                     8.29e-68
# Kurtosis:                       2.107   Cond. No.                     2.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 2. 1H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     15.99
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.86e-18
# Time:                        13:09:19   Log-Likelihood:                -46094.
# No. Observations:                4218   AIC:                         9.220e+04
# Df Residuals:                    4211   BIC:                         9.225e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.882e+04    695.249     55.829      0.000    3.75e+04    4.02e+04
# flair_nonprocessed_data_score                       3691.6077    662.467      5.573      0.000    2392.822    4990.393
# spacytextblob_nonprocessed_data_polarity_score     -3399.3566   1102.972     -3.082      0.002   -5561.763   -1236.950
# spacytextblob_nonprocessed_data_subjectivity_score -3273.8604    832.890     -3.931      0.000   -4906.763   -1640.958
# textblob_nonprocessed_data_polarity_score          -3399.3566   1102.972     -3.082      0.002   -5561.763   -1236.950
# textblob_nonprocessed_data_subjectivity_score      -3273.8604    832.890     -3.931      0.000   -4906.763   -1640.958
# vader_nonprocessed_data_score                       4472.9425   1429.691      3.129      0.002    1669.993    7275.892
# bert_nonprocessed_data_sentiment_score             -7542.5958   1481.372     -5.092      0.000   -1.04e+04   -4638.324
# roberta_nonprocessed_data_sentiment_score           4829.7255   1318.659      3.663      0.000    2244.458    7414.993
# ==============================================================================
# Omnibus:                      517.970   Durbin-Watson:                   0.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.430
# Skew:                           0.159   Prob(JB):                     1.31e-33
# Kurtosis:                       2.128   Cond. No.                     8.12e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.96e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     16.06
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.40e-18
# Time:                        13:09:19   Log-Likelihood:                -46094.
# No. Observations:                4218   AIC:                         9.220e+04
# Df Residuals:                    4211   BIC:                         9.225e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.883e+04    695.209     55.860      0.000    3.75e+04    4.02e+04
# flair_nonprocessed_data_score                       3708.5896    662.429      5.598      0.000    2409.880    5007.299
# spacytextblob_nonprocessed_data_polarity_score     -3371.9241   1102.908     -3.057      0.002   -5534.205   -1209.643
# spacytextblob_nonprocessed_data_subjectivity_score -3299.9253    832.841     -3.962      0.000   -4932.733   -1667.117
# textblob_nonprocessed_data_polarity_score          -3371.9241   1102.908     -3.057      0.002   -5534.205   -1209.643
# textblob_nonprocessed_data_subjectivity_score      -3299.9253    832.841     -3.962      0.000   -4932.733   -1667.117
# vader_nonprocessed_data_score                       4442.2102   1429.608      3.107      0.002    1639.424    7244.996
# bert_nonprocessed_data_sentiment_score             -7531.6768   1481.286     -5.085      0.000   -1.04e+04   -4627.574
# roberta_nonprocessed_data_sentiment_score           4835.8607   1318.582      3.667      0.000    2250.744    7420.978
# ==============================================================================
# Omnibus:                      515.576   Durbin-Watson:                   0.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.973
# Skew:                           0.158   Prob(JB):                     1.65e-33
# Kurtosis:                       2.129   Cond. No.                     8.12e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.96e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     16.14
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.91e-18
# Time:                        13:09:19   Log-Likelihood:                -46094.
# No. Observations:                4218   AIC:                         9.220e+04
# Df Residuals:                    4211   BIC:                         9.225e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.886e+04    695.187     55.896      0.000    3.75e+04    4.02e+04
# flair_nonprocessed_data_score                       3705.9316    662.408      5.595      0.000    2407.263    5004.600
# spacytextblob_nonprocessed_data_polarity_score     -3371.7018   1102.873     -3.057      0.002   -5533.914   -1209.490
# spacytextblob_nonprocessed_data_subjectivity_score -3334.8343    832.815     -4.004      0.000   -4967.590   -1702.078
# textblob_nonprocessed_data_polarity_score          -3371.7018   1102.873     -3.057      0.002   -5533.914   -1209.490
# textblob_nonprocessed_data_subjectivity_score      -3334.8343    832.815     -4.004      0.000   -4967.590   -1702.078
# vader_nonprocessed_data_score                       4446.6198   1429.563      3.110      0.002    1643.923    7249.317
# bert_nonprocessed_data_sentiment_score             -7498.0086   1481.239     -5.062      0.000   -1.04e+04   -4593.998
# roberta_nonprocessed_data_sentiment_score           4849.4209   1318.540      3.678      0.000    2264.386    7434.456
# ==============================================================================
# Omnibus:                      517.300   Durbin-Watson:                   0.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.862
# Skew:                           0.156   Prob(JB):                     1.74e-33
# Kurtosis:                       2.128   Cond. No.                     8.12e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.96e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     16.20
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.58e-18
# Time:                        13:09:19   Log-Likelihood:                -46094.
# No. Observations:                4218   AIC:                         9.220e+04
# Df Residuals:                    4211   BIC:                         9.225e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.889e+04    695.147     55.947      0.000    3.75e+04    4.03e+04
# flair_nonprocessed_data_score                       3694.5918    662.370      5.578      0.000    2395.996    4993.187
# spacytextblob_nonprocessed_data_polarity_score     -3430.7884   1102.811     -3.111      0.002   -5592.879   -1268.698
# spacytextblob_nonprocessed_data_subjectivity_score -3360.8824    832.768     -4.036      0.000   -4993.547   -1728.218
# textblob_nonprocessed_data_polarity_score          -3430.7884   1102.811     -3.111      0.002   -5592.879   -1268.698
# textblob_nonprocessed_data_subjectivity_score      -3360.8824    832.768     -4.036      0.000   -4993.547   -1728.218
# vader_nonprocessed_data_score                       4461.6108   1429.482      3.121      0.002    1659.071    7264.150
# bert_nonprocessed_data_sentiment_score             -7444.3714   1481.156     -5.026      0.000   -1.03e+04   -4540.524
# roberta_nonprocessed_data_sentiment_score           4845.4095   1318.466      3.675      0.000    2260.520    7430.299
# ==============================================================================
# Omnibus:                      516.666   Durbin-Watson:                   0.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.538
# Skew:                           0.155   Prob(JB):                     2.05e-33
# Kurtosis:                       2.128   Cond. No.                     8.12e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.96e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     16.27
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.30e-18
# Time:                        13:09:19   Log-Likelihood:                -46093.
# No. Observations:                4218   AIC:                         9.220e+04
# Df Residuals:                    4211   BIC:                         9.224e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.892e+04    694.986     56.006      0.000    3.76e+04    4.03e+04
# flair_nonprocessed_data_score                       3698.3318    662.217      5.585      0.000    2400.037    4996.627
# spacytextblob_nonprocessed_data_polarity_score     -3385.3223   1102.555     -3.070      0.002   -5546.912   -1223.732
# spacytextblob_nonprocessed_data_subjectivity_score -3423.1123    832.575     -4.111      0.000   -5055.398   -1790.826
# textblob_nonprocessed_data_polarity_score          -3385.3223   1102.555     -3.070      0.002   -5546.912   -1223.732
# textblob_nonprocessed_data_subjectivity_score      -3423.1123    832.575     -4.111      0.000   -5055.398   -1790.826
# vader_nonprocessed_data_score                       4345.8927   1429.151      3.041      0.002    1544.002    7147.783
# bert_nonprocessed_data_sentiment_score             -7484.3620   1480.813     -5.054      0.000   -1.04e+04   -4581.187
# roberta_nonprocessed_data_sentiment_score           4895.8790   1318.161      3.714      0.000    2311.588    7480.170
# ==============================================================================
# Omnibus:                      520.146   Durbin-Watson:                   0.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.244
# Skew:                           0.151   Prob(JB):                     2.37e-33
# Kurtosis:                       2.126   Cond. No.                     8.12e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.96e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 3. 4H frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_4hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_4hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     10.56
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.02e-11
# Time:                        13:09:19   Log-Likelihood:                -12047.
# No. Observations:                1104   AIC:                         2.411e+04
# Df Residuals:                    1097   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.861e+04   1808.066     21.356      0.000    3.51e+04    4.22e+04
# flair_nonprocessed_data_score                       1.068e+04   1778.046      6.004      0.000    7186.473    1.42e+04
# spacytextblob_nonprocessed_data_polarity_score     -8958.8519   3007.948     -2.978      0.003   -1.49e+04   -3056.871
# spacytextblob_nonprocessed_data_subjectivity_score -3752.1815   2354.352     -1.594      0.111   -8371.723     867.360
# textblob_nonprocessed_data_polarity_score          -8958.8519   3007.948     -2.978      0.003   -1.49e+04   -3056.871
# textblob_nonprocessed_data_subjectivity_score      -3752.1815   2354.352     -1.594      0.111   -8371.723     867.360
# vader_nonprocessed_data_score                       1.059e+04   3916.659      2.704      0.007    2903.700    1.83e+04
# bert_nonprocessed_data_sentiment_score             -1.931e+04   3941.891     -4.898      0.000    -2.7e+04   -1.16e+04
# roberta_nonprocessed_data_sentiment_score           8483.0433   3516.947      2.412      0.016    1582.341    1.54e+04
# ==============================================================================
# Omnibus:                       84.364   Durbin-Watson:                   0.104
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.303
# Skew:                           0.198   Prob(JB):                     3.56e-08
# Kurtosis:                       2.233   Cond. No.                     4.13e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.01e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     10.58
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.94e-11
# Time:                        13:09:19   Log-Likelihood:                -12047.
# No. Observations:                1104   AIC:                         2.411e+04
# Df Residuals:                    1097   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.878e+04   1807.705     21.454      0.000    3.52e+04    4.23e+04
# flair_nonprocessed_data_score                       1.056e+04   1777.692      5.939      0.000    7069.102     1.4e+04
# spacytextblob_nonprocessed_data_polarity_score     -9053.6881   3007.348     -3.011      0.003    -1.5e+04   -3152.884
# spacytextblob_nonprocessed_data_subjectivity_score -4009.0474   2353.882     -1.703      0.089   -8627.668     609.573
# textblob_nonprocessed_data_polarity_score          -9053.6881   3007.348     -3.011      0.003    -1.5e+04   -3152.884
# textblob_nonprocessed_data_subjectivity_score      -4009.0474   2353.882     -1.703      0.089   -8627.668     609.573
# vader_nonprocessed_data_score                       1.026e+04   3915.878      2.619      0.009    2571.887    1.79e+04
# bert_nonprocessed_data_sentiment_score             -1.899e+04   3941.105     -4.818      0.000   -2.67e+04   -1.13e+04
# roberta_nonprocessed_data_sentiment_score           8920.4230   3516.245      2.537      0.011    2021.096    1.58e+04
# ==============================================================================
# Omnibus:                       83.174   Durbin-Watson:                   0.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.757
# Skew:                           0.193   Prob(JB):                     4.68e-08
# Kurtosis:                       2.235   Cond. No.                     4.13e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.01e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     10.63
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.68e-11
# Time:                        13:09:19   Log-Likelihood:                -12047.
# No. Observations:                1104   AIC:                         2.411e+04
# Df Residuals:                    1097   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.882e+04   1807.804     21.474      0.000    3.53e+04    4.24e+04
# flair_nonprocessed_data_score                       1.057e+04   1777.789      5.948      0.000    7085.716    1.41e+04
# spacytextblob_nonprocessed_data_polarity_score     -8781.8572   3007.512     -2.920      0.004   -1.47e+04   -2880.730
# spacytextblob_nonprocessed_data_subjectivity_score -4215.9166   2354.011     -1.791      0.074   -8834.789     402.956
# textblob_nonprocessed_data_polarity_score          -8781.8572   3007.512     -2.920      0.004   -1.47e+04   -2880.730
# textblob_nonprocessed_data_subjectivity_score      -4215.9166   2354.011     -1.791      0.074   -8834.789     402.956
# vader_nonprocessed_data_score                       1.015e+04   3916.093      2.592      0.010    2468.497    1.78e+04
# bert_nonprocessed_data_sentiment_score             -1.923e+04   3941.320     -4.878      0.000    -2.7e+04   -1.15e+04
# roberta_nonprocessed_data_sentiment_score           9022.5715   3516.438      2.566      0.010    2122.868    1.59e+04
# ==============================================================================
# Omnibus:                       82.797   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.428
# Skew:                           0.188   Prob(JB):                     5.51e-08
# Kurtosis:                       2.235   Cond. No.                     4.13e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.01e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     10.56
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.03e-11
# Time:                        13:09:19   Log-Likelihood:                -12047.
# No. Observations:                1104   AIC:                         2.411e+04
# Df Residuals:                    1097   BIC:                         2.414e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                3.87e+04   1808.346     21.398      0.000    3.51e+04    4.22e+04
# flair_nonprocessed_data_score                       1.051e+04   1778.322      5.910      0.000    7020.253     1.4e+04
# spacytextblob_nonprocessed_data_polarity_score     -8905.3768   3008.414     -2.960      0.003   -1.48e+04   -3002.482
# spacytextblob_nonprocessed_data_subjectivity_score -4034.9124   2354.716     -1.714      0.087   -8655.169     585.344
# textblob_nonprocessed_data_polarity_score          -8905.3768   3008.414     -2.960      0.003   -1.48e+04   -3002.482
# textblob_nonprocessed_data_subjectivity_score      -4034.9124   2354.716     -1.714      0.087   -8655.169     585.344
# vader_nonprocessed_data_score                       1.029e+04   3917.266      2.626      0.009    2600.469     1.8e+04
# bert_nonprocessed_data_sentiment_score              -1.92e+04   3942.501     -4.869      0.000   -2.69e+04   -1.15e+04
# roberta_nonprocessed_data_sentiment_score           9051.0040   3517.491      2.573      0.010    2149.233     1.6e+04
# ==============================================================================
# Omnibus:                       81.724   Durbin-Watson:                   0.107
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.258
# Skew:                           0.189   Prob(JB):                     6.00e-08
# Kurtosis:                       2.238   Cond. No.                     4.13e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.01e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     10.78
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.11e-11
# Time:                        13:09:19   Log-Likelihood:                -12048.
# No. Observations:                1104   AIC:                         2.411e+04
# Df Residuals:                    1097   BIC:                         2.415e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.876e+04   1810.053     21.415      0.000    3.52e+04    4.23e+04
# flair_nonprocessed_data_score                       1.074e+04   1780.000      6.035      0.000    7250.137    1.42e+04
# spacytextblob_nonprocessed_data_polarity_score     -8930.7009   3011.253     -2.966      0.003   -1.48e+04   -3022.234
# spacytextblob_nonprocessed_data_subjectivity_score -4053.6718   2356.939     -1.720      0.086   -8678.290     570.946
# textblob_nonprocessed_data_polarity_score          -8930.7009   3011.253     -2.966      0.003   -1.48e+04   -3022.234
# textblob_nonprocessed_data_subjectivity_score      -4053.6718   2356.939     -1.720      0.086   -8678.290     570.946
# vader_nonprocessed_data_score                       1.019e+04   3920.964      2.598      0.010    2492.518    1.79e+04
# bert_nonprocessed_data_sentiment_score              -1.96e+04   3946.223     -4.966      0.000   -2.73e+04   -1.19e+04
# roberta_nonprocessed_data_sentiment_score           8999.8199   3520.812      2.556      0.011    2091.534    1.59e+04
# ==============================================================================
# Omnibus:                       79.533   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.699
# Skew:                           0.187   Prob(JB):                     7.93e-08
# Kurtosis:                       2.244   Cond. No.                     4.13e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.01e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 4. 6H Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_6hr_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_6hr_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     7.627
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           5.83e-08
# Time:                        13:09:19   Log-Likelihood:                -8141.8
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.633e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.848e+04   2415.941     15.926      0.000    3.37e+04    4.32e+04
# flair_nonprocessed_data_score                       1.189e+04   2306.171      5.155      0.000    7361.759    1.64e+04
# spacytextblob_nonprocessed_data_polarity_score     -8822.9741   4058.581     -2.174      0.030   -1.68e+04    -855.251
# spacytextblob_nonprocessed_data_subjectivity_score -4809.7089   3177.478     -1.514      0.131    -1.1e+04    1428.250
# textblob_nonprocessed_data_polarity_score          -8822.9741   4058.581     -2.174      0.030   -1.68e+04    -855.251
# textblob_nonprocessed_data_subjectivity_score      -4809.7089   3177.478     -1.514      0.131    -1.1e+04    1428.250
# vader_nonprocessed_data_score                       9102.9699   5153.390      1.766      0.078   -1014.058    1.92e+04
# bert_nonprocessed_data_sentiment_score             -2.349e+04   5221.756     -4.499      0.000   -3.37e+04   -1.32e+04
# roberta_nonprocessed_data_sentiment_score           1.189e+04   4680.065      2.540      0.011    2700.173    2.11e+04
# ==============================================================================
# Omnibus:                       64.647   Durbin-Watson:                   0.119
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.510
# Skew:                           0.191   Prob(JB):                     4.76e-06
# Kurtosis:                       2.198   Cond. No.                     1.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     7.715
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           4.64e-08
# Time:                        13:09:19   Log-Likelihood:                -8141.3
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.633e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.874e+04   2414.469     16.046      0.000     3.4e+04    4.35e+04
# flair_nonprocessed_data_score                       1.175e+04   2304.767      5.100      0.000    7228.581    1.63e+04
# spacytextblob_nonprocessed_data_polarity_score     -8594.8020   4056.110     -2.119      0.034   -1.66e+04    -631.932
# spacytextblob_nonprocessed_data_subjectivity_score -5377.7249   3175.543     -1.693      0.091   -1.16e+04     856.434
# textblob_nonprocessed_data_polarity_score          -8594.8020   4056.110     -2.119      0.034   -1.66e+04    -631.932
# textblob_nonprocessed_data_subjectivity_score      -5377.7249   3175.543     -1.693      0.091   -1.16e+04     856.434
# vader_nonprocessed_data_score                       8412.1528   5150.251      1.633      0.103   -1698.713    1.85e+04
# bert_nonprocessed_data_sentiment_score             -2.316e+04   5218.575     -4.438      0.000   -3.34e+04   -1.29e+04
# roberta_nonprocessed_data_sentiment_score           1.284e+04   4677.215      2.745      0.006    3655.260     2.2e+04
# ==============================================================================
# Omnibus:                       61.693   Durbin-Watson:                   0.120
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.639
# Skew:                           0.182   Prob(JB):                     7.36e-06
# Kurtosis:                       2.207   Cond. No.                     1.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     7.656
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           5.41e-08
# Time:                        13:09:19   Log-Likelihood:                -8141.5
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.633e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.875e+04   2415.022     16.043      0.000     3.4e+04    4.35e+04
# flair_nonprocessed_data_score                       1.166e+04   2305.295      5.060      0.000    7138.480    1.62e+04
# spacytextblob_nonprocessed_data_polarity_score     -8477.5085   4057.038     -2.090      0.037   -1.64e+04    -512.815
# spacytextblob_nonprocessed_data_subjectivity_score -5451.0759   3176.270     -1.716      0.087   -1.17e+04     784.511
# textblob_nonprocessed_data_polarity_score          -8477.5085   4057.038     -2.090      0.037   -1.64e+04    -512.815
# textblob_nonprocessed_data_subjectivity_score      -5451.0759   3176.270     -1.716      0.087   -1.17e+04     784.511
# vader_nonprocessed_data_score                       8318.4478   5151.430      1.615      0.107   -1794.733    1.84e+04
# bert_nonprocessed_data_sentiment_score             -2.321e+04   5219.770     -4.447      0.000   -3.35e+04    -1.3e+04
# roberta_nonprocessed_data_sentiment_score           1.287e+04   4678.286      2.751      0.006    3687.414    2.21e+04
# ==============================================================================
# Omnibus:                       61.056   Durbin-Watson:                   0.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.375
# Skew:                           0.178   Prob(JB):                     8.40e-06
# Kurtosis:                       2.209   Cond. No.                     1.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     7.785
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           3.87e-08
# Time:                        13:09:19   Log-Likelihood:                -8142.8
# No. Observations:                 746   AIC:                         1.630e+04
# Df Residuals:                     739   BIC:                         1.633e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.882e+04   2419.317     16.047      0.000    3.41e+04    4.36e+04
# flair_nonprocessed_data_score                        1.19e+04   2309.394      5.155      0.000    7370.687    1.64e+04
# spacytextblob_nonprocessed_data_polarity_score     -8554.4430   4064.253     -2.105      0.036   -1.65e+04    -575.585
# spacytextblob_nonprocessed_data_subjectivity_score -5447.4894   3181.918     -1.712      0.087   -1.17e+04     799.187
# textblob_nonprocessed_data_polarity_score          -8554.4430   4064.253     -2.105      0.036   -1.65e+04    -575.585
# textblob_nonprocessed_data_subjectivity_score      -5447.4894   3181.918     -1.712      0.087   -1.17e+04     799.187
# vader_nonprocessed_data_score                       8182.4612   5160.592      1.586      0.113   -1948.706    1.83e+04
# bert_nonprocessed_data_sentiment_score             -2.364e+04   5229.053     -4.521      0.000   -3.39e+04   -1.34e+04
# roberta_nonprocessed_data_sentiment_score           1.278e+04   4686.606      2.727      0.007    3578.936     2.2e+04
# ==============================================================================
# Omnibus:                       59.164   Durbin-Watson:                   0.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.938
# Skew:                           0.176   Prob(JB):                     1.04e-05
# Kurtosis:                       2.216   Cond. No.                     1.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     7.712
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           4.67e-08
# Time:                        13:09:19   Log-Likelihood:                -8150.9
# No. Observations:                 746   AIC:                         1.632e+04
# Df Residuals:                     739   BIC:                         1.635e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.947e+04   2445.716     16.138      0.000    3.47e+04    4.43e+04
# flair_nonprocessed_data_score                       1.204e+04   2334.594      5.159      0.000    7460.312    1.66e+04
# spacytextblob_nonprocessed_data_polarity_score     -8550.6560   4108.601     -2.081      0.038   -1.66e+04    -484.735
# spacytextblob_nonprocessed_data_subjectivity_score -6014.4667   3216.639     -1.870      0.062   -1.23e+04     300.372
# textblob_nonprocessed_data_polarity_score          -8550.6560   4108.601     -2.081      0.038   -1.66e+04    -484.735
# textblob_nonprocessed_data_subjectivity_score      -6014.4667   3216.639     -1.870      0.062   -1.23e+04     300.372
# vader_nonprocessed_data_score                       8366.7328   5216.903      1.604      0.109   -1874.982    1.86e+04
# bert_nonprocessed_data_sentiment_score             -2.362e+04   5286.111     -4.467      0.000    -3.4e+04   -1.32e+04
# roberta_nonprocessed_data_sentiment_score           1.208e+04   4737.745      2.550      0.011    2778.842    2.14e+04
# ==============================================================================
# Omnibus:                       57.721   Durbin-Watson:                   0.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.875
# Skew:                           0.181   Prob(JB):                     1.08e-05
# Kurtosis:                       2.223   Cond. No.                     1.05e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.36e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# 5. 1D Frequency

# %%
# statistical tests - multiple linear regression
import statsmodels.api as sm

X = sm.add_constant(data_1d_joined[['flair_nonprocessed_data_score', 'spacytextblob_nonprocessed_data_polarity_score', 'spacytextblob_nonprocessed_data_subjectivity_score', 'textblob_nonprocessed_data_polarity_score', 'textblob_nonprocessed_data_subjectivity_score', 'vader_nonprocessed_data_score', 'bert_nonprocessed_data_sentiment_score', 'roberta_nonprocessed_data_sentiment_score']])

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close'], X).fit()
print(f"model summary for same day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+1'], X).fit()
print(f"model summary for day+1 closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+2'], X).fit()
print(f"model summary for day+2 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+3'], X).fit()
print(f"model summary for day+3 day closing price{model.summary()}")

# on close bitcoin price for the given date
model = sm.OLS(data_1d_joined['close_t+7'], X).fit()
print(f"model summary for day+7 day closing price{model.summary()}")
# Out:
# model summary for same day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     6.478
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.55e-06
# Time:                        13:09:20   Log-Likelihood:                -2534.6
# No. Observations:                 233   AIC:                             5083.
# Df Residuals:                     226   BIC:                             5107.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                2.86e+04   5972.354      4.789      0.000    1.68e+04    4.04e+04
# flair_nonprocessed_data_score                       1.973e+04   5599.965      3.524      0.001    8699.565    3.08e+04
# spacytextblob_nonprocessed_data_polarity_score     -2.733e+04   1.03e+04     -2.657      0.008   -4.76e+04   -7057.707
# spacytextblob_nonprocessed_data_subjectivity_score  -566.2165   7395.306     -0.077      0.939   -1.51e+04     1.4e+04
# textblob_nonprocessed_data_polarity_score          -2.733e+04   1.03e+04     -2.657      0.008   -4.76e+04   -7057.707
# textblob_nonprocessed_data_subjectivity_score       -566.2165   7395.306     -0.077      0.939   -1.51e+04     1.4e+04
# vader_nonprocessed_data_score                        4.35e+04   1.34e+04      3.247      0.001    1.71e+04    6.99e+04
# bert_nonprocessed_data_sentiment_score             -5.549e+04   1.33e+04     -4.175      0.000   -8.17e+04   -2.93e+04
# roberta_nonprocessed_data_sentiment_score           2.547e+04   1.15e+04      2.207      0.028    2724.169    4.82e+04
# ==============================================================================
# Omnibus:                        7.136   Durbin-Watson:                   0.288
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                5.311
# Skew:                           0.252   Prob(JB):                       0.0703
# Kurtosis:                       2.458   Cond. No.                     1.27e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  2e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+1 closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+1   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     6.984
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           7.92e-07
# Time:                        13:09:20   Log-Likelihood:                -2532.7
# No. Observations:                 233   AIC:                             5079.
# Df Residuals:                     226   BIC:                             5103.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               2.857e+04   5922.504      4.824      0.000    1.69e+04    4.02e+04
# flair_nonprocessed_data_score                        2.02e+04   5553.223      3.637      0.000    9255.848    3.11e+04
# spacytextblob_nonprocessed_data_polarity_score     -2.739e+04   1.02e+04     -2.685      0.008   -4.75e+04   -7289.383
# spacytextblob_nonprocessed_data_subjectivity_score -1585.7460   7333.578     -0.216      0.829    -1.6e+04    1.29e+04
# textblob_nonprocessed_data_polarity_score          -2.739e+04   1.02e+04     -2.685      0.008   -4.75e+04   -7289.383
# textblob_nonprocessed_data_subjectivity_score      -1585.7460   7333.578     -0.216      0.829    -1.6e+04    1.29e+04
# vader_nonprocessed_data_score                       4.166e+04   1.33e+04      3.136      0.002    1.55e+04    6.78e+04
# bert_nonprocessed_data_sentiment_score             -5.733e+04   1.32e+04     -4.351      0.000   -8.33e+04   -3.14e+04
# roberta_nonprocessed_data_sentiment_score           2.991e+04   1.14e+04      2.614      0.010    7361.822    5.25e+04
# ==============================================================================
# Omnibus:                        5.853   Durbin-Watson:                   0.293
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                4.374
# Skew:                           0.213   Prob(JB):                        0.112
# Kurtosis:                       2.482   Cond. No.                     1.27e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  2e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+2 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+2   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     6.992
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           7.78e-07
# Time:                        13:09:20   Log-Likelihood:                -2535.0
# No. Observations:                 233   AIC:                             5084.
# Df Residuals:                     226   BIC:                             5108.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                2.93e+04   5980.891      4.900      0.000    1.75e+04    4.11e+04
# flair_nonprocessed_data_score                       2.173e+04   5607.970      3.874      0.000    1.07e+04    3.28e+04
# spacytextblob_nonprocessed_data_polarity_score     -2.711e+04   1.03e+04     -2.631      0.009   -4.74e+04   -6807.994
# spacytextblob_nonprocessed_data_subjectivity_score -1894.7606   7405.877     -0.256      0.798   -1.65e+04    1.27e+04
# textblob_nonprocessed_data_polarity_score          -2.711e+04   1.03e+04     -2.631      0.009   -4.74e+04   -6807.994
# textblob_nonprocessed_data_subjectivity_score      -1894.7606   7405.877     -0.256      0.798   -1.65e+04    1.27e+04
# vader_nonprocessed_data_score                       3.924e+04   1.34e+04      2.925      0.004    1.28e+04    6.57e+04
# bert_nonprocessed_data_sentiment_score             -5.882e+04   1.33e+04     -4.420      0.000    -8.5e+04   -3.26e+04
# roberta_nonprocessed_data_sentiment_score           3.002e+04   1.16e+04      2.598      0.010    7249.015    5.28e+04
# ==============================================================================
# Omnibus:                        5.140   Durbin-Watson:                   0.296
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                4.180
# Skew:                           0.228   Prob(JB):                        0.124
# Kurtosis:                       2.528   Cond. No.                     1.27e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  2e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+3 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+3   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     6.837
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           1.11e-06
# Time:                        13:09:20   Log-Likelihood:                -2537.6
# No. Observations:                 233   AIC:                             5089.
# Df Residuals:                     226   BIC:                             5113.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                                3.12e+04   6049.396      5.158      0.000    1.93e+04    4.31e+04
# flair_nonprocessed_data_score                       2.199e+04   5672.204      3.876      0.000    1.08e+04    3.32e+04
# spacytextblob_nonprocessed_data_polarity_score     -2.889e+04   1.04e+04     -2.773      0.006   -4.94e+04   -8356.687
# spacytextblob_nonprocessed_data_subjectivity_score -3472.0215   7490.703     -0.464      0.643   -1.82e+04    1.13e+04
# textblob_nonprocessed_data_polarity_score          -2.889e+04   1.04e+04     -2.773      0.006   -4.94e+04   -8356.687
# textblob_nonprocessed_data_subjectivity_score      -3472.0215   7490.703     -0.464      0.643   -1.82e+04    1.13e+04
# vader_nonprocessed_data_score                       3.718e+04   1.36e+04      2.739      0.007    1.04e+04    6.39e+04
# bert_nonprocessed_data_sentiment_score             -5.854e+04   1.35e+04     -4.349      0.000   -8.51e+04    -3.2e+04
# roberta_nonprocessed_data_sentiment_score           3.025e+04   1.17e+04      2.588      0.010    7218.134    5.33e+04
# ==============================================================================
# Omnibus:                        4.603   Durbin-Watson:                   0.318
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                4.024
# Skew:                           0.241   Prob(JB):                        0.134
# Kurtosis:                       2.573   Cond. No.                     1.27e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  2e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# model summary for day+7 day closing price                            OLS Regression Results
# ==============================================================================
# Dep. Variable:              close_t+7   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     7.522
# Date:                Sat, 23 Dec 2023   Prob (F-statistic):           2.30e-07
# Time:                        13:09:20   Log-Likelihood:                -2534.4
# No. Observations:                 233   AIC:                             5083.
# Df Residuals:                     226   BIC:                             5107.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# const                                               3.381e+04   5965.709      5.667      0.000    2.21e+04    4.56e+04
# flair_nonprocessed_data_score                       2.272e+04   5593.735      4.061      0.000    1.17e+04    3.37e+04
# spacytextblob_nonprocessed_data_polarity_score     -3.138e+04   1.03e+04     -3.053      0.003   -5.16e+04   -1.11e+04
# spacytextblob_nonprocessed_data_subjectivity_score -5882.0786   7387.077     -0.796      0.427   -2.04e+04    8674.277
# textblob_nonprocessed_data_polarity_score          -3.138e+04   1.03e+04     -3.053      0.003   -5.16e+04   -1.11e+04
# textblob_nonprocessed_data_subjectivity_score      -5882.0786   7387.077     -0.796      0.427   -2.04e+04    8674.277
# vader_nonprocessed_data_score                       3.724e+04   1.34e+04      2.783      0.006    1.09e+04    6.36e+04
# bert_nonprocessed_data_sentiment_score             -5.708e+04   1.33e+04     -4.300      0.000   -8.32e+04   -3.09e+04
# roberta_nonprocessed_data_sentiment_score           3.131e+04   1.15e+04      2.716      0.007    8593.739     5.4e+04
# ==============================================================================
# Omnibus:                        5.995   Durbin-Watson:                   0.321
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                3.766
# Skew:                           0.126   Prob(JB):                        0.152
# Kurtosis:                       2.431   Cond. No.                     1.27e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  2e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
